# %% [markdown]
# # Initialization

# %% [markdown]
# ###### Inport modules

# %%
# %matplotlib inline
import os, sys
import matplotlib.pyplot as plt
import numpy as np
from pprint import pprint
from tqdm.notebook import tqdm

from time import sleep, monotonic, time


import qcodes as qc
from qcodes import Parameter

from qcodes.dataset.plotting import plot_dataset, plot_by_id
from qcodes.utils.metadata import diff_param_values
from qcodes.instrument.specialized_parameters import ElapsedTimeParameter
from qcodes.dataset.measurements import Measurement

# sys.path.append('M:\\tnw\\ns\\qt\\2D Topo\\code\\qcodes')
sys.path.append('C:\\qcodes')
from sweeps import do1d, do2d, time_sweep, measure_until, do1d_until

import warnings
warnings.filterwarnings('ignore')

# %%
fridge_name = 'BF1'
# %run ..\..\..\..\..\code\qcodes\init_fridge.py {fridge_name}
# %run ..\..\..\init_fridge.py {fridge_name}
# Out:
# Connected to: KEITHLEY INSTRUMENTS DMM6500 (serial:04518181, firmware:1.7.7b) in 0.47s
# Connected to: KEITHLEY INSTRUMENTS INC. 2440 (serial:1225508, firmware:C30   Mar 17 2006 09:29:29/A02  /B/A) in 0.02s
# [keithley_24(Keithley2400)] Snapshot: Could not update parameter: volt
# [keithley_24(Keithley2400)] Snapshot: Could not update parameter: curr
# [keithley_24(Keithley2400)] Snapshot: Could not update parameter: resistance
# [keithley_19(Keithley2400)] Snapshot: Could not update parameter: volt
# [keithley_19(Keithley2400)] Snapshot: Could not update parameter: curr
# [keithley_19(Keithley2400)] Snapshot: Could not update parameter: resistance
# Connected to: KEITHLEY INSTRUMENTS INC. 2400 (serial:0957985, firmware:C32   Oct  4 2010 14:20:11/A02  /K/M) in 0.03s
# Connected to: AMERICAN MAGNETICS INC. 430 (serial:430-22-114, firmware:3.15) in 1.42s
# Connected to: AMERICAN MAGNETICS INC. 430 (serial:430-22-113, firmware:3.15) in 1.07s
# Connected to: AMERICAN MAGNETICS INC. 430 (serial:430-22-111, firmware:3.15) in 1.01s

# %%
snapshot_of_station = station.snapshot()
pprint(snapshot_of_station)
# Out:
# {'components': {},
#  'config': None,
#  'instruments': {'AMI430_3D': {'__class__': 'qcodes.instrument_drivers.american_magnetics.AMI430.AMI430_3D',
#                                'functions': {},
#                                'label': 'AMI430_3D',
#                                'name': 'AMI430_3D',
#                                'parameters': {'IDN': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                       'full_name': 'AMI430_3D_IDN',
#                                                       'instrument': 'qcodes.instrument_drivers.american_magnetics.AMI430.AMI430_3D',
#                                                       'instrument_name': 'AMI430_3D',
#                                                       'inter_delay': 0,
#                                                       'label': 'IDN',
#                                                       'name': 'IDN',
#                                                       'post_delay': 0,
#                                                       'raw_value': {'firmware': None,
#                                                                     'model': 'AMI430_3D',
#                                                                     'serial': None,
#                                                                     'vendor': 'American '
#                                                                               'Magnetics'},
#                                                       'ts': '2024-04-09 '
#                                                             '18:12:54',
#                                                       'unit': '',
#                                                       'vals': '<Anything>',
#                                                       'value': {'firmware': None,
#                                                                 'model': 'AMI430_3D',
#                                                                 'serial': None,
#                                                                 'vendor': 'American '
#                                                                           'Magnetics'}},
#                                               'block_during_ramp': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                                     'full_name': 'AMI430_3D_block_during_ramp',
#                                                                     'instrument': 'qcodes.instrument_drivers.american_magnetics.AMI430.AMI430_3D',
#                                                                     'instrument_name': 'AMI430_3D',
#                                                                     'inter_delay': 0,
#                                                                     'label': 'block_during_ramp',
#                                                                     'name': 'block_during_ramp',
#                                                                     'post_delay': 0,
#                                                                     'raw_value': True,
#                                                                     'ts': '2024-04-09 '
#                                                                           '18:12:55',
#                                                                     'unit': '',
#                                                                     'vals': '<Boolean>',
#                                                                     'value': True},
#                                               'cartesian': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                             'full_name': 'AMI430_3D_cartesian',
#                                                             'instrument': 'qcodes.instrument_drivers.american_magnetics.AMI430.AMI430_3D',
#                                                             'instrument_name': 'AMI430_3D',
#                                                             'inter_delay': 0,
#                                                             'label': 'cartesian',
#                                                             'name': 'cartesian',
#                                                             'post_delay': 0,
#                                                             'raw_value': [-4.36e-07,
#                                                                           2.67e-07,
#                                                                           2.8865e-05],
#                                                             'ts': '2024-04-09 '
#                                                                   '18:12:55',
#                                                             'unit': 'T',
#                                                             'vals': '<Anything>',
#                                                             'value': [-4.36e-07,
#                                                                       2.67e-07,
#                                                                       2.8865e-05]},
#                                               'cartesian_measured': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                                      'full_name': 'AMI430_3D_cartesian_measured',
#                                                                      'instrument': 'qcodes.instrument_drivers.american_magnetics.AMI430.AMI430_3D',
#                                                                      'instrument_name': 'AMI430_3D',
#                                                                      'inter_delay': 0,
#                                                                      'label': 'cartesian_measured',
#                                                                      'name': 'cartesian_measured',
#                                                                      'post_delay': 0,
#                                                                      'raw_value': [-2.42e-07,
#                                                                                    9.7e-08,
#                                                                                    3.6081e-05],
#                                                                      'ts': '2024-04-09 '
#                                                                            '18:12:54',
#                                                                      'unit': 'T',
#                                                                      'value': [-2.42e-07,
#                                                                                9.7e-08,
#                                                                                3.6081e-05]},
#                                               'cylindrical': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                               'full_name': 'AMI430_3D_cylindrical',
#                                                               'instrument': 'qcodes.instrument_drivers.american_magnetics.AMI430.AMI430_3D',
#                                                               'instrument_name': 'AMI430_3D',
#                                                               'inter_delay': 0,
#                                                               'label': 'cylindrical',
#                                                               'name': 'cylindrical',
#                                                               'post_delay': 0,
#                                                               'raw_value': [5.112582517671475e-07,
#                                                                             148.51730896736495,
#                                                                             2.8865e-05],
#                                                               'ts': '2024-04-09 '
#                                                                     '18:12:55',
#                                                               'unit': 'tuple?',
#                                                               'vals': '<Anything>',
#                                                               'value': [5.112582517671475e-07,
#                                                                         148.51730896736495,
#                                                                         2.8865e-05]},
#                                               'cylindrical_measured': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                                        'full_name': 'AMI430_3D_cylindrical_measured',
#                                                                        'instrument': 'qcodes.instrument_drivers.american_magnetics.AMI430.AMI430_3D',
#                                                                        'instrument_name': 'AMI430_3D',
#                                                                        'inter_delay': 0,
#                                                                        'label': 'cylindrical_measured',
#                                                                        'name': 'cylindrical_measured',
#                                                                        'post_delay': 0,
#                                                                        'raw_value': [9.992497185388645e-08,
#                                                                                      76.10282368498464,
#                                                                                      3.2637e-05],
#                                                                        'ts': '2024-04-09 '
#                                                                              '18:12:55',
#                                                                        'unit': 'T',
#                                                                        'value': [9.992497185388645e-08,
#                                                                                  76.10282368498464,
#                                                                                  3.2637e-05]},
#                                               'field': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                         'full_name': 'AMI430_3D_field',
#                                                         'instrument': 'qcodes.instrument_drivers.american_magnetics.AMI430.AMI430_3D',
#                                                         'instrument_name': 'AMI430_3D',
#                                                         'inter_delay': 0,
#                                                         'label': 'field',
#                                                         'name': 'field',
#                                                         'post_delay': 0,
#                                                         'raw_value': 2.8869527360176853e-05,
#                                                         'ts': '2024-04-09 '
#                                                               '18:12:55',
#                                                         'unit': 'T',
#                                                         'vals': '<Numbers>',
#                                                         'value': 2.8869527360176853e-05},
#                                               'field_measured': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                                  'full_name': 'AMI430_3D_field_measured',
#                                                                  'instrument': 'qcodes.instrument_drivers.american_magnetics.AMI430.AMI430_3D',
#                                                                  'instrument_name': 'AMI430_3D',
#                                                                  'inter_delay': 0,
#                                                                  'label': 'field_measured',
#                                                                  'name': 'field_measured',
#                                                                  'post_delay': 0,
#                                                                  'raw_value': 3.2968232012044566e-05,
#                                                                  'ts': '2024-04-09 '
#                                                                        '18:12:55',
#                                                                  'unit': 'T',
#                                                                  'value': 3.2968232012044566e-05},
#                                               'phi': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                       'full_name': 'AMI430_3D_phi',
#                                                       'instrument': 'qcodes.instrument_drivers.american_magnetics.AMI430.AMI430_3D',
#                                                       'instrument_name': 'AMI430_3D',
#                                                       'inter_delay': 0,
#                                                       'label': 'phi',
#                                                       'name': 'phi',
#                                                       'post_delay': 0,
#                                                       'raw_value': 148.51730896736495,
#                                                       'ts': '2024-04-09 '
#                                                             '18:12:55',
#                                                       'unit': 'deg',
#                                                       'vals': '<Numbers>',
#                                                       'value': 148.51730896736495},
#                                               'phi_measured': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                                'full_name': 'AMI430_3D_phi_measured',
#                                                                'instrument': 'qcodes.instrument_drivers.american_magnetics.AMI430.AMI430_3D',
#                                                                'instrument_name': 'AMI430_3D',
#                                                                'inter_delay': 0,
#                                                                'label': 'phi_measured',
#                                                                'name': 'phi_measured',
#                                                                'post_delay': 0,
#                                                                'raw_value': -78.72637663361174,
#                                                                'ts': '2024-04-09 '
#                                                                      '18:12:55',
#                                                                'unit': 'deg',
#                                                                'value': -78.72637663361174},
#                                               'ramp_mode': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                             'full_name': 'AMI430_3D_ramp_mode',
#                                                             'instrument': 'qcodes.instrument_drivers.american_magnetics.AMI430.AMI430_3D',
#                                                             'instrument_name': 'AMI430_3D',
#                                                             'inter_delay': 0,
#                                                             'label': 'ramp_mode',
#                                                             'name': 'ramp_mode',
#                                                             'post_delay': 0,
#                                                             'raw_value': 'default',
#                                                             'ts': '2024-04-09 '
#                                                                   '18:12:55',
#                                                             'unit': '',
#                                                             'vals': '<Enum: '
#                                                                     "{'default', "
#                                                                     "'simultaneous'}>",
#                                                             'value': 'default'},
#                                               'ramping_state_check_interval': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                                                'full_name': 'AMI430_3D_ramping_state_check_interval',
#                                                                                'instrument': 'qcodes.instrument_drivers.american_magnetics.AMI430.AMI430_3D',
#                                                                                'instrument_name': 'AMI430_3D',
#                                                                                'inter_delay': 0,
#                                                                                'label': 'ramping_state_check_interval',
#                                                                                'name': 'ramping_state_check_interval',
#                                                                                'post_delay': 0,
#                                                                                'raw_value': 0.05,
#                                                                                'ts': '2024-04-09 '
#                                                                                      '18:12:55',
#                                                                                'unit': 's',
#                                                                                'vals': '<Numbers '
#                                                                                        '0<=v<=10>',
#                                                                                'value': 0.05},
#                                               'rho': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                       'full_name': 'AMI430_3D_rho',
#                                                       'instrument': 'qcodes.instrument_drivers.american_magnetics.AMI430.AMI430_3D',
#                                                       'instrument_name': 'AMI430_3D',
#                                                       'inter_delay': 0,
#                                                       'label': 'rho',
#                                                       'name': 'rho',
#                                                       'post_delay': 0,
#                                                       'raw_value': 5.112582517671475e-07,
#                                                       'ts': '2024-04-09 '
#                                                             '18:12:55',
#                                                       'unit': 'T',
#                                                       'vals': '<Numbers>',
#                                                       'value': 5.112582517671475e-07},
#                                               'rho_measured': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                                'full_name': 'AMI430_3D_rho_measured',
#                                                                'instrument': 'qcodes.instrument_drivers.american_magnetics.AMI430.AMI430_3D',
#                                                                'instrument_name': 'AMI430_3D',
#                                                                'inter_delay': 0,
#                                                                'label': 'rho_measured',
#                                                                'name': 'rho_measured',
#                                                                'post_delay': 0,
#                                                                'raw_value': 3.8358441052785236e-07,
#                                                                'ts': '2024-04-09 '
#                                                                      '18:12:55',
#                                                                'unit': 'T',
#                                                                'value': 3.8358441052785236e-07},
#                                               'spherical': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                             'full_name': 'AMI430_3D_spherical',
#                                                             'instrument': 'qcodes.instrument_drivers.american_magnetics.AMI430.AMI430_3D',
#                                                             'instrument_name': 'AMI430_3D',
#                                                             'inter_delay': 0,
#                                                             'label': 'spherical',
#                                                             'name': 'spherical',
#                                                             'post_delay': 0,
#                                                             'raw_value': [2.8869527360176853e-05,
#                                                                           1.014719467053666,
#                                                                           148.51730896736495],
#                                                             'ts': '2024-04-09 '
#                                                                   '18:12:55',
#                                                             'unit': 'tuple?',
#                                                             'vals': '<Anything>',
#                                                             'value': [2.8869527360176853e-05,
#                                                                       1.014719467053666,
#                                                                       148.51730896736495]},
#                                               'spherical_measured': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                                      'full_name': 'AMI430_3D_spherical_measured',
#                                                                      'instrument': 'qcodes.instrument_drivers.american_magnetics.AMI430.AMI430_3D',
#                                                                      'instrument_name': 'AMI430_3D',
#                                                                      'inter_delay': 0,
#                                                                      'label': 'spherical_measured',
#                                                                      'name': 'spherical_measured',
#                                                                      'post_delay': 0,
#                                                                      'raw_value': [3.526895260707355e-05,
#                                                                                    1.216758174049983,
#                                                                                    -155.04318919195305],
#                                                                      'ts': '2024-04-09 '
#                                                                            '18:12:55',
#                                                                      'unit': 'T',
#                                                                      'value': [3.526895260707355e-05,
#                                                                                1.216758174049983,
#                                                                                -155.04318919195305]},
#                                               'theta': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                         'full_name': 'AMI430_3D_theta',
#                                                         'instrument': 'qcodes.instrument_drivers.american_magnetics.AMI430.AMI430_3D',
#                                                         'instrument_name': 'AMI430_3D',
#                                                         'inter_delay': 0,
#                                                         'label': 'theta',
#                                                         'name': 'theta',
#                                                         'post_delay': 0,
#                                                         'raw_value': 1.014719467053666,
#                                                         'ts': '2024-04-09 '
#                                                               '18:12:55',
#                                                         'unit': 'deg',
#                                                         'vals': '<Numbers>',
#                                                         'value': 1.014719467053666},
#                                               'theta_measured': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                                  'full_name': 'AMI430_3D_theta_measured',
#                                                                  'instrument': 'qcodes.instrument_drivers.american_magnetics.AMI430.AMI430_3D',
#                                                                  'instrument_name': 'AMI430_3D',
#                                                                  'inter_delay': 0,
#                                                                  'label': 'theta_measured',
#                                                                  'name': 'theta_measured',
#                                                                  'post_delay': 0,
#                                                                  'raw_value': 1.3704146914794155,
#                                                                  'ts': '2024-04-09 '
#                                                                        '18:12:55',
#                                                                  'unit': 'deg',
#                                                                  'value': 1.3704146914794155},
#                                               'vector_ramp_rate': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                                    'full_name': 'AMI430_3D_vector_ramp_rate',
#                                                                    'instrument': 'qcodes.instrument_drivers.american_magnetics.AMI430.AMI430_3D',
#                                                                    'instrument_name': 'AMI430_3D',
#                                                                    'inter_delay': 0,
#                                                                    'label': 'vector_ramp_rate',
#                                                                    'name': 'vector_ramp_rate',
#                                                                    'post_delay': 0,
#                                                                    'raw_value': None,
#                                                                    'ts': '2024-04-09 '
#                                                                          '18:12:55',
#                                                                    'unit': 'T/s',
#                                                                    'vals': '<Numbers '
#                                                                            'v>=0.0>',
#                                                                    'value': None},
#                                               'x': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                     'full_name': 'AMI430_3D_x',
#                                                     'instrument': 'qcodes.instrument_drivers.american_magnetics.AMI430.AMI430_3D',
#                                                     'instrument_name': 'AMI430_3D',
#                                                     'inter_delay': 0,
#                                                     'label': 'x',
#                                                     'name': 'x',
#                                                     'post_delay': 0,
#                                                     'raw_value': -4.36e-07,
#                                                     'ts': '2024-04-09 18:12:55',
#                                                     'unit': 'T',
#                                                     'vals': '<Numbers>',
#                                                     'value': -4.36e-07},
#                                               'x_measured': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                              'full_name': 'AMI430_3D_x_measured',
#                                                              'instrument': 'qcodes.instrument_drivers.american_magnetics.AMI430.AMI430_3D',
#                                                              'instrument_name': 'AMI430_3D',
#                                                              'inter_delay': 0,
#                                                              'label': 'x_measured',
#                                                              'name': 'x_measured',
#                                                              'post_delay': 0,
#                                                              'raw_value': 1.7e-07,
#                                                              'ts': '2024-04-09 '
#                                                                    '18:12:54',
#                                                              'unit': 'T',
#                                                              'value': 1.7e-07},
#                                               'y': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                     'full_name': 'AMI430_3D_y',
#                                                     'instrument': 'qcodes.instrument_drivers.american_magnetics.AMI430.AMI430_3D',
#                                                     'instrument_name': 'AMI430_3D',
#                                                     'inter_delay': 0,
#                                                     'label': 'y',
#                                                     'name': 'y',
#                                                     'post_delay': 0,
#                                                     'raw_value': 2.67e-07,
#                                                     'ts': '2024-04-09 18:12:55',
#                                                     'unit': 'T',
#                                                     'vals': '<Numbers>',
#                                                     'value': 2.67e-07},
#                                               'y_measured': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                              'full_name': 'AMI430_3D_y_measured',
#                                                              'instrument': 'qcodes.instrument_drivers.american_magnetics.AMI430.AMI430_3D',
#                                                              'instrument_name': 'AMI430_3D',
#                                                              'inter_delay': 0,
#                                                              'label': 'y_measured',
#                                                              'name': 'y_measured',
#                                                              'post_delay': 0,
#                                                              'raw_value': 1.46e-07,
#                                                              'ts': '2024-04-09 '
#                                                                    '18:12:54',
#                                                              'unit': 'T',
#                                                              'value': 1.46e-07},
#                                               'z': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                     'full_name': 'AMI430_3D_z',
#                                                     'instrument': 'qcodes.instrument_drivers.american_magnetics.AMI430.AMI430_3D',
#                                                     'instrument_name': 'AMI430_3D',
#                                                     'inter_delay': 0,
#                                                     'label': 'z',
#                                                     'name': 'z',
#                                                     'post_delay': 0,
#                                                     'raw_value': 2.8865e-05,
#                                                     'ts': '2024-04-09 18:12:55',
#                                                     'unit': 'T',
#                                                     'vals': '<Numbers>',
#                                                     'value': 2.8865e-05},
#                                               'z_measured': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                              'full_name': 'AMI430_3D_z_measured',
#                                                              'instrument': 'qcodes.instrument_drivers.american_magnetics.AMI430.AMI430_3D',
#                                                              'instrument_name': 'AMI430_3D',
#                                                              'inter_delay': 0,
#                                                              'label': 'z_measured',
#                                                              'name': 'z_measured',
#                                                              'post_delay': 0,
#                                                              'raw_value': 3.2473e-05,
#                                                              'ts': '2024-04-09 '
#                                                                    '18:12:54',
#                                                              'unit': 'T',
#                                                              'value': 3.2473e-05}},
#                                'submodules': {}},
#                  'keithley_19': {'__class__': 'qcodes.instrument_drivers.Keithley.Keithley_2400.Keithley2400',
#                                  'address': 'GPIB0::19::INSTR',
#                                  'functions': {},
#                                  'label': 'keithley_19',
#                                  'name': 'keithley_19',
#                                  'parameters': {'IDN': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                         'full_name': 'keithley_19_IDN',
#                                                         'instrument': 'qcodes.instrument_drivers.Keithley.Keithley_2400.Keithley2400',
#                                                         'instrument_name': 'keithley_19',
#                                                         'inter_delay': 0,
#                                                         'label': 'IDN',
#                                                         'name': 'IDN',
#                                                         'post_delay': 0,
#                                                         'raw_value': {'firmware': 'C32   '
#                                                                                   'Oct  '
#                                                                                   '4 '
#                                                                                   '2010 '
#                                                                                   '14:20:11/A02  '
#                                                                                   '/K/M',
#                                                                       'model': '2400',
#                                                                       'serial': '0957985',
#                                                                       'vendor': 'KEITHLEY '
#                                                                                 'INSTRUMENTS '
#                                                                                 'INC.'},
#                                                         'ts': '2024-04-09 '
#                                                               '18:12:44',
#                                                         'unit': '',
#                                                         'vals': '<Anything>',
#                                                         'value': {'firmware': 'C32   '
#                                                                               'Oct  '
#                                                                               '4 '
#                                                                               '2010 '
#                                                                               '14:20:11/A02  '
#                                                                               '/K/M',
#                                                                   'model': '2400',
#                                                                   'serial': '0957985',
#                                                                   'vendor': 'KEITHLEY '
#                                                                             'INSTRUMENTS '
#                                                                             'INC.'}},
#                                                 'compliancei': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                                 'full_name': 'keithley_19_compliancei',
#                                                                 'instrument': 'qcodes.instrument_drivers.Keithley.Keithley_2400.Keithley2400',
#                                                                 'instrument_name': 'keithley_19',
#                                                                 'inter_delay': 0,
#                                                                 'label': 'Current '
#                                                                          'Compliance',
#                                                                 'name': 'compliancei',
#                                                                 'post_delay': 0,
#                                                                 'raw_value': '1.000000E-01',
#                                                                 'ts': '2024-04-09 '
#                                                                       '18:12:44',
#                                                                 'unit': '',
#                                                                 'value': 0.1},
#                                                 'compliancev': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                                 'full_name': 'keithley_19_compliancev',
#                                                                 'instrument': 'qcodes.instrument_drivers.Keithley.Keithley_2400.Keithley2400',
#                                                                 'instrument_name': 'keithley_19',
#                                                                 'inter_delay': 0,
#                                                                 'label': 'Voltage '
#                                                                          'Compliance',
#                                                                 'name': 'compliancev',
#                                                                 'post_delay': 0,
#                                                                 'raw_value': '2.100000E+01',
#                                                                 'ts': '2024-04-09 '
#                                                                       '18:12:44',
#                                                                 'unit': '',
#                                                                 'value': 21.0},
#                                                 'curr': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                          'full_name': 'keithley_19_curr',
#                                                          'instrument': 'qcodes.instrument_drivers.Keithley.Keithley_2400.Keithley2400',
#                                                          'instrument_name': 'keithley_19',
#                                                          'inter_delay': 0,
#                                                          'label': 'Current',
#                                                          'name': 'curr',
#                                                          'post_delay': 0,
#                                                          'raw_value': None,
#                                                          'ts': None,
#                                                          'unit': 'A',
#                                                          'value': None},
#                                                 'mode': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                          'full_name': 'keithley_19_mode',
#                                                          'instrument': 'qcodes.instrument_drivers.Keithley.Keithley_2400.Keithley2400',
#                                                          'instrument_name': 'keithley_19',
#                                                          'inter_delay': 0,
#                                                          'label': 'Mode',
#                                                          'name': 'mode',
#                                                          'post_delay': 0,
#                                                          'raw_value': 'VOLT',
#                                                          'ts': '2024-04-09 '
#                                                                '18:12:44',
#                                                          'unit': '',
#                                                          'vals': '<Enum: '
#                                                                  "{'CURR', "
#                                                                  "'VOLT'}>",
#                                                          'value': 'VOLT'},
#                                                 'nplci': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                           'full_name': 'keithley_19_nplci',
#                                                           'instrument': 'qcodes.instrument_drivers.Keithley.Keithley_2400.Keithley2400',
#                                                           'instrument_name': 'keithley_19',
#                                                           'inter_delay': 0,
#                                                           'label': 'Current '
#                                                                    'integration '
#                                                                    'time',
#                                                           'name': 'nplci',
#                                                           'post_delay': 0,
#                                                           'raw_value': '1.00',
#                                                           'ts': '2024-04-09 '
#                                                                 '18:12:44',
#                                                           'unit': '',
#                                                           'value': 1.0},
#                                                 'nplcv': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                           'full_name': 'keithley_19_nplcv',
#                                                           'instrument': 'qcodes.instrument_drivers.Keithley.Keithley_2400.Keithley2400',
#                                                           'instrument_name': 'keithley_19',
#                                                           'inter_delay': 0,
#                                                           'label': 'Voltage '
#                                                                    'integration '
#                                                                    'time',
#                                                           'name': 'nplcv',
#                                                           'post_delay': 0,
#                                                           'raw_value': '1.00',
#                                                           'ts': '2024-04-09 '
#                                                                 '18:12:44',
#                                                           'unit': '',
#                                                           'value': 1.0},
#                                                 'output': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                            'full_name': 'keithley_19_output',
#                                                            'instrument': 'qcodes.instrument_drivers.Keithley.Keithley_2400.Keithley2400',
#                                                            'instrument_name': 'keithley_19',
#                                                            'inter_delay': 0,
#                                                            'label': 'output',
#                                                            'name': 'output',
#                                                            'post_delay': 0,
#                                                            'raw_value': '0',
#                                                            'ts': '2024-04-09 '
#                                                                  '18:12:44',
#                                                            'unit': '',
#                                                            'val_mapping': OrderedDict([('On',
#                                                                                         '1'),
#                                                                                        ('ON',
#                                                                                         '1'),
#                                                                                        ('on',
#                                                                                         '1'),
#                                                                                        ('1',
#                                                                                         '1'),
#                                                                                        (True,
#                                                                                         '1'),
#                                                                                        ('Off',
#                                                                                         '0'),
#                                                                                        ('OFF',
#                                                                                         '0'),
#                                                                                        ('off',
#                                                                                         '0'),
#                                                                                        ('0',
#                                                                                         '0'),
#                                                                                        (False,
# ...
#                                                                         'ramping': 1,
#                                                                         'zeroing current': 6},
#                                                         'vals': '<Enum: '
#                                                                 "{'zeroing "
#                                                                 "current', "
#                                                                 "'quench "
#                                                                 "detected', "
#                                                                 "'ramping', "
#                                                                 "'paused', "
#                                                                 "'heating "
#                                                                 "switch', "
#                                                                 "'manual up', "
#                                                                 "'cooling "
#                                                                 "switch', "
#                                                                 "'holding', "
#                                                                 "'manual "
#                                                                 "down', 'at "
#                                                                 'zero '
#                                                                 "current'}>",
#                                                         'value': 'paused'},
#                                       'ramping_state_check_interval': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                                        'full_name': 'z_ramping_state_check_interval',
#                                                                        'instrument': 'qcodes.instrument_drivers.american_magnetics.AMI430.AMI430',
#                                                                        'instrument_name': 'z',
#                                                                        'inter_delay': 0,
#                                                                        'label': 'ramping_state_check_interval',
#                                                                        'name': 'ramping_state_check_interval',
#                                                                        'post_delay': 0,
#                                                                        'raw_value': 0.05,
#                                                                        'ts': '2024-04-09 '
#                                                                              '18:12:54',
#                                                                        'unit': 's',
#                                                                        'vals': '<Numbers '
#                                                                                '0<=v<=10>',
#                                                                        'value': 0.05},
#                                       'setpoint': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                    'full_name': 'z_setpoint',
#                                                    'instrument': 'qcodes.instrument_drivers.american_magnetics.AMI430.AMI430',
#                                                    'instrument_name': 'z',
#                                                    'inter_delay': 0,
#                                                    'label': 'setpoint',
#                                                    'name': 'setpoint',
#                                                    'post_delay': 0,
#                                                    'raw_value': '0.000000000\r\n',
#                                                    'ts': '2024-04-09 18:12:53',
#                                                    'unit': 'T',
#                                                    'value': 0.0}},
#                        'persistent': True,
#                        'port': 7180,
#                        'submodules': {'switch_heater': {'__class__': 'qcodes.instrument_drivers.american_magnetics.AMI430.AMI430SwitchHeater',
#                                                         'functions': {},
#                                                         'label': 'SwitchHeater',
#                                                         'name': 'z_SwitchHeater',
#                                                         'parameters': {'cool_time': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                                                      'full_name': 'z_SwitchHeater_cool_time',
#                                                                                      'instrument': 'qcodes.instrument_drivers.american_magnetics.AMI430.AMI430SwitchHeater',
#                                                                                      'instrument_name': 'z_SwitchHeater',
#                                                                                      'inter_delay': 0,
#                                                                                      'label': 'Cooling '
#                                                                                               'Time',
#                                                                                      'name': 'cool_time',
#                                                                                      'post_delay': 0,
#                                                                                      'raw_value': '600\r\n',
#                                                                                      'ts': '2024-04-09 '
#                                                                                            '18:12:52',
#                                                                                      'unit': 's',
#                                                                                      'vals': '<Ints '
#                                                                                              '5<=v<=3600>',
#                                                                                      'value': 600},
#                                                                        'current': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                                                    'full_name': 'z_SwitchHeater_current',
#                                                                                    'instrument': 'qcodes.instrument_drivers.american_magnetics.AMI430.AMI430SwitchHeater',
#                                                                                    'instrument_name': 'z_SwitchHeater',
#                                                                                    'inter_delay': 0,
#                                                                                    'label': 'Switch '
#                                                                                             'Heater '
#                                                                                             'Current',
#                                                                                    'name': 'current',
#                                                                                    'post_delay': 0,
#                                                                                    'raw_value': '18.9\r\n',
#                                                                                    'ts': '2024-04-09 '
#                                                                                          '18:12:52',
#                                                                                    'unit': 'mA',
#                                                                                    'vals': '<Numbers '
#                                                                                            '0<=v<=125>',
#                                                                                    'value': 18.9},
#                                                                        'enabled': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                                                    'full_name': 'z_SwitchHeater_enabled',
#                                                                                    'instrument': 'qcodes.instrument_drivers.american_magnetics.AMI430.AMI430SwitchHeater',
#                                                                                    'instrument_name': 'z_SwitchHeater',
#                                                                                    'inter_delay': 0,
#                                                                                    'label': 'Switch '
#                                                                                             'Heater '
#                                                                                             'Enabled',
#                                                                                    'name': 'enabled',
#                                                                                    'post_delay': 0,
#                                                                                    'raw_value': True,
#                                                                                    'ts': '2024-04-09 '
#                                                                                          '18:12:52',
#                                                                                    'unit': '',
#                                                                                    'vals': '<Boolean>',
#                                                                                    'value': True},
#                                                                        'heat_time': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                                                      'full_name': 'z_SwitchHeater_heat_time',
#                                                                                      'instrument': 'qcodes.instrument_drivers.american_magnetics.AMI430.AMI430SwitchHeater',
#                                                                                      'instrument_name': 'z_SwitchHeater',
#                                                                                      'inter_delay': 0,
#                                                                                      'label': 'Heating '
#                                                                                               'Time',
#                                                                                      'name': 'heat_time',
#                                                                                      'post_delay': 0,
#                                                                                      'raw_value': '30\r\n',
#                                                                                      'ts': '2024-04-09 '
#                                                                                            '18:12:52',
#                                                                                      'unit': 's',
#                                                                                      'vals': '<Ints '
#                                                                                              '5<=v<=120>',
#                                                                                      'value': 30},
#                                                                        'in_persistent_mode': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                                                               'full_name': 'z_SwitchHeater_in_persistent_mode',
#                                                                                               'instrument': 'qcodes.instrument_drivers.american_magnetics.AMI430.AMI430SwitchHeater',
#                                                                                               'instrument_name': 'z_SwitchHeater',
#                                                                                               'inter_delay': 0,
#                                                                                               'label': 'Persistent '
#                                                                                                        'Mode',
#                                                                                               'name': 'in_persistent_mode',
#                                                                                               'post_delay': 0,
#                                                                                               'raw_value': '0\r\n',
#                                                                                               'ts': '2024-04-09 '
#                                                                                                     '18:12:52',
#                                                                                               'unit': '',
#                                                                                               'val_mapping': {False: 0,
#                                                                                                               True: 1},
#                                                                                               'vals': '<Enum: '
#                                                                                                       '{False, '
#                                                                                                       'True}>',
#                                                                                               'value': False},
#                                                                        'state': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                                                  'full_name': 'z_SwitchHeater_state',
#                                                                                  'instrument': 'qcodes.instrument_drivers.american_magnetics.AMI430.AMI430SwitchHeater',
#                                                                                  'instrument_name': 'z_SwitchHeater',
#                                                                                  'inter_delay': 0,
#                                                                                  'label': 'Switch '
#                                                                                           'Heater '
#                                                                                           'On',
#                                                                                  'name': 'state',
#                                                                                  'post_delay': 0,
#                                                                                  'raw_value': True,
#                                                                                  'ts': '2024-04-09 '
#                                                                                        '18:12:52',
#                                                                                  'unit': '',
#                                                                                  'vals': '<Boolean>',
#                                                                                  'value': True}},
#                                                         'submodules': {}}},
#                        'terminator': '\r\n',
#                        'timeout': 5}},
#  'parameters': {}}

# %% [markdown]
# ##  DAC range(K213)

# %%
keithley_2.averaging_enabled(False)

# %%
magnet_y.current_limit()

# %%
K213.voltage1(0)
K213.voltage2(0)
K213.voltage3(0)
K213.voltage4(0)
#you can choose the DAC range by setting to a specific value
K213.vrange1(3) #0(0V), 1(1V), 2(5V), 3(10V)
K213.vrange2(3) #0(0V), 1(1V), 2(5V), 3(10V)
K213.vrange3(3) #0(0V), 1(1V), 2(5V), 3(10V)
K213.vrange4(3) #0(0V), 1(1V), 2(5V), 3(10V)

# %%
K213.voltage1(1e-3)

# %% [markdown]
# ## DAC Kei 2440

# %% [markdown]
# ### sensitive check

# %%
keithley_24.mode()
# Out:
# 'VOLT'

# %%
keithley_24.output(1) # output on
keithley_24.rangev(10) # 200 mV, 2 V, 10 V and 40 V 
keithley_24.volt(1)
keithley_24.compliancei(100e-3)
# keithley_24.output(0) #output off
sleep(1)
v_read=keithley_2.amplitude()
print(v_read)
# Out:
# 0.0002153898

# %%
keithley_24.volt(0.0)
keithley_24.output(0) #output off

# %%
keithley_24.rangev(10)
keithley_24.rangev()
# Out:
# 10.5

# %%
keithley_24.rangev()

# %% [markdown]
# ## TG 2400

# %%
keithley_19.output(1) # output on
keithley_19.rangev(22) # 200 mV, 2 V, 20 V and 200 V 
keithley_19.volt(0)
keithley_19.compliancei(100e-3)
# keithley_24.output(0) #output off
sleep(1)
v_read=keithley_2.amplitude()
print(v_read)
# Out:
# 6.605899e-05

# %%
keithley_19.volt(1)
keithley_19.output(0) #output off

# %%
keithley_19.rangev(22)
keithley_19.rangev()
# Out:
# 210.0

# %% [markdown]
# ##  Database initialisation

# %%
reuse = True
# %run ..\..\..\init_database.py {reuse}
# Out:
# Using existing database file:
# D:\data\Kay\NTHU_MoS2_batch2\NTHU_MoS2_batch2_2024-04-02_01.db

# %% [markdown]
# # Scaled parameters

# %%
from qcodes import ManualParameter, ScaledParameter

# %% [markdown]
# ## Defining scaled parameters

# %%
Irange = Parameter('Irange', label='current range', unit='', set_cmd=None, get_cmd=None)
Vrange = Parameter('Vrange', label='voltage range', unit='', set_cmd=None, get_cmd=None)
TGrange = Parameter('TGrange', label='Top gate range', unit='', set_cmd=None, get_cmd=None)

#division paraemtrs required for simplier update: they used as an argument for scaled paraemtrs of sorce instruments

# Irange_division = Parameter('Irange_division', 
#                             label='scaled current range', unit='', 
#                             set_cmd=None, get_cmd=lambda : 100 / Irange())

Irange_division = Parameter('Irange_division', 
                            label='scaled current range', unit='', 
                            set_cmd=None, get_cmd=lambda : 1 / Irange())

Vrange_division = Parameter('Vrange_division', 
                            label='scaled voltage range', unit='', 
                            set_cmd=None, get_cmd=lambda : 1 / Vrange())

TGrange_division = Parameter('TGrange_division', 
                             label='scaled Top gate range', unit='', 
                             set_cmd=None, get_cmd=lambda : 1 / TGrange())

Irange_AC_division = Parameter('Irange_AC_division', 
                               label='scaled current range for lockin', unit='', 
                               set_cmd=None, get_cmd=lambda : 1000 / Irange())

Vrange_AC_division = Parameter('Vrange_AC_division', 
                               label='scaled voltage range for lockin', unit='', 
                               set_cmd=None, get_cmd=lambda : 1000 / Vrange())

Gain_K1 = Parameter('Gain_K1', label='Gain K1', unit='', set_cmd=None, get_cmd=None)
Gain_K2 = Parameter('Gain_K2', label='Gain K2', unit='', set_cmd=None, get_cmd=None)
Gain_L1 = Parameter('Gain_L1', label='Gain L1', unit='', set_cmd=None, get_cmd=None)
Gain_L2 = Parameter('Gain_L2', label='Gain L2', unit='', set_cmd=None, get_cmd=None)

#Add components
station.add_component(Irange)
station.add_component(Vrange)
station.add_component(TGrange)

station.add_component(Irange_division)
station.add_component(Vrange_division)
station.add_component(TGrange_division)

station.add_component(Irange_AC_division)
station.add_component(Vrange_AC_division)
                             
station.add_component(Gain_K1)
station.add_component(Gain_K2)
station.add_component(Gain_L1)
station.add_component(Gain_L2)
# Out:
# 'Gain_L2'

# %% [markdown]
# ## Parameters - update here during measuerements

# %%
Irange.set(1e-6)
Vrange.set(1) ## need to be sync with K213 range
TGrange.set(1)
Gain_K1.set(1e6)
Gain_K2.set(1e6)
# Gain_K3.set(1e2)
Gain_L1.set(Gain_K1())
Gain_L2.set(Gain_K2())
#division parameters are updated automatically

# %% [markdown]
# ## DC parameters

# %%
# appl_current = ScaledParameter(ivvi.dac1, division = Irange_division, name = 'appl_current', unit = 'A')
appl_current = ScaledParameter(keithley_24.volt, division = Irange_division, name = 'appl_current', unit = 'A')
# for K213
# appl_current = ScaledParameter(K213.voltage1, division = Irange_division, name = 'appl_current', unit = 'A')
appl_voltage = ScaledParameter(keithley_24.volt, division = Vrange_division, name = 'appl_voltage', unit = 'V')
appl_TG = ScaledParameter(keithley_19.volt, division = TGrange_division, name = 'appl_TG', unit = 'V')

# meas_voltage_K1 = ScaledParameter(keithley_1.amplitude, division = Gain_K1, name = 'meas_voltage_K1', unit = 'V')
meas_voltage_K2 = ScaledParameter(keithley_2.amplitude, division = Gain_K2, name = 'meas_voltage_K2', unit = 'V')

#meas_leakage = ScaledParameter(keithley_2.amplitude, division = Gain_K2, name = 'meas_leakage', unit = 'A')

# meas_current_K1 = ScaledParameter(keithley_1.amplitude, division = Gain_K1, name = 'meas_current_K1', unit = 'A')
meas_current_K2 = ScaledParameter(keithley_2.amplitude, division = Gain_K2, name = 'meas_current_K2', unit = 'A')

station.add_component(appl_current)
station.add_component(appl_voltage)
station.add_component(appl_TG)
# station.add_component(meas_voltage_K1)
station.add_component(meas_voltage_K2)
#station.add_component(meas_leakage)
# station.add_component(meas_current_K1)
station.add_component(meas_current_K2)
# Out:
# 'meas_current_K2'

# %%
keithley_24.output(0)
appl_current(0)
sleep(1)
# meas_voltage_K2()

# %% [markdown]
# ##  AC parameters

# %%
appl_current_AC = ScaledParameter(lockin_1.amplitude, division = Irange_AC_division, name = 'appl_current_AC', unit = 'A')
appl_voltage_AC = ScaledParameter(lockin_1.amplitude, division = Vrange_AC_division, name = 'appl_voltage_AC', unit = 'V')

station.add_component(appl_current_AC)
station.add_component(appl_voltage_AC)

meas_voltage_AC_L1 = ScaledParameter(lockin_1.X, division = Gain_L1, name = 'meas_voltage_Lockin1', unit = 'V')
meas_current_AC_L1 = ScaledParameter(lockin_1.X, division = Gain_L1, name = 'meas_current_Lockin1', unit = 'A')
meas_phase_AC_L1 = ScaledParameter(lockin_1.P, division = 1, name = 'meas_phase_Lockin1', unit = 'degree')


# meas_voltage_AC_L2 = ScaledParameter(lockin_2.X, division = Gain_L2, name = 'meas_voltage_Lockin2', unit = 'V')
# meas_current_AC_L2 = ScaledParameter(lockin_2.X, division = Gain_L2, name = 'meas_current_Lockin2', unit = 'A')
# meas_phase_AC_L2 = ScaledParameter(lockin_2.P, division = 1, name = 'meas_phase_Lockin1', unit = 'degree')

station.add_component(meas_voltage_AC_L1)
station.add_component(meas_current_AC_L1)
station.add_component(meas_phase_AC_L1)

# station.add_component(meas_voltage_AC_L2)
# station.add_component(meas_current_AC_L2)

meas_voltage_AC_L1_R = ScaledParameter(lockin_1.R, division = Gain_L1, name = 'meas_voltage_R_Lockin1', unit = 'V')
# meas_voltage_AC_L2_R = ScaledParameter(lockin_2.R, division = Gain_L2, name = 'meas_voltage_R_Lockin2', unit = 'V')

station.add_component(meas_voltage_AC_L1_R)
# station.add_component(meas_voltage_AC_L2_R)

# %%
meas_voltage_AC_L1_P = ScaledParameter(lockin_1.P, division = 1, name = 'meas_voltage_Lockin1_P', unit = 'degree')
meas_current_AC_L1_P = ScaledParameter(lockin_1.P, division = 1, name = 'meas_current_Lockin1_P', unit = 'degree')

# meas_voltage_AC_L2_P = ScaledParameter(lockin_2.P, division = 1, name = 'meas_voltage_Lockin2_P', unit = 'degree')
# meas_current_AC_L2_P = ScaledParameter(lockin_2.P, division = 1, name = 'meas_current_Lockin2_P', unit = 'degree')

station.add_component(meas_voltage_AC_L1_P)
station.add_component(meas_current_AC_L1_P)

# station.add_component(meas_voltage_AC_L2_P)
# station.add_component(meas_current_AC_L2_P)

# %% [markdown]
# ## Another useful example: magnet using dac (Janis)

# %% [markdown]
# >2231.2 G per A => 0.22312 T per A<br>
# I source 10mA per V => 1e-5 A per 1mV<br>
# result: 0.22312 T/A * 1e-5 A/mV

# %%
def get_R_from_IV(dataid):
    dataset = qc.load_by_id(dataid)

    voltage = dataset.get_parameter_data()['meas_voltage_K2']['meas_voltage_K2']
    current = dataset.get_parameter_data()['meas_voltage_K2']['appl_current']
    fit_values = np.polyfit(current,voltage,1)
    
    return fit_values[0]

def get_R_from_IV_2(dataid):
    dataset = qc.load_by_id(dataid)

    voltage = dataset.get_parameter_data()['meas_voltage_K2']['meas_voltage_K2']
    current = dataset.get_parameter_data()['meas_voltage_K2']['appl_current']
    fit_values = np.polyfit(current,voltage,1)
    
    return fit_values[0]

# %%
def get_G_from_IV(dataid):
    dataset = qc.load_by_id(dataid)

    voltage = dataset.get_parameter_data()['meas_current_K1']['appl_voltage']
    current = dataset.get_parameter_data()['meas_current_K1']['meas_curret_K1']
    fit_values = np.polyfit(voltage,current,1)
    
    return fit_values[0]

def get_G_from_IV_2(dataid):
    dataset = qc.load_by_id(dataid)

    voltage = dataset.get_parameter_data()['meas_current_K2']['appl_voltage']
    current = dataset.get_parameter_data()['meas_current_K2']['meas_curret_K2']
    fit_values = np.polyfit(voltage,current,1)
    
    return fit_values[0]

# %%
def get_R_from_VI(dataid):
    dataset = qc.load_by_id(dataid)

    current = dataset.get_parameter_data()['meas_current_K2']['meas_current_K2']
    voltage = dataset.get_parameter_data()['meas_current_K2']['appl_voltage']
    fit_values = np.polyfit(current,voltage,1)
    
    return fit_values[0]

def get_R_from_VI_2(dataid):
    dataset = qc.load_by_id(dataid)

    current = dataset.get_parameter_data()['meas_current_K2']['meas_current_K2']
    voltage = dataset.get_parameter_data()['meas_current_K2']['appl_voltage']
    fit_values = np.polyfit(current,voltage,1)
    
    return fit_values[0]

# %% [markdown]
# # Simple VIs

# %% [markdown]
# ## sensitive check

# %% [markdown]
# ### 升電壓

# %%
keithley_19.output(1)
for i in range(41):
    appl_TG(-40+i)
    sleep(0.5)
keithley_19.output(0)

# %% [markdown]
# ### 降電壓

# %%
keithley_19.output(1)
for i in range(41):
    appl_TG(0-i)
    sleep(0.5)
keithley_19.output(0)

# %% [markdown]
# ## VI

# %% [markdown]
# ### VI

# %%
keithley_2.averaging_count(5)
keithley_2.averaging_enabled(True)
keithley_24.output(1)

appl_voltage(-1.5)
sleep(5)

# station.snapshot(update=True);
exp = qc.new_experiment('V vs I', sample_name='VI_25_27_V+-1.5_1E6')
#d_o1d(param_set, start, stop, num_points, delay, *param_meas)


dataid = do1d(appl_voltage,-1.5,1.5, 101, 0.5, meas_current_K2)
# dataid = do1d(appl_current, 6e-6 , -6e-6, 251, 0.01, meas_voltage_K1)
# ivvi.set_dacs_zero()

appl_voltage(0)
plot_by_id(dataid)
# R=1/get_G_from_IV_2
# print(get_G_from_IV_2)
#print(get_R_from_IV_2(dataid))
keithley_24.output(0)

# %%
keithley_2.averaging_count(10)
keithley_2.averaging_enabled(True)
keithley_24.output(1)

appl_voltage(-0.2)

# station.snapshot(update=True);
exp = qc.new_experiment('V vs I', sample_name='VI_19_23')
#d_o1d(param_set, start, stop, num_points, delay, *param_meas)

dataid = do1d(appl_voltage,-0.2 ,1.5, 101, 0.05, meas_current_K2)
# dataid = do1d(appl_current, 6e-6 , -6e-6, 251, 0.01, meas_voltage_K1)
# ivvi.set_dacs_zero()

appl_voltage(0)
plot_by_id(dataid)
# R=1/get_G_from_IV_2
# print(get_G_from_IV_2)
#print(get_R_from_IV_2(dataid))
keithley_24.output(0)

# %%
get_R_from_VI(157)/1e6

# %% [markdown]
# ### VgI

# %%
keithley_19.output(1)
keithley_24.output(1)

for i in range(31):
    appl_TG(0-i)
    sleep(0.01)    

appl_TG()

# %%
keithley_2.averaging_count(10)
keithley_2.averaging_enabled(True)
appl_voltage(0.5)
sleep(5)

dataid = do1d(appl_TG,-10,40, 201, 0.0, meas_current_K2)
plot_by_id(dataid)

keithley_19.output(0)  
keithley_24.output(0)
appl_voltage(0)

# %%
get_R_from_VI(78)/1e6

# %%
keithley_2.averaging_count(5)
keithley_2.averaging_enabled(True)
keithley_19.output(1)
keithley_24.output(1)

for i in range(11):
    appl_TG(0-i)
    sleep(10)
appl_voltage(1.5)

exp = qc.new_experiment('Vg vs I', sample_name='VgI_25_27_+1.5_for')

#d_o1d(param_set, start, stop, num_points, delay, *param_meas)

dataid = do1d(appl_TG,-10 ,40, 101, 10, meas_current_K2)

plot_by_id(dataid)

keithley_19.output(0)  
keithley_24.output(0)
appl_voltage(0)

# %% [markdown]
# ## 加TG(1D)

# %%
keithley_19.output(1)
keithley_24.output(1)
for i in range(4):
    appl_TG(35i)
    sleep(10)
appl_voltage(-0.5)
sleep(5)

# station.snapshot(update=True);
exp = qc.new_experiment('V vs I', sample_name='VI_27_31_V+-0.5V_Vg:50V')
#d_o1d(param_set, start, stop, num_points, delay, *param_meas)

dataid = do1d(appl_voltage,-0.5 ,0.5 ,101, 0.1, meas_current_K2)
# dataid = do1d(appl_current, 6e-6 , -6e-6, 251, 0.01, meas_voltage_K1)
# ivvi.set_dacs_zero()

plot_by_id(dataid)

keithley_19.output(0)  
keithley_24.output(0)
appl_current(0)

#print(get_R_from_IV(dataid))
# print(get_R_from_IV_2(dataid))

# %% [markdown]
# # Simple IVs

# %% [markdown]
# ## IV

# %%
keithley_24.output(1)
appl_current(-1e-6)
sleep(5)
# station.snapshot(update=True);
exp = qc.new_experiment('I vs V', sample_name='IV_24_27_26_29')
#d_o1d(param_set, start, stop, num_points, delay, *param_meas)

dataid = do1d(appl_current,-1e-6 ,1e-6, 101, 0.05, meas_voltage_K2)
# dataid = do1d(appl_current, 6e-6 , -6e-6, 251, 0.01, meas_voltage_K1)
# ivvi.set_dacs_zero()

appl_current(0)
plot_by_id(dataid)
# print(get_R_from_IV(dataid))
#print(get_R_from_IV_2(dataid))


keithley_24.output(0)

# %%
keithley_24.output(1)
appl_current(0.0e-6)
keithley_24.output(0)
#appl_current(0e-6)

# %%
runid=349
print(get_R_from_IV_2(runid))

# %% [markdown]
# ## 加TG (1D)

# %%
keithley_19.output(1)
appl_TG(0)

# %%
keithley_19.output(1)
keithley_24.output(1)
appl_TG(-30)
sleep(3)
appl_current(-1.5e-6)
sleep(1)

# station.snapshot(update=True);
exp = qc.new_experiment('IV', sample_name='35_J2')

#do1d(param_set, start, stop, num_points, delay, *param_meas)
dataid = do1d(appl_current, -1.5e-6 ,1.5e-6, 101, 0.05, meas_voltage_K2)
# dataid = do1d(appl_current, 6e-6 , -6e-6, 251, 0.01, meas_voltage_K1)
# ivvi.set_dacs_zero()

keithley_19.output(0)
keithley_24.output(0)
appl_current(0)
plot_by_id(dataid)
#print(get_R_from_IV(dataid))
# print(get_R_from_IV_2(dataid))

# %% [markdown]
# ## 歸零

# %%
keithley_19.output(1)
keithley_24.output(1)

appl_current(0)
sleep(1)
appl_TG(0)
sleep(5)


keithley_19.output(0)
keithley_24.output(0)

# %% [markdown]
# # Magnetic field

# %% [markdown]
# ## Bx

# %% [markdown]
# ### IV vs Bx

# %%
keithley_24.rangev()

# %%
keithley_24.volt(0)
keithley_24.output(1) #output off
sleep(1)
appl_current(1.5e-6)
sleep(2)
meas_voltage_K2()

# %%
keithley_24.output(1)
sleep(2)
magnet_x.field(-5e-3)
appl_current(-0.8e-6)
sleep(5)

# station.snapshot(update=True);

exp = qc.new_experiment('IV vs Bx', sample_name='IV_Bx_-5to-30mT')

dataid = do2d(magnet_x.field, -5e-3, -30e-3, 4001, 1, appl_current, -0.8e-6 ,1e-6, 101, 0.01, meas_voltage_K2)

appl_current(0)
# magnet_x.field(0)

plot_by_id(dataid)

keithley_24.output(0)
#keithley_24.output(0)
#appl_current(0e-6)

# %%
magnet_x.field(0e-3)
sleep(5)

#magnet_x.field(-17.24e-3)
#sleep(5)

# %% [markdown]
# ### VI vs Bx

# %%
keithley_24.output(1)
sleep(2)
magnet_x.field(-30e-3)
appl_voltage(-0.2)
sleep(5)

# station.snapshot(update=True);

exp = qc.new_experiment('IV vs Bx', sample_name='IV_Bx_-30to-30mT')

dataid = do2d(magnet_x.field, -30e-3, -30e-3, 301, 1, appl_voltage, -0.2 ,1.5, 101, 0.01, meas_voltage_K2)

appl_voltage(0)
# magnet_x.field(0)

plot_by_id(dataid)

keithley_24.output(0)
#keithley_24.output(0)
#appl_current(0e-6)

# %%
magnet_x.field(-20e-3)
sleep(5)

magnet_x.field(-17.24e-3)
sleep(5)

# %% [markdown]
# ## By

# %% [markdown]
# ### IV vs By

# %%
keithley_24.output(1)
sleep(2)
magnet_y.field(3e-3)
sleep(3)
appl_current(-2e-7)
sleep(5)

# station.snapshot(update=True);

exp = qc.new_experiment('IV vs By', sample_name='IV_By_3mT')

dataid = do2d(magnet_y.field, 3e-3, 1e-3, 200 , 1, appl_current, -2e-7 ,2e-7, 101, 0.01, meas_voltage_K2)

appl_current(0)
keithley_24.output(0)
# magnet_y.field(0)

plot_by_id(dataid)

# %%
magnet_y.field(-0.82)
sleep(60)
magnet_y.field(-0.8)
sleep(60)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 magnet_y.field(-0.82)
#       2 sleep(60)
#       3 magnet_y.field(-0.8)
#
# NameError: name 'magnet_y' is not defined

# %% [markdown]
# ### VI vs By

# %%
keithley_24.output(1)
sleep(2)
magnet_y.field(-0.8)
sleep(10)
keithley_19.output(1)
for i in range(41):
    appl_TG(0+i)
    sleep(20) 
appl_voltage(-1)
sleep(60)

# station.snapshot(update=True);

exp = qc.new_experiment('IV vs By', sample_name='VI_By_+-0.8T_for_Vg40')

dataid = do2d(magnet_y.field, -0.8, 0.8, 101 , 30, appl_voltage, -1 ,1, 101, 0.1, meas_current_K2)

appl_TG(0)
appl_voltage(0)
keithley_24.output(0)
keithley_19.output(0)
# magnet_y.field(0)

plot_by_id(dataid)

# %%
keithley_24.output(1)
sleep(2)
magnet_y.field(-0.8)
sleep(20)
keithley_19.output(1)
for i in range(41):
    appl_TG(0+i)
    sleep(20) 
appl_voltage(1)
sleep(60)

# station.snapshot(update=True);

exp = qc.new_experiment('IV vs By', sample_name='VI_By_+-0.8T_for_Vg40/V1')

dataid = do1d(magnet_y.field, -0.8, 0.8, 101 , 20, meas_current_K2)

appl_TG(0)
appl_voltage(0)
keithley_24.output(0)
keithley_19.output(0)
# magnet_y.field(0)

plot_by_id(dataid)

# %% [markdown]
# ## IV w/ Bx

# %%
keithley_24.output(1)
sleep(2)
magnet_x.field(0.23e-3)
appl_current(-0.5e-6)
sleep(10)

# station.snapshot(update=True);
exp = qc.new_experiment('I vs V', sample_name='IV_w/_Bx')

#do1d(param_set, start, stop, num_points, delay, *param_meas)
dataid = do1d(appl_current, -0.5e-6 ,0.5e-6, 101, 0.05, meas_voltage_K2)
# dataid = do1d(appl_current, 6e-6 , -6e-6, 251, 0.01, meas_voltage_K1)
# ivvi.set_dacs_zero()

appl_current(0)
plot_by_id(dataid)
# print(get_R_from_IV(dataid))
#print(get_R_from_IV_2(dataid))

keithley_24.output(0)

# %% [markdown]
# ## IV w/ By

# %%
keithley_24.output(1)
sleep(2)
magnet_y.field(2e-3)
appl_current(-1.5e-5)
sleep(60)

# station.snapshot(update=True);
exp = qc.new_experiment('I vs V', sample_name='IV_w/_By')

#do1d(param_set, start, stop, num_points, delay, *param_meas)
dataid = do1d(appl_current, -2.5e-6 ,2.5e-6, 501, 0.05, meas_voltage_K2)
# dataid = do1d(appl_current, 6e-6 , -6e-6, 251, 0.01, meas_voltage_K1)
# ivvi.set_dacs_zero()

appl_current(0)
plot_by_id(dataid)
# print(get_R_from_IV(dataid))
#print(get_R_from_IV_2(dataid))

keithley_24.output(0)

# %%
keithley_24.output(1)
keithley_19.output(1)
sleep(2)
magnet_y.field(5e-3)
appl_TG(40)
appl_voltage(-1.5)
sleep(60)

# station.snapshot(update=True);
exp = qc.new_experiment('V vs I', sample_name='VI_w/_By_-5mT')

#do1d(param_set, start, stop, num_points, delay, *param_meas)
dataid = do1d(appl_voltage, -1.5 ,1.5, 201, 0.05, meas_voltage_K2)
# dataid = do1d(appl_current, 6e-6 , -6e-6, 251, 0.01, meas_voltage_K1)
# ivvi.set_dacs_zero()

appl_current(0)
plot_by_id(dataid)
# print(get_R_from_IV(dataid))
#print(get_R_from_IV_2(dataid))

keithley_19.output(0)
keithley_24.output(0)

# %% [markdown]
# # Zero everything

# %%
appl_current(0)
appl_TG(0)
magnet_y.field(0)
sleep(2)
magnet_x.field(0)
sleep(2)
#appl_voltage_AC(0.004)
#SGS.off()

keithley_24.output(0)

# %% [markdown]
# # Gate simple sweeps

# %% [markdown]
# ## IVs 加TG (2D)

# %%
keithley_19.output(1)
keithley_24.output(1)
appl_TG(-40)
sleep(5)
appl_current(-0.1)
sleep(1)

exp = qc.new_experiment('I_vs_Vgate_up', sample_name='19_21_Vg')
dataid = do2d(appl_TG, -40, 1, 101, 1, appl_current, -0.1, 0.1, 101, 0.1, meas_voltage_K2)

appl_TG(0)
sleep(5)
appl_current(0)
sleep(5)

keithley_19.output(0)
keithley_24.output(0)

plot_by_id(dataid)

# %%
keithley_19.output(1)
keithley_24.output(1)

for i in range(31):
    appl_TG(0-i)
    sleep(0.05)    

appl_TG()

# %% [markdown]
# ## VI 加TG (2D)

# %%
### Ting
keithley_2.averaging_count(5)
keithley_2.averaging_enabled(True)
appl_voltage(-0.1)
sleep(5)

exp = qc.new_experiment('I_vs_Vgate_up', sample_name='18_15Real_Vg22')

dataid = do2d(appl_TG, 1 ,40, 71, 10, appl_voltage, -0.1, 0.1, 101, 0.1, meas_current_K2)

# dataid = do1d(appl_voltage,-0.1 ,0.1, 101, 0.05, meas_current_K2)
# dataid = do1d(appl_current, 6e-6 , -6e-6, 251, 0.01, meas_voltage_K1)
# ivvi.set_dacs_zero()

# for i in range(51):
#     appl_TG(51-i)
#     sleep(0.05)

# keithley_19.output(0)  
# keithley_24.output(0)
appl_voltage(0)
# appl_TG(0)

plot_by_id(dataid)

# %%
keithley_2.averaging_count(5)
keithley_2.averaging_enabled(True)
keithley_19.output(1)
keithley_24.output(1)

for i in range(11):
    appl_TG(0-i)
    sleep(10)
    
appl_voltage(-1.5)
sleep(5)

exp = qc.new_experiment('I_vs_Vgate_up', sample_name='25_27_Vg22_for_+-1.5V_1E6')

dataid = do2d(appl_TG,-10 ,40, 71, 10, appl_voltage, -1.5, 1.5, 101, 0.1, meas_current_K2)
# dataid = do1d(appl_voltage,-0.1 ,0.1, 101, 0.05, meas_current_K2)
# dataid = do1d(appl_current, 6e-6 , -6e-6, 251, 0.01, meas_voltage_K1)
# ivvi.set_dacs_zero()
sleep(30)


appl_voltage(0)
appl_TG(0)
sleep(5)

keithley_19.output(0)  
keithley_24.output(0)


plot_by_id(dataid)

# %%
keithley_2.averaging_count(5)
keithley_2.averaging_enabled(True)
keithley_19.output(1)
keithley_24.output(1)

for i in range(2):
    appl_TG(i+0)
    sleep(5)
    
appl_voltage(-0.05)
sleep(5)

exp = qc.new_experiment('I_vs_Vgate_up', sample_name='18_15Real_Vg22_for')

dataid = do2d(appl_TG,1 ,20, 101, 5, appl_voltage, -0.05,0.05, 101, 0.5, meas_current_K2)
# dataid = do1d(appl_voltage,-0.1 ,0.1, 101, 0.05, meas_current_K2)
# dataid = do1d(appl_current, 6e-6 , -6e-6, 251, 0.01, meas_voltage_K1)
# ivvi.set_dacs_zero()
sleep(120)


appl_voltage(0)
appl_TG(0)
sleep(5)

keithley_19.output(0)  
keithley_24.output(0)


plot_by_id(dataid)

# %% [markdown]
# # RF

# %% [markdown]
# ## I vs RF_f

# %% [markdown]
# ### sensitive check

# %%
SGS.power()

# %%
SGS.on()

# %%
SGS.off()

# %%
magnet_x.field(0.4e-3)
sleep(10)
magnet_y.field(2.53e-3)
sleep(10)

# %% [markdown]
# ### I vs RF_f (1D)

# %%
SGS.off()
exp = qc.new_experiment('I vs RF_f', sample_name='IvsRF_f')
SGS.power(25)
SGS.frequency(1.8e9)
SGS.on()
sleep(1)
keithley_2.averaging_count(5)
keithley_2.averaging_enabled(False)
keithley_24.output(1)

appl_current(0.1e-6)
#appl_TG(10)
# magnet_x.field(0.4e-3)
# magnet_y.field(2.53e-3)

dataid = do1d(SGS.frequency, 1.8e9, 2.5e9, 5000, 0.1, meas_voltage_K2)
appl_current(0)
SGS.off()
keithley_24.output(0)
plot_by_id(dataid)

# %% [markdown]
# ### I vs RF_f (2D)

# %%
SGS.off()
SGS.power(0)
SGS.frequency(0.1e9)
SGS.on()
keithley_2.averaging_count(1)
keithley_2.averaging_enabled(False)
keithley_24.output(1)

appl_current(-1.5e-6)
#appl_TG(-10)
# magnet_x.field(0.4e-3)
# magnet_y.field(2.53e-3)
# sleep(1)

# station.snapshot(update=True);
exp = qc.new_experiment('IV vs RF_f', sample_name='IV vs RF_f_J3_2D')

#do1d(param_set, start, stop, num_points, delay, *param_meas)
dataid = do2d(SGS.frequency, 0.1e9, 20e9, 1000, 0.1, appl_current,-1.5e-6 ,1.5e-6, 101, 0.01, meas_voltage_K2)
# dataid = do1d(appl_current, 6e-6 , -6e-6, 251, 0.01, meas_voltage_K1)
# ivvi.set_dacs_zero()
keithley_24.output(0)
SGS.off()
appl_current(0)
plot_by_id(dataid)
# print(get_R_from_IV(dataid))
#print(get_R_from_IV_2(dataid))

# %% [markdown]
# ## Bx vs RF_f

# %%
SGS.off()
SGS.power(0)
SGS.frequency(3.87e9)
SGS.on()
keithley_2.averaging_count(5)
keithley_2.averaging_enabled(False)
keithley_24.output(1)

appl_current(-1.2e-6)
#appl_TG(-10)
magnet_y.field(-10e-3)

#magnet_y.field(1.41e-3)
# sleep(1)

# station.snapshot(update=True);
exp = qc.new_experiment('Bx vs RF_f', sample_name='By vs RF_f_J2_3.87_-10dB')

#do1d(param_set, start, stop, num_points, delay, *param_meas)""
dataid = do2d(magnet_y.field, -10e-3, 10e-3,701, 1, appl_current,-1.2e-6 ,1.2e-6, 101, 0.05,  meas_voltage_K2)
# dataid = do1d(appl_current, 6e-6 , -6e-6, 251, 0.01, meas_voltage_K1)
# ivvi.set_dacs_zero()
keithley_24.output(0)
SGS.off()
appl_current(0)
plot_by_id(dataid)
# print(get_R_from_IV(dataid))
#print(get_R_from_IV_2(dataid))

# %%
appl_current(0)
#appl_TG(0)
magnet_y.field(0)
sleep(2)
magnet_x.field(0)
sleep(2)
#appl_voltage_AC(0.004)
SGS.off()

# %% [markdown]
# ## IV vs RF_f

# %% [markdown]
# ### Shapiro steps

# %% [markdown]
# #### 1 line

# %%
SGS.off()
SGS.power(-20)
SGS.frequency(5.5381e9)
SGS.on()
keithley_2.averaging_count(5)
keithley_2.averaging_enabled(False)
keithley_24.output(1)

appl_current(-1e-6)
#appl_TG(-10)
#magnet_x.field(0.23e-3)
#magnet_y.field(1.41e-3)
# sleep(1)

# station.snapshot(update=True);
exp = qc.new_experiment('IV vs RF_f', sample_name='IV vs RF_f_5.538_-20dB')

#do1d(param_set, start, stop, num_points, delay, *param_meas)""
dataid = do1d(appl_current,-1e-6 ,1e-6, 101, 0.05,  meas_voltage_K2)
# dataid = do1d(appl_current, 6e-6 , -6e-6, 251, 0.01, meas_voltage_K1)
# ivvi.set_dacs_zero()
keithley_24.output(0)
SGS.off()
appl_current(0)
plot_by_id(dataid)
# print(get_R_from_IV(dataid))
#print(get_R_from_IV_2(dataid))

# %%
appl_current(0)
#appl_TG(0)
magnet_y.field(0)
sleep(10)
magnet_x.field(0)
sleep(10)
#appl_voltage_AC(0.004)
SGS.off()

# %% [markdown]
# #### multi-line

# %%
def run_1d_measurement(frequency, exp_name_suffix):
    SGS.off()
    SGS.power(0)
    SGS.frequency(frequency)
    SGS.on()

    keithley_2.averaging_count(5)
    keithley_2.averaging_enabled(False)
    keithley_24.output(1)

    appl_current(-2e-6)

    exp = qc.new_experiment('IV vs RF_f', sample_name=f'IV vs RF_f_{frequency}_0dB')

    dataid = do1d(appl_current, -1.5e-6, 1.5e-6, 101, 0.05, meas_voltage_K2)

    keithley_24.output(0)
    SGS.off()
    appl_current(0)

    plot_by_id(dataid)

# 指定不同的頻率進行 1D 測量
frequencies = [5.876e9, 6.155e9, 7.410e9, 7.769e9, 8.167e9, 5.538e9, 5.398e9, 4.303e9]  # 添加更多頻率
for frequency in frequencies:
    run_1d_measurement(frequency, '')

# %%
appl_current(0)
#appl_TG(0)
magnet_y.field(0)
sleep(10)
magnet_x.field(0)
sleep(10)
#appl_voltage_AC(0.004)
SGS.off()

# %% [markdown]
# ## IV vs Power Dependence

# %% [markdown]
# ### 1 frequency

# %%
SGS.off()
SGS.power(-20)
SGS.frequency(6.155e9)
SGS.on()
keithley_2.averaging_count(5)
keithley_2.averaging_enabled(True)
keithley_24.output(1)

sleep(5)
#magnet_x.field(15e-3)
#sleep(5)
appl_current(-1e-6)
#appl_TG(-30)
sleep(2)

# station.snapshot(update=True);
exp = qc.new_experiment('IV vs power dependence', sample_name='IV vs PD_6.155')

#do1d(param_set, start, stop, num_points, delay, *param_meas)

dataid = do2d(SGS.power,-12, 18, 201, 1, appl_current,-2.5e-6 ,2.5e-6, 101, 0.01, meas_voltage_K2)
# dataid = do1d(appl_current, 6e-6 , -6e-6, 251, 0.01, meas_voltage_K1)
# ivvi.set_dacs_zero()

SGS.off()
sleep(5)
plot_by_id(dataid)


SGS.power(-20)
SGS.frequency(7.410e9)
SGS.on()
keithley_2.averaging_count(5)
keithley_2.averaging_enabled(True)
keithley_24.output(1)

sleep(5)
#magnet_x.field(15e-3)
#sleep(5)
appl_current(-1e-6)
#appl_TG(-30)
sleep(2)

# station.snapshot(update=True);
exp = qc.new_experiment('IV vs power dependence', sample_name='IV vs PD_7.410')

#do1d(param_set, start, stop, num_points, delay, *param_meas)

dataid = do2d(SGS.power,-12, 18, 201, 1, appl_current,-2e-6 ,2e-6, 101, 0.01, meas_voltage_K2)
# dataid = do1d(appl_current, 6e-6 , -6e-6, 251, 0.01, meas_voltage_K1)
# ivvi.set_dacs_zero()

SGS.off()
sleep(5)
plot_by_id(dataid)


SGS.power(-20)
SGS.frequency(7.769e9)
SGS.on()
keithley_2.averaging_count(5)
keithley_2.averaging_enabled(True)
keithley_24.output(1)

sleep(5)
#magnet_x.field(15e-3)
#sleep(5)
appl_current(-1e-6)
#appl_TG(-30)
sleep(2)

# station.snapshot(update=True);
exp = qc.new_experiment('IV vs power dependence', sample_name='IV vs PD_7.769')

#do1d(param_set, start, stop, num_points, delay, *param_meas)

dataid = do2d(SGS.power,-12, 18, 201, 1, appl_current,-2e-6 ,2e-6, 101, 0.01, meas_voltage_K2)
# dataid = do1d(appl_current, 6e-6 , -6e-6, 251, 0.01, meas_voltage_K1)
# ivvi.set_dacs_zero()

SGS.off()
sleep(5)
plot_by_id(dataid)


SGS.power(-20)
SGS.frequency(8.167e9)
SGS.on()
keithley_2.averaging_count(5)
keithley_2.averaging_enabled(True)
keithley_24.output(1)

sleep(5)
#magnet_x.field(15e-3)
#sleep(5)
appl_current(-1e-6)
#appl_TG(-30)
sleep(2)

# station.snapshot(update=True);
exp = qc.new_experiment('IV vs power dependence', sample_name='IV vs PD_8.167')

#do1d(param_set, start, stop, num_points, delay, *param_meas)

dataid = do2d(SGS.power,-10, 18, 201, 1, appl_current,-2e-6 ,2e-6, 101, 0.01, meas_voltage_K2)
# dataid = do1d(appl_current, 6e-6 , -6e-6, 251, 0.01, meas_voltage_K1)
# ivvi.set_dacs_zero()

SGS.off()


appl_current(0)
keithley_24.output()
sleep(10)
plot_by_id(dataid)
# print(get_R_from_IV(dataid))
print(get_R_from_IV_2(dataid))

# %%
SGS.off()
SGS.power(-20)
SGS.frequency(5.398e9)
SGS.on()
keithley_2.averaging_count(5)
keithley_2.averaging_enabled(True)
keithley_24.output(1)

magnet_x.field(5e-3)
sleep(5)
appl_current(-1e-6)
#appl_TG(-30)
sleep(2)

# station.snapshot(update=True);
exp = qc.new_experiment('IV vs power dependence', sample_name='IV vs PD_5.398_5mT')

#do1d(param_set, start, stop, num_points, delay, *param_meas)

dataid = do2d(SGS.power,-20, 25, 101, 1, appl_current,-1e-6 ,1e-6, 101, 0.05, meas_voltage_K2)
# dataid = do1d(appl_current, 6e-6 , -6e-6, 251, 0.01, meas_voltage_K1)
# ivvi.set_dacs_zero()

SGS.off()
plot_by_id(dataid)
sleep(10)


SGS.power(-20)
SGS.frequency(8.167e9)
SGS.on()
keithley_2.averaging_count(5)
keithley_2.averaging_enabled(True)
keithley_24.output(1)

magnet_x.field(5e-3)
sleep(5)
appl_current(-1e-6)
#appl_TG(-30)
sleep(2)

# station.snapshot(update=True);
exp = qc.new_experiment('IV vs power dependence', sample_name='IV vs PD_8.167_5mT')

#do1d(param_set, start, stop, num_points, delay, *param_meas)

dataid = do2d(SGS.power,-20, 25, 101, 1, appl_current,-1e-6 ,1e-6, 101, 0.05, meas_voltage_K2)
# dataid = do1d(appl_current, 6e-6 , -6e-6, 251, 0.01, meas_voltage_K1)
# ivvi.set_dacs_zero()


SGS.off()
plot_by_id(dataid)
sleep(10)

SGS.power(-20)
SGS.frequency(4.303e9)
SGS.on()
keithley_2.averaging_count(5)
keithley_2.averaging_enabled(True)
keithley_24.output(1)

magnet_x.field(5e-3)
sleep(5)
appl_current(-1e-6)
#appl_TG(-30)
sleep(2)

# station.snapshot(update=True);
exp = qc.new_experiment('IV vs power dependence', sample_name='IV vs PD_4.303_5mT')

#do1d(param_set, start, stop, num_points, delay, *param_meas)

dataid = do2d(SGS.power,-20, 25, 101, 1, appl_current,-1e-6 ,1e-6, 101, 0.05, meas_voltage_K2)
# dataid = do1d(appl_current, 6e-6 , -6e-6, 251, 0.01, meas_voltage_K1)
# ivvi.set_dacs_zero()


SGS.off()
sleep(10)

appl_current(0)
keithley_24.output()
plot_by_id(dataid)

# print(get_R_from_IV(dataid))
print(get_R_from_IV_2(dataid))

# %% [markdown]
# ### multi-frequency

# %%
def run_measurement(power, frequency, exp_name_suffix):
    SGS.power(power)
    SGS.frequency(frequency)
    SGS.on()

    keithley_2.averaging_count(5)
    keithley_2.averaging_enabled(True)
    keithley_24.output(1)

    sleep(5)

    appl_current(-1e-6)
    sleep(2)

    exp = qc.new_experiment('IV vs power dependence', sample_name=f'IV vs PD_{frequency}')

    dataid = do2d(SGS.power, -20, 13, 201, 1, appl_current, -2e-6, 2e-6, 101, 0.01, meas_voltage_K2)

    SGS.off()
    sleep(5)

    plot_by_id(dataid)

    appl_current(0)
    keithley_24.output()
    sleep(10)

    plot_by_id(dataid)
    print(get_R_from_IV_2(dataid))


# 使用不同頻率運行測量
run_measurement(-20, 7.769e9, '7.769')
run_measurement(-20, 8.167e9, '8.167')

# %%
## SGS.off()
SGS.power(-20)
SGS.frequency(5.e9)
SGS.on()
keithley_2.averaging_count(5)
keithley_2.averaging_enabled(True)
keithley_24.output(1)

magnet_x.field(10e-3)
sleep(5)
appl_current(-1e-6)
#appl_TG(-30)
sleep(2)

# station.snapshot(update=True);
exp = qc.new_experiment('IV vs power dependence', sample_name='IV vs PD_5.398_10mT')

#do1d(param_set, start, stop, num_points, delay, *param_meas)

dataid = do2d(SGS.power,-20, 25, 101, 1, appl_current,-1e-6 ,1e-6, 101, 0.05, meas_voltage_K2)
# dataid = do1d(appl_current, 6e-6 , -6e-6, 251, 0.01, meas_voltage_K1)
# ivvi.set_dacs_zero()

SGS.off()
plot_by_id(dataid)
sleep(10)


SGS.power(-20)
SGS.frequency(8.167e9)
SGS.on()
keithley_2.averaging_count(5)
keithley_2.averaging_enabled(True)
keithley_24.output(1)

magnet_x.field(10e-3)
sleep(5)
appl_current(-1e-6)
#appl_TG(-30)
sleep(2)

# station.snapshot(update=True);
exp = qc.new_experiment('IV vs power dependence', sample_name='IV vs PD_8.167_10mT')

#do1d(param_set, start, stop, num_points, delay, *param_meas)

dataid = do2d(SGS.power,-20, 25, 101, 1, appl_current,-1e-6 ,1e-6, 101, 0.05, meas_voltage_K2)
# dataid = do1d(appl_current, 6e-6 , -6e-6, 251, 0.01, meas_voltage_K1)
# ivvi.set_dacs_zero()


SGS.off()
plot_by_id(dataid)
sleep(10)

SGS.power(-20)
SGS.frequency(4.303e9)
SGS.on()
keithley_2.averaging_count(5)
keithley_2.averaging_enabled(True)
keithley_24.output(1)

magnet_x.field(10e-3)
sleep(5)
appl_current(-1e-6)
#appl_TG(-30)
sleep(2)

# station.snapshot(update=True);
exp = qc.new_experiment('IV vs power dependence', sample_name='IV vs PD_4.303_10mT')

#do1d(param_set, start, stop, num_points, delay, *param_meas)

dataid = do2d(SGS.power,-20, 25, 101, 1, appl_current,-1e-6 ,1e-6, 101, 0.01, meas_voltage_K2)
# dataid = do1d(appl_current, 6e-6 , -6e-6, 251, 0.01, meas_voltage_K1)
# ivvi.set_dacs_zero()


SGS.off()
sleep(10)

appl_current(0)
keithley_24.output()
plot_by_id(dataid)

# print(get_R_from_IV(dataid))
print(get_R_from_IV_2(dataid))

# %% [markdown]
# # AC

# %% [markdown]
# ## IV vs Vgate

# %%
appl_current(0)
appl_TG(0)
magnet_y.field(0)
sleep(10)
magnet_x.field(0)
sleep(10)
appl_voltage_AC(0.004)
SGS.off()

# %%
SGS.off()
SGS.power(25)
SGS.frequency(4.83e9)
SGS.on()
keithley_2.averaging_count(5)
keithley_2.averaging_enabled(True)
appl_current(-0.4e-7)
appl_current_AC(0.1e-10)

appl_TG(-10)
sleep(1)

# station.snapshot(update=True);
exp = qc.new_experiment('IV vs Vgate', sample_name='IV vs Vg')

dataid = do2d(appl_TG, -10, 10, 751, 0.5, appl_current, -0.4e-7, 0.4e-7, 101, 0.01, meas_voltage_AC_L1, meas_voltage_AC_L1_P, meas_voltage_K2)
# dataid = do1d(appl_current, 6e-6 , -6e-6, 251, 0.01, meas_voltage_K1)
# ivvi.set_dacs_zero()
SGS.off()
appl_current(0)
plot_by_id(dataid)
# print(get_R_from_IV(dataid))
#print(get_R_from_IV_2(dataid))

# %%
appl_current(0)
appl_TG(0)
magnet_y.field(0)
sleep(10)
magnet_x.field(0)
sleep(10)
appl_voltage_AC(0.004)
SGS.off()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Constants
k = 8.617333262145e-5  # Boltzmann constant in eV/K
E_a = 0.5  # Example value for the activation energy in eV
p_0 = 1.0  # Example value for p0

# Create an array of temperatures from 100 to 1000 K
temperatures = np.linspace(100, 1000, 50)

# Calculate 1/T
inverse_temperatures = 1 / temperatures

# Calculate ln(p)
ln_p = np.log(p_0) - (E_a / k) * inverse_temperatures

# Plotting
plt.figure(figsize=(8, 6))
plt.plot(inverse_temperatures, ln_p, marker='o', linestyle='-')
plt.xlabel('1/T (1/K)')
plt.ylabel('ln(p)')
plt.title('ln(p) vs 1/T for Hole Concentration')
plt.grid(True)
plt.show()
