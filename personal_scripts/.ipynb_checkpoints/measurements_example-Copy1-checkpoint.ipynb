# %% [markdown]
# # Initialization

# %% [markdown]
# ## Import of useful modules:

# %%
# %matplotlib inline
import os, sys
import matplotlib.pyplot as plt
import numpy as np
from pprint import pprint
from tqdm.notebook import tqdm

from time import sleep, monotonic, time


import qcodes as qc
from qcodes import Parameter
from qcodes.dataset.plotting import plot_dataset, plot_by_id
from qcodes.utils.metadata import diff_param_values
from qcodes.instrument.specialized_parameters import ElapsedTimeParameter
from qcodes.dataset.measurements import Measurement

# sys.path.append('M:\\tnw\\ns\\qt\\2D Topo\\code\\qcodes')
sys.path.append('C:\\qcodes')
from sweeps import do1d, do2d, time_sweep, measure_until, do1d_until

import warnings
warnings.filterwarnings('ignore')

# %%
fridge_name = 'BF1'
# %run ..\..\..\..\..\code\qcodes\init_fridge.py {fridge_name}
# %run ..\init_fridge.py {fridge_name}
# Out:
# Connected to: KEITHLEY INSTRUMENTS DMM6500 (serial:04518052, firmware:1.7.7b) in 0.41s
# Connected to: KEITHLEY INSTRUMENTS DMM6500 (serial:04518181, firmware:1.7.7b) in 0.02s
# ---------------------------------------------------------------------------
# VisaIOError                               Traceback (most recent call last)
# File C:\qcodes\init_fridge.py:31
#      29     exec(open('../../../../../code/fridge_specific/init_CF1400.py').read())
#      30 elif fridge_name == 'BF1':
# ---> 31     exec(open('../fridge_specific/init_BF1.py').read())
#      32 else:
#      33     print('Wrong fridge name!')
#
# File <string>:22
#
# File ~\.conda\envs\qcodes\lib\site-packages\qcodes\instrument\base.py:559, in InstrumentMeta.__call__(cls, *args, **kwargs)
#     554 def __call__(cls, *args: Any, **kwargs: Any) -> Any:
#     555     """
#     556     Overloads `type.__call__` to add code that runs only if __init__ completes
#     557     successfully.
#     558     """
# --> 559     new_inst = super().__call__(*args, **kwargs)
#     560     is_abstract = new_inst._is_abstract()
#     561     if is_abstract:
#
# File ~\.conda\envs\qcodes\lib\site-packages\qcodes\instrument_drivers\stanford_research\SR860.py:9, in SR860.__init__(self, name, address, reset, **kwargs)
#       8 def __init__(self, name: str, address: str, reset: bool=False, **kwargs: str) ->None:
# ----> 9     super().__init__(name, address, max_frequency=500e3, reset=reset, **kwargs)
#
# File ~\.conda\envs\qcodes\lib\site-packages\qcodes\instrument_drivers\stanford_research\SR86x.py:966, in SR86x.__init__(self, name, address, max_frequency, reset, **kwargs)
#     963 self.add_function('disable_front_panel', call_cmd='OVRM 0')
#     964 self.add_function('enable_front_panel', call_cmd='OVRM 1')
# --> 966 buffer = SR86xBuffer(self, f"{self.name}_buffer")
#     967 self.add_submodule("buffer", buffer)
#     969 self.input_config()
#
# File ~\.conda\envs\qcodes\lib\site-packages\qcodes\instrument_drivers\stanford_research\SR86x.py:120, in SR86xBuffer.__init__(self, parent, name)
#     104 self.add_parameter(
#     105     "capture_rate_max",
#     106     label="capture rate maximum",
#     107     get_cmd="CAPTURERATEMAX?",
#     108     get_parser=float
#     109 )
#     111 self.add_parameter(
#     112     "capture_rate",
#     113     label="capture rate raw",
#    (...)
#     117     set_parser=self._set_capture_rate_parser
#     118 )
# --> 120 max_rate = self.capture_rate_max()
#     121 self.available_frequencies = [max_rate / 2 ** i for i in range(20)]
#     123 self.add_parameter(  # Are we capturing at the moment?
#     124     "capture_status",
#     125     label="capture status",
#     126     get_cmd="CAPTURESTAT?"
#     127 )
#
# File ~\.conda\envs\qcodes\lib\site-packages\qcodes\instrument\parameter.py:456, in _BaseParameter.__call__(self, *args, **kwargs)
#     454 if len(args) == 0 and len(kwargs) == 0:
#     455     if self.gettable:
# --> 456         return self.get()
#     457     else:
#     458         raise NotImplementedError('no get cmd found in' +
#     459                                   f' Parameter {self.name}')
#
# File ~\.conda\envs\qcodes\lib\site-packages\qcodes\instrument\parameter.py:661, in _BaseParameter._wrap_get.<locals>.get_wrapper(*args, **kwargs)
#     659 except Exception as e:
#     660     e.args = e.args + (f'getting {self}',)
# --> 661     raise e
#
# File ~\.conda\envs\qcodes\lib\site-packages\qcodes\instrument\parameter.py:648, in _BaseParameter._wrap_get.<locals>.get_wrapper(*args, **kwargs)
#     643     raise NotImplementedError(
#     644         f"Trying to get an abstract parameter: {self.full_name}"
#     645     )
#     646 try:
#     647     # There might be cases where a .get also has args/kwargs
# --> 648     raw_value = get_function(*args, **kwargs)
#     650     value = self._from_raw_value_to_value(raw_value)
#     652     if self._validate_on_get:
#
# File ~\.conda\envs\qcodes\lib\site-packages\qcodes\utils\command.py:203, in Command.__call__(self, *args)
#     201 if len(args) != self.arg_count:
#     202     raise TypeError(f"command takes exactly {self.arg_count} args")
# --> 203 return self.exec_function(*args)
#
# File ~\.conda\envs\qcodes\lib\site-packages\qcodes\utils\command.py:151, in Command.call_by_str(self, *args)
#     149 def call_by_str(self, *args: Any) -> Output:
#     150     """Execute a formatted string."""
# --> 151     return self.exec_str(self.cmd_str.format(*args))
#
# File ~\.conda\envs\qcodes\lib\site-packages\qcodes\instrument\channel.py:77, in InstrumentModule.ask(self, cmd)
#      76 def ask(self, cmd: str) -> str:
# ---> 77     return self._parent.ask(cmd)
#
# File ~\.conda\envs\qcodes\lib\site-packages\qcodes\instrument\base.py:961, in Instrument.ask(self, cmd)
#     959 inst = repr(self)
#     960 e.args = e.args + ('asking ' + repr(cmd) + ' to ' + inst,)
# --> 961 raise e
#
# File ~\.conda\envs\qcodes\lib\site-packages\qcodes\instrument\base.py:954, in Instrument.ask(self, cmd)
#     936 """
#     937 Write a command string to the hardware and return a response.
#     938
#    (...)
#     951         including the command and the instrument.
#     952 """
#     953 try:
# --> 954     answer = self.ask_raw(cmd)
#     956     return answer
#     958 except Exception as e:
#
# File ~\.conda\envs\qcodes\lib\site-packages\qcodes\instrument\visa.py:227, in VisaInstrument.ask_raw(self, cmd)
#     225 with DelayedKeyboardInterrupt():
#     226     self.visa_log.debug(f"Querying: {cmd}")
# --> 227     response = self.visa_handle.query(cmd)
#     228     self.visa_log.debug(f"Response: {response}")
#     229 return response
#
# File ~\.conda\envs\qcodes\lib\site-packages\pyvisa\resources\messagebased.py:644, in MessageBasedResource.query(self, message, delay)
#     641 if delay > 0.0:
#     642     time.sleep(delay)
# --> 644 return self.read()
#
# File ~\.conda\envs\qcodes\lib\site-packages\pyvisa\resources\messagebased.py:486, in MessageBasedResource.read(self, termination, encoding)
#     484 if termination is None:
#     485     termination = self._read_termination
# --> 486     message = self._read_raw().decode(enco)
#     487 else:
#     488     with self.read_termination_context(termination):
#
# File ~\.conda\envs\qcodes\lib\site-packages\pyvisa\resources\messagebased.py:442, in MessageBasedResource._read_raw(self, size)
#     435     while status == loop_status:
#     436         logger.debug(
#     437             "%s - reading %d bytes (last status %r)",
#     438             self._resource_name,
#     439             size,
#     440             status,
#     441         )
# --> 442         chunk, status = self.visalib.read(self.session, size)
#     443         ret.extend(chunk)
#     444 except errors.VisaIOError as e:
#
# File ~\.conda\envs\qcodes\lib\site-packages\pyvisa\ctwrapper\functions.py:2337, in read(library, session, count)
#    2335 buffer = create_string_buffer(count)
#    2336 return_count = ViUInt32()
# -> 2337 ret = library.viRead(session, buffer, count, byref(return_count))
#    2338 return buffer.raw[: return_count.value], ret
#
# File ~\.conda\envs\qcodes\lib\site-packages\pyvisa\ctwrapper\highlevel.py:222, in IVIVisaLibrary._return_handler(self, ret_value, func, arguments)
#     219         # Set session back to a safe value
#     220         session = None
# --> 222 return self.handle_return_value(session, ret_value)
#
# File ~\.conda\envs\qcodes\lib\site-packages\pyvisa\highlevel.py:251, in VisaLibraryBase.handle_return_value(self, session, status_code)
#     248     self._last_status_in_session[session] = rv
#     250 if rv < 0:
# --> 251     raise errors.VisaIOError(rv)
#     253 if rv in self.issue_warning_on:
#     254     if session and rv not in self._ignore_warning_in_session[session]:
#
# VisaIOError: ('VI_ERROR_TMO (-1073807339): Timeout expired before operation completed.', "asking 'CAPTURERATEMAX?' to <SR860: lockin_2>", 'getting lockin_2_lockin_2_buffer_capture_rate_max')

# %%
snapshot_of_station = station.snapshot()
pprint(snapshot_of_station)
# Out:
# {'components': {},
#  'config': None,
#  'instruments': {'k213': {'__class__': 'Kei213_2.K213',
#                           'address': 'GPIB0::9::INSTR',
#                           'functions': {},
#                           'name': 'k213',
#                           'parameters': {'IDN': {'__class__': 'qcodes.instrument.parameter.Parameter',
#                                                  'full_name': 'k213_IDN',
#                                                  'instrument': 'Kei213_2.K213',
#                                                  'instrument_name': 'k213',
#                                                  'inter_delay': 0,
#                                                  'label': 'IDN',
#                                                  'name': 'IDN',
#                                                  'post_delay': 0,
#                                                  'raw_value': {'firmware': None,
#                                                                'model': None,
#                                                                'serial': None,
#                                                                'vendor': 'A1C0P1R0V+00.00000'},
#                                                  'ts': '2022-11-16 17:06:57',
#                                                  'unit': '',
#                                                  'vals': '<Anything>',
#                                                  'value': {'firmware': None,
#                                                            'model': None,
#                                                            'serial': None,
#                                                            'vendor': 'A1C0P1R0V+00.00000'}},
#                                          'autorange1': {'__class__': 'qcodes.instrument.parameter.Parameter',
#                                                         'full_name': 'k213_autorange1',
#                                                         'instrument': 'Kei213_2.K213',
#                                                         'instrument_name': 'k213',
#                                                         'inter_delay': 0,
#                                                         'label': 'Autorange1',
#                                                         'name': 'autorange1',
#                                                         'post_delay': 0,
#                                                         'raw_value': 0,
#                                                         'ts': '2022-11-17 '
#                                                               '14:03:57',
#                                                         'unit': '',
#                                                         'vals': '<Numbers '
#                                                                 '0<=v<=1>',
#                                                         'value': 0},
#                                          'autorange2': {'__class__': 'qcodes.instrument.parameter.Parameter',
#                                                         'full_name': 'k213_autorange2',
#                                                         'instrument': 'Kei213_2.K213',
#                                                         'instrument_name': 'k213',
#                                                         'inter_delay': 0,
#                                                         'label': 'Autorange1',
#                                                         'name': 'autorange2',
#                                                         'post_delay': 0,
#                                                         'raw_value': 'A1\r',
#                                                         'ts': '2022-11-16 '
#                                                               '17:06:57',
#                                                         'unit': '',
#                                                         'vals': '<Numbers '
#                                                                 '0<=v<=1>',
#                                                         'value': 'A1\r'},
#                                          'autorange3': {'__class__': 'qcodes.instrument.parameter.Parameter',
#                                                         'full_name': 'k213_autorange3',
#                                                         'instrument': 'Kei213_2.K213',
#                                                         'instrument_name': 'k213',
#                                                         'inter_delay': 0,
#                                                         'label': 'Autorange3',
#                                                         'name': 'autorange3',
#                                                         'post_delay': 0,
#                                                         'raw_value': 'A1\r',
#                                                         'ts': '2022-11-16 '
#                                                               '17:06:57',
#                                                         'unit': '',
#                                                         'vals': '<Numbers '
#                                                                 '0<=v<=1>',
#                                                         'value': 'A1\r'},
#                                          'autorange4': {'__class__': 'qcodes.instrument.parameter.Parameter',
#                                                         'full_name': 'k213_autorange4',
#                                                         'instrument': 'Kei213_2.K213',
#                                                         'instrument_name': 'k213',
#                                                         'inter_delay': 0,
#                                                         'label': 'Autorange4',
#                                                         'name': 'autorange4',
#                                                         'post_delay': 0,
#                                                         'raw_value': 'A1\r',
#                                                         'ts': '2022-11-16 '
#                                                               '17:06:58',
#                                                         'unit': '',
#                                                         'vals': '<Numbers '
#                                                                 '0<=v<=1>',
#                                                         'value': 'A1\r'},
#                                          'timeout': {'__class__': 'qcodes.instrument.parameter.Parameter',
#                                                      'full_name': 'k213_timeout',
#                                                      'instrument': 'Kei213_2.K213',
#                                                      'instrument_name': 'k213',
#                                                      'inter_delay': 0,
#                                                      'label': 'timeout',
#                                                      'name': 'timeout',
#                                                      'post_delay': 0,
#                                                      'raw_value': 10.0,
#                                                      'ts': '2022-11-16 '
#                                                            '17:06:58',
#                                                      'unit': 's',
#                                                      'vals': '<MultiType: '
#                                                              'Numbers v>=0, '
#                                                              'Enum: {None}>',
#                                                      'value': 10.0},
#                                          'voltage1': {'__class__': 'qcodes.instrument.parameter.Parameter',
#                                                       'full_name': 'k213_voltage1',
#                                                       'instrument': 'Kei213_2.K213',
#                                                       'instrument_name': 'k213',
#                                                       'inter_delay': 0,
#                                                       'label': 'Voltage1',
#                                                       'name': 'voltage1',
#                                                       'post_delay': 0,
#                                                       'raw_value': 0.0049499999999999995,
#                                                       'ts': '2022-11-17 '
#                                                             '14:04:24',
#                                                       'unit': 'V',
#                                                       'vals': '<Numbers '
#                                                               '-10<=v<=10>',
#                                                       'value': 0.0049499999999999995},
#                                          'voltage2': {'__class__': 'qcodes.instrument.parameter.Parameter',
#                                                       'full_name': 'k213_voltage2',
#                                                       'instrument': 'Kei213_2.K213',
#                                                       'instrument_name': 'k213',
#                                                       'inter_delay': 0,
#                                                       'label': 'Voltage2',
#                                                       'name': 'voltage2',
#                                                       'post_delay': 0,
#                                                       'raw_value': 'V+00.00000\r',
#                                                       'ts': '2022-11-16 '
#                                                             '17:06:57',
#                                                       'unit': 'V',
#                                                       'vals': '<Numbers '
#                                                               '-10<=v<=10>',
#                                                       'value': 'V+00.00000\r'},
#                                          'voltage3': {'__class__': 'qcodes.instrument.parameter.Parameter',
#                                                       'full_name': 'k213_voltage3',
#                                                       'instrument': 'Kei213_2.K213',
#                                                       'instrument_name': 'k213',
#                                                       'inter_delay': 0,
#                                                       'label': 'Voltage3',
#                                                       'name': 'voltage3',
#                                                       'post_delay': 0,
#                                                       'raw_value': 'V+00.00000\r',
#                                                       'ts': '2022-11-16 '
#                                                             '17:06:57',
#                                                       'unit': 'V',
#                                                       'vals': '<Numbers '
#                                                               '-10<=v<=10>',
#                                                       'value': 'V+00.00000\r'},
#                                          'voltage4': {'__class__': 'qcodes.instrument.parameter.Parameter',
#                                                       'full_name': 'k213_voltage4',
#                                                       'instrument': 'Kei213_2.K213',
#                                                       'instrument_name': 'k213',
#                                                       'inter_delay': 0,
#                                                       'label': 'Voltage4',
#                                                       'name': 'voltage4',
#                                                       'post_delay': 0,
#                                                       'raw_value': 'V+00.00000\r',
#                                                       'ts': '2022-11-16 '
#                                                             '17:06:58',
#                                                       'unit': 'V',
#                                                       'vals': '<Numbers '
#                                                               '-10<=v<=10>',
#                                                       'value': 'V+00.00000\r'},
#                                          'vrange1': {'__class__': 'qcodes.instrument.parameter.Parameter',
#                                                      'full_name': 'k213_vrange1',
#                                                      'instrument': 'Kei213_2.K213',
#                                                      'instrument_name': 'k213',
#                                                      'inter_delay': 0,
#                                                      'label': 'VRange1',
#                                                      'name': 'vrange1',
#                                                      'post_delay': 0,
#                                                      'raw_value': 3,
#                                                      'ts': '2022-11-17 '
#                                                            '14:04:17',
#                                                      'unit': 'V',
#                                                      'vals': '<Numbers '
#                                                              '0<=v<=3>',
#                                                      'value': 3},
#                                          'vrange2': {'__class__': 'qcodes.instrument.parameter.Parameter',
#                                                      'full_name': 'k213_vrange2',
#                                                      'instrument': 'Kei213_2.K213',
#                                                      'instrument_name': 'k213',
#                                                      'inter_delay': 0,
#                                                      'label': 'VRange2',
#                                                      'name': 'vrange2',
#                                                      'post_delay': 0,
#                                                      'raw_value': 'R0\r',
#                                                      'ts': '2022-11-16 '
#                                                            '17:06:57',
#                                                      'unit': 'V',
#                                                      'vals': '<Numbers '
#                                                              '0<=v<=3>',
#                                                      'value': 'R0\r'},
#                                          'vrange3': {'__class__': 'qcodes.instrument.parameter.Parameter',
#                                                      'full_name': 'k213_vrange3',
#                                                      'instrument': 'Kei213_2.K213',
#                                                      'instrument_name': 'k213',
#                                                      'inter_delay': 0,
#                                                      'label': 'VRange3',
#                                                      'name': 'vrange3',
#                                                      'post_delay': 0,
#                                                      'raw_value': 'R0\r',
#                                                      'ts': '2022-11-16 '
#                                                            '17:06:57',
#                                                      'unit': 'V',
#                                                      'vals': '<Numbers '
#                                                              '0<=v<=3>',
#                                                      'value': 'R0\r'},
#                                          'vrange4': {'__class__': 'qcodes.instrument.parameter.Parameter',
#                                                      'full_name': 'k213_vrange4',
#                                                      'instrument': 'Kei213_2.K213',
#                                                      'instrument_name': 'k213',
#                                                      'inter_delay': 0,
#                                                      'label': 'VRange4',
#                                                      'name': 'vrange4',
#                                                      'post_delay': 0,
#                                                      'raw_value': 'R0\r',
#                                                      'ts': '2022-11-16 '
#                                                            '17:06:58',
#                                                      'unit': 'V',
#                                                      'vals': '<Numbers '
#                                                              '0<=v<=3>',
#                                                      'value': 'R0\r'}},
#                           'read_terminator': '\n',
#                           'submodules': {},
#                           'terminator': '\n',
#                           'timeout': 10.0,
#                           'write_terminator': '\n'},
#                  'keithley_1': {'__class__': 'qcodes.instrument_drivers.tektronix.Keithley_6500.Keithley_6500',
#                                 'address': 'GPIB0::6::INSTR',
#                                 'functions': {},
#                                 'name': 'keithley_1',
#                                 'parameters': {'IDN': {'__class__': 'qcodes.instrument.parameter.Parameter',
#                                                        'full_name': 'keithley_1_IDN',
#                                                        'instrument': 'qcodes.instrument_drivers.tektronix.Keithley_6500.Keithley_6500',
#                                                        'instrument_name': 'keithley_1',
#                                                        'inter_delay': 0,
#                                                        'label': 'IDN',
#                                                        'name': 'IDN',
#                                                        'post_delay': 0,
#                                                        'raw_value': {'firmware': '1.7.7b',
#                                                                      'model': 'DMM6500',
#                                                                      'serial': '04518052',
#                                                                      'vendor': 'KEITHLEY '
#                                                                                'INSTRUMENTS'},
#                                                        'ts': '2022-11-16 '
#                                                              '17:06:57',
#                                                        'unit': '',
#                                                        'vals': '<Anything>',
#                                                        'value': {'firmware': '1.7.7b',
#                                                                  'model': 'DMM6500',
#                                                                  'serial': '04518052',
#                                                                  'vendor': 'KEITHLEY '
#                                                                            'INSTRUMENTS'}},
#                                                'amplitude': {'__class__': 'qcodes.instrument.parameter.Parameter',
#                                                              'full_name': 'keithley_1_amplitude',
#                                                              'instrument': 'qcodes.instrument_drivers.tektronix.Keithley_6500.Keithley_6500',
#                                                              'instrument_name': 'keithley_1',
#                                                              'inter_delay': 0,
#                                                              'label': 'amplitude',
#                                                              'name': 'amplitude',
#                                                              'post_delay': 0,
#                                                              'raw_value': 1.729427e-05,
#                                                              'ts': '2022-11-17 '
#                                                                    '14:04:24',
#                                                              'unit': 'a.u.',
#                                                              'value': 1.729427e-05},
#                                                'auto_range_enabled': {'__class__': 'qcodes.instrument.parameter.Parameter',
#                                                                       'full_name': 'keithley_1_auto_range_enabled',
#                                                                       'instrument': 'qcodes.instrument_drivers.tektronix.Keithley_6500.Keithley_6500',
#                                                                       'instrument_name': 'keithley_1',
#                                                                       'inter_delay': 0,
#                                                                       'label': 'auto_range_enabled',
#                                                                       'name': 'auto_range_enabled',
#                                                                       'post_delay': 0,
#                                                                       'raw_value': True,
#                                                                       'ts': '2022-11-16 '
#                                                                             '17:06:57',
#                                                                       'unit': '',
#                                                                       'vals': '<Boolean>',
#                                                                       'value': True},
#                                                'averaging_count': {'__class__': 'qcodes.instrument.parameter.Parameter',
#                                                                    'full_name': 'keithley_1_averaging_count',
#                                                                    'instrument': 'qcodes.instrument_drivers.tektronix.Keithley_6500.Keithley_6500',
#                                                                    'instrument_name': 'keithley_1',
#                                                                    'inter_delay': 0,
#                                                                    'label': 'averaging_count',
#                                                                    'name': 'averaging_count',
#                                                                    'post_delay': 0,
#                                                                    'raw_value': 10,
#                                                                    'ts': '2022-11-16 '
#                                                                          '17:06:57',
#                                                                    'unit': '',
#                                                                    'vals': '<Ints '
#                                                                            '1<=v<=100>',
#                                                                    'value': 10},
#                                                'averaging_enabled': {'__class__': 'qcodes.instrument.parameter.Parameter',
#                                                                      'full_name': 'keithley_1_averaging_enabled',
#                                                                      'instrument': 'qcodes.instrument_drivers.tektronix.Keithley_6500.Keithley_6500',
#                                                                      'instrument_name': 'keithley_1',
#                                                                      'inter_delay': 0,
#                                                                      'label': 'averaging_enabled',
#                                                                      'name': 'averaging_enabled',
#                                                                      'post_delay': 0,
#                                                                      'raw_value': True,
#                                                                      'ts': '2022-11-16 '
#                                                                            '17:06:57',
#                                                                      'unit': '',
#                                                                      'vals': '<Boolean>',
#                                                                      'value': True},
#                                                'averaging_type': {'__class__': 'qcodes.instrument.parameter.Parameter',
#                                                                   'full_name': 'keithley_1_averaging_type',
#                                                                   'instrument': 'qcodes.instrument_drivers.tektronix.Keithley_6500.Keithley_6500',
#                                                                   'instrument_name': 'keithley_1',
#                                                                   'inter_delay': 0,
#                                                                   'label': 'averaging_type',
#                                                                   'name': 'averaging_type',
#                                                                   'post_delay': 0,
#                                                                   'raw_value': 'repeat',
#                                                                   'ts': '2022-11-16 '
#                                                                         '17:06:57',
#                                                                   'unit': '',
#                                                                   'vals': '<Enum: '
#                                                                           "{'repeat', "
#                                                                           "'moving'}>",
#                                                                   'value': 'repeat'},
#                                                'digits': {'__class__': 'qcodes.instrument.parameter.Parameter',
#                                                           'full_name': 'keithley_1_digits',
#                                                           'instrument': 'qcodes.instrument_drivers.tektronix.Keithley_6500.Keithley_6500',
#                                                           'instrument_name': 'keithley_1',
#                                                           'inter_delay': 0,
#                                                           'label': 'digits',
#                                                           'name': 'digits',
#                                                           'post_delay': 0,
#                                                           'raw_value': '6',
#                                                           'ts': '2022-11-16 '
#                                                                 '17:06:57',
#                                                           'unit': '',
#                                                           'vals': '<Ints '
#                                                                   '4<=v<=7>',
#                                                           'value': 6},
#                                                'display_backlight': {'__class__': 'qcodes.instrument.parameter.Parameter',
#                                                                      'full_name': 'keithley_1_display_backlight',
#                                                                      'instrument': 'qcodes.instrument_drivers.tektronix.Keithley_6500.Keithley_6500',
#                                                                      'instrument_name': 'keithley_1',
#                                                                      'inter_delay': 0,
#                                                                      'label': 'display_backlight',
#                                                                      'name': 'display_backlight',
#                                                                      'post_delay': 0,
#                                                                      'raw_value': 'ON50',
#                                                                      'ts': '2022-11-16 '
#                                                                            '17:06:57',
#                                                                      'unit': '',
#                                                                      'val_mapping': {'Blackout': 'BLACkout',
#                                                                                      'Off': 'OFF',
#                                                                                      'On 100': 'ON100',
#                                                                                      'On 25': 'ON25',
#                                                                                      'On 50': 'ON50',
#                                                                                      'On 75': 'ON75'},
#                                                                      'vals': '<Enum: '
#                                                                              "{'On "
#                                                                              "25', "
#                                                                              "'On "
#                                                                              "100', "
#                                                                              "'On "
#                                                                              "50', "
#                                                                              "'Off', "
#                                                                              "'On "
#                                                                              "75', "
#                                                                              "'Blackout'}>",
#                                                                      'value': 'On '
#                                                                               '50'},
#                                                'mode': {'__class__': 'qcodes.instrument.parameter.Parameter',
#                                                         'full_name': 'keithley_1_mode',
#                                                         'instrument': 'qcodes.instrument_drivers.tektronix.Keithley_6500.Keithley_6500',
#                                                         'instrument_name': 'keithley_1',
#                                                         'inter_delay': 0,
#                                                         'label': 'mode',
#                                                         'name': 'mode',
#                                                         'post_delay': 0,
#                                                         'raw_value': 'VOLT:DC',
#                                                         'ts': '2022-11-16 '
#                                                               '17:06:57',
#                                                         'unit': '',
#                                                         'val_mapping': {'2w resistance': 'RES',
#                                                                         '4w resistance': 'FRES',
#                                                                         'ac current': 'CURR:AC',
#                                                                         'ac voltage': 'VOLT:AC',
#                                                                         'dc current': 'CURR:DC',
#                                                                         'dc voltage': 'VOLT:DC',
#                                                                         'frequency': 'FREQ',
#                                                                         'temperature': 'TEMP'},
#                                                         'vals': "<Enum: {'ac "
#                                                                 "voltage', 'dc "
#                                                                 "current', '4w "
#                                                                 "resistance', "
#                                                                 "'frequency', "
#                                                                 "'2w "
#                                                                 "resistance', "
#                                                                 "'ac current', "
#                                                                 "'temperature', "
#                                                                 "'dc "
#                                                                 "voltage'}>",
#                                                         'value': 'dc voltage'},
#                                                'nplc': {'__class__': 'qcodes.instrument.parameter.Parameter',
#                                                         'full_name': 'keithley_1_nplc',
#                                                         'instrument': 'qcodes.instrument_drivers.tektronix.Keithley_6500.Keithley_6500',
#                                                         'instrument_name': 'keithley_1',
#                                                         'inter_delay': 0,
#                                                         'label': 'nplc',
#                                                         'name': 'nplc',
#                                                         'post_delay': 0,
#                                                         'raw_value': 1.0,
#                                                         'ts': '2022-11-16 '
#                                                               '17:06:57',
#                                                         'unit': '',
#                                                         'vals': '<Numbers '
#                                                                 '0.01<=v<=10>',
#                                                         'value': 1.0},
#                                                'range': {'__class__': 'qcodes.instrument.parameter.Parameter',
#                                                          'full_name': 'keithley_1_range',
#                                                          'instrument': 'qcodes.instrument_drivers.tektronix.Keithley_6500.Keithley_6500',
#                                                          'instrument_name': 'keithley_1',
#                                                          'inter_delay': 0,
#                                                          'label': 'range',
#                                                          'name': 'range',
#                                                          'post_delay': 0,
#                                                          'raw_value': 0.1,
#                                                          'ts': '2022-11-16 '
#                                                                '17:06:57',
#                                                          'unit': '',
#                                                          'vals': '<Numbers>',
#                                                          'value': 0.1},
#                                                'timeout': {'__class__': 'qcodes.instrument.parameter.Parameter',
#                                                            'full_name': 'keithley_1_timeout',
#                                                            'instrument': 'qcodes.instrument_drivers.tektronix.Keithley_6500.Keithley_6500',
#                                                            'instrument_name': 'keithley_1',
#                                                            'inter_delay': 0,
#                                                            'label': 'timeout',
#                                                            'name': 'timeout',
#                                                            'post_delay': 0,
#                                                            'raw_value': 10.0,
#                                                            'ts': '2022-11-16 '
#                                                                  '17:06:57',
#                                                            'unit': 's',
#                                                            'vals': '<MultiType: '
#                                                                    'Numbers '
#                                                                    'v>=0, '
#                                                                    'Enum: '
#                                                                    '{None}>',
#                                                            'value': 10.0},
#                                                'trigger1_delay': {'__class__': 'qcodes.instrument.parameter.Parameter',
#                                                                   'full_name': 'keithley_1_trigger1_delay',
#                                                                   'instrument': 'qcodes.instrument_drivers.tektronix.Keithley_6500.Keithley_6500',
#                                                                   'instrument_name': 'keithley_1',
#                                                                   'inter_delay': 0,
#                                                                   'label': 'trigger1_delay',
#                                                                   'name': 'trigger1_delay',
#                                                                   'post_delay': 0,
#                                                                   'raw_value': '1E-05',
#                                                                   'ts': '2022-11-16 '
#                                                                         '17:06:57',
#                                                                   'unit': 's',
#                                                                   'vals': '<Numbers '
#                                                                           '0<=v<=999999.999>',
#                                                                   'value': 1e-05},
#                                                'trigger1_source': {'__class__': 'qcodes.instrument.parameter.Parameter',
#                                                                    'full_name': 'keithley_1_trigger1_source',
#                                                                    'instrument': 'qcodes.instrument_drivers.tektronix.Keithley_6500.Keithley_6500',
#                                                                    'instrument_name': 'keithley_1',
#                                                                    'inter_delay': 0,
#                                                                    'label': 'trigger1_source',
#                                                                    'name': 'trigger1_source',
#                                                                    'post_delay': 0,
#                                                                    'raw_value': 'NONE',
#                                                                    'ts': '2022-11-16 '
#                                                                          '17:06:57',
#                                                                    'unit': '',
#                                                                    'val_mapping': {'bus': 'COMM',
#                                                                                    'external': 'EXT',
#                                                                                    'front-panel': 'DISP',
#                                                                                    'immediate': 'NONE',
#                                                                                    'notify1': 'NOT1',
#                                                                                    'notify2': 'NOT2',
#                                                                                    'notify3': 'NOT3',
#                                                                                    'timer1': 'TIM1',
#                                                                                    'timer2': 'TIM2',
#                                                                                    'timer3': 'TIM3',
#                                                                                    'timer4': 'TIM4'},
#                                                                    'vals': '<Enum: '
#                                                                            "{'timer1', "
#                                                                            "'external', "
#                                                                            "'notify2', "
#                                                                            "'timer4', "
#                                                                            "'notify1', "
#                                                                            "'front-panel', "
#                                                                            "'immediate', "
#                                                                            "'notify3', "
#                                                                            "'bus', "
#                                                                            "'timer3', "
#                                                                            "'timer2'}>",
#                                                                    'value': 'immediate'},
#                                                'trigger2_delay': {'__class__': 'qcodes.instrument.parameter.Parameter',
#                                                                   'full_name': 'keithley_1_trigger2_delay',
#                                                                   'instrument': 'qcodes.instrument_drivers.tektronix.Keithley_6500.Keithley_6500',
#                                                                   'instrument_name': 'keithley_1',
#                                                                   'inter_delay': 0,
#                                                                   'label': 'trigger2_delay',
#                                                                   'name': 'trigger2_delay',
#                                                                   'post_delay': 0,
#                                                                   'raw_value': '1E-05',
#                                                                   'ts': '2022-11-16 '
#                                                                         '17:06:57',
#                                                                   'unit': 's',
#                                                                   'vals': '<Numbers '
#                                                                           '0<=v<=999999.999>',
#                                                                   'value': 1e-05},
#                                                'trigger2_source': {'__class__': 'qcodes.instrument.parameter.Parameter',
#                                                                    'full_name': 'keithley_1_trigger2_source',
#                                                                    'instrument': 'qcodes.instrument_drivers.tektronix.Keithley_6500.Keithley_6500',
#                                                                    'instrument_name': 'keithley_1',
#                                                                    'inter_delay': 0,
#                                                                    'label': 'trigger2_source',
#                                                                    'name': 'trigger2_source',
#                                                                    'post_delay': 0,
#                                                                    'raw_value': 'NONE',
#                                                                    'ts': '2022-11-16 '
#                                                                          '17:06:57',
#                                                                    'unit': '',
#                                                                    'val_mapping': {'bus': 'COMM',
#                                                                                    'external': 'EXT',
#                                                                                    'front-panel': 'DISP',
#                                                                                    'immediate': 'NONE',
#                                                                                    'notify1': 'NOT1',
#                                                                                    'notify2': 'NOT2',
#                                                                                    'notify3': 'NOT3',
#                                                                                    'timer1': 'TIM1',
#                                                                                    'timer2': 'TIM2',
#                                                                                    'timer3': 'TIM3',
#                                                                                    'timer4': 'TIM4'},
#                                                                    'vals': '<Enum: '
#                                                                            "{'timer1', "
#                                                                            "'external', "
#                                                                            "'notify2', "
#                                                                            "'timer4', "
#                                                                            "'notify1', "
#                                                                            "'front-panel', "
#                                                                            "'immediate', "
#                                                                            "'notify3', "
#                                                                            "'bus', "
#                                                                            "'timer3', "
#                                                                            "'timer2'}>",
#                                                                    'value': 'immediate'},
#                                                'trigger3_delay': {'__class__': 'qcodes.instrument.parameter.Parameter',
#                                                                   'full_name': 'keithley_1_trigger3_delay',
#                                                                   'instrument': 'qcodes.instrument_drivers.tektronix.Keithley_6500.Keithley_6500',
#                                                                   'instrument_name': 'keithley_1',
#                                                                   'inter_delay': 0,
#                                                                   'label': 'trigger3_delay',
#                                                                   'name': 'trigger3_delay',
#                                                                   'post_delay': 0,
#                                                                   'raw_value': '1E-05',
#                                                                   'ts': '2022-11-16 '
#                                                                         '17:06:57',
# ...
#                                                                    'raw_value': 'NONE',
#                                                                    'ts': '2022-11-16 '
#                                                                          '17:06:57',
#                                                                    'unit': '',
#                                                                    'val_mapping': {'bus': 'COMM',
#                                                                                    'external': 'EXT',
#                                                                                    'front-panel': 'DISP',
#                                                                                    'immediate': 'NONE',
#                                                                                    'notify1': 'NOT1',
#                                                                                    'notify2': 'NOT2',
#                                                                                    'notify3': 'NOT3',
#                                                                                    'timer1': 'TIM1',
#                                                                                    'timer2': 'TIM2',
#                                                                                    'timer3': 'TIM3',
#                                                                                    'timer4': 'TIM4'},
#                                                                    'vals': '<Enum: '
#                                                                            "{'timer1', "
#                                                                            "'external', "
#                                                                            "'notify2', "
#                                                                            "'timer4', "
#                                                                            "'notify1', "
#                                                                            "'front-panel', "
#                                                                            "'immediate', "
#                                                                            "'notify3', "
#                                                                            "'bus', "
#                                                                            "'timer3', "
#                                                                            "'timer2'}>",
#                                                                    'value': 'immediate'},
#                                                'trigger3_delay': {'__class__': 'qcodes.instrument.parameter.Parameter',
#                                                                   'full_name': 'keithley_2_trigger3_delay',
#                                                                   'instrument': 'qcodes.instrument_drivers.tektronix.Keithley_6500.Keithley_6500',
#                                                                   'instrument_name': 'keithley_2',
#                                                                   'inter_delay': 0,
#                                                                   'label': 'trigger3_delay',
#                                                                   'name': 'trigger3_delay',
#                                                                   'post_delay': 0,
#                                                                   'raw_value': '1E-05',
#                                                                   'ts': '2022-11-16 '
#                                                                         '17:06:57',
#                                                                   'unit': 's',
#                                                                   'vals': '<Numbers '
#                                                                           '0<=v<=999999.999>',
#                                                                   'value': 1e-05},
#                                                'trigger3_source': {'__class__': 'qcodes.instrument.parameter.Parameter',
#                                                                    'full_name': 'keithley_2_trigger3_source',
#                                                                    'instrument': 'qcodes.instrument_drivers.tektronix.Keithley_6500.Keithley_6500',
#                                                                    'instrument_name': 'keithley_2',
#                                                                    'inter_delay': 0,
#                                                                    'label': 'trigger3_source',
#                                                                    'name': 'trigger3_source',
#                                                                    'post_delay': 0,
#                                                                    'raw_value': 'NONE',
#                                                                    'ts': '2022-11-16 '
#                                                                          '17:06:57',
#                                                                    'unit': '',
#                                                                    'val_mapping': {'bus': 'COMM',
#                                                                                    'external': 'EXT',
#                                                                                    'front-panel': 'DISP',
#                                                                                    'immediate': 'NONE',
#                                                                                    'notify1': 'NOT1',
#                                                                                    'notify2': 'NOT2',
#                                                                                    'notify3': 'NOT3',
#                                                                                    'timer1': 'TIM1',
#                                                                                    'timer2': 'TIM2',
#                                                                                    'timer3': 'TIM3',
#                                                                                    'timer4': 'TIM4'},
#                                                                    'vals': '<Enum: '
#                                                                            "{'timer1', "
#                                                                            "'external', "
#                                                                            "'notify2', "
#                                                                            "'timer4', "
#                                                                            "'notify1', "
#                                                                            "'front-panel', "
#                                                                            "'immediate', "
#                                                                            "'notify3', "
#                                                                            "'bus', "
#                                                                            "'timer3', "
#                                                                            "'timer2'}>",
#                                                                    'value': 'immediate'},
#                                                'trigger4_delay': {'__class__': 'qcodes.instrument.parameter.Parameter',
#                                                                   'full_name': 'keithley_2_trigger4_delay',
#                                                                   'instrument': 'qcodes.instrument_drivers.tektronix.Keithley_6500.Keithley_6500',
#                                                                   'instrument_name': 'keithley_2',
#                                                                   'inter_delay': 0,
#                                                                   'label': 'trigger4_delay',
#                                                                   'name': 'trigger4_delay',
#                                                                   'post_delay': 0,
#                                                                   'raw_value': '1E-05',
#                                                                   'ts': '2022-11-16 '
#                                                                         '17:06:57',
#                                                                   'unit': 's',
#                                                                   'vals': '<Numbers '
#                                                                           '0<=v<=999999.999>',
#                                                                   'value': 1e-05},
#                                                'trigger4_source': {'__class__': 'qcodes.instrument.parameter.Parameter',
#                                                                    'full_name': 'keithley_2_trigger4_source',
#                                                                    'instrument': 'qcodes.instrument_drivers.tektronix.Keithley_6500.Keithley_6500',
#                                                                    'instrument_name': 'keithley_2',
#                                                                    'inter_delay': 0,
#                                                                    'label': 'trigger4_source',
#                                                                    'name': 'trigger4_source',
#                                                                    'post_delay': 0,
#                                                                    'raw_value': 'NONE',
#                                                                    'ts': '2022-11-16 '
#                                                                          '17:06:57',
#                                                                    'unit': '',
#                                                                    'val_mapping': {'bus': 'COMM',
#                                                                                    'external': 'EXT',
#                                                                                    'front-panel': 'DISP',
#                                                                                    'immediate': 'NONE',
#                                                                                    'notify1': 'NOT1',
#                                                                                    'notify2': 'NOT2',
#                                                                                    'notify3': 'NOT3',
#                                                                                    'timer1': 'TIM1',
#                                                                                    'timer2': 'TIM2',
#                                                                                    'timer3': 'TIM3',
#                                                                                    'timer4': 'TIM4'},
#                                                                    'vals': '<Enum: '
#                                                                            "{'timer1', "
#                                                                            "'external', "
#                                                                            "'notify2', "
#                                                                            "'timer4', "
#                                                                            "'notify1', "
#                                                                            "'front-panel', "
#                                                                            "'immediate', "
#                                                                            "'notify3', "
#                                                                            "'bus', "
#                                                                            "'timer3', "
#                                                                            "'timer2'}>",
#                                                                    'value': 'immediate'},
#                                                'trigger_count': {'__class__': 'qcodes.instrument.parameter.Parameter',
#                                                                  'full_name': 'keithley_2_trigger_count',
#                                                                  'instrument': 'qcodes.instrument_drivers.tektronix.Keithley_6500.Keithley_6500',
#                                                                  'instrument_name': 'keithley_2',
#                                                                  'inter_delay': 0,
#                                                                  'label': 'trigger_count',
#                                                                  'name': 'trigger_count',
#                                                                  'post_delay': 0,
#                                                                  'raw_value': '1',
#                                                                  'ts': '2022-11-16 '
#                                                                        '17:06:57',
#                                                                  'unit': '',
#                                                                  'vals': '<MultiType: '
#                                                                          'Ints '
#                                                                          '1<=v<=9999, '
#                                                                          'Enum: '
#                                                                          "{'maximum', "
#                                                                          "'inf', "
#                                                                          "'default', "
#                                                                          "'minimum'}>",
#                                                                  'value': 1},
#                                                'trigger_timer': {'__class__': 'qcodes.instrument.parameter.Parameter',
#                                                                  'full_name': 'keithley_2_trigger_timer',
#                                                                  'instrument': 'qcodes.instrument_drivers.tektronix.Keithley_6500.Keithley_6500',
#                                                                  'instrument_name': 'keithley_2',
#                                                                  'inter_delay': 0,
#                                                                  'label': 'trigger_timer',
#                                                                  'name': 'trigger_timer',
#                                                                  'post_delay': 0,
#                                                                  'raw_value': '0',
#                                                                  'ts': '2022-11-16 '
#                                                                        '17:06:57',
#                                                                  'unit': 's',
#                                                                  'vals': '<Numbers '
#                                                                          '0<=v<=999999.999>',
#                                                                  'value': 0.0}},
#                                 'read_terminator': '\n',
#                                 'submodules': {},
#                                 'terminator': '\n',
#                                 'timeout': 10.0,
#                                 'write_terminator': '\n'}},
#  'parameters': {}}

# %% [markdown]
# ## Linear K213 DC Voltage to Keithley6500 Measurement Test

# %%
K213_V1 = []
keithley_R0_V1 = []
keithley_R1_V1 = []
keithley_R2_V1 = []
keithley_R3_V1 = []
N=100
Max_V=.005


K213.autorange1(0)
K213.voltage1(0)

K213.vrange1(0)
for i in range(-N,N,1):
    v = Max_V*i/N
    K213_V1.append(v)
    K213.voltage1(v)
    keithley_R0_V1.append(keithley_1.amplitude())
    
K213.vrange1(1)
for i in range(-N,N,1):
    v = Max_V*i/N
    K213.voltage1(v)
    keithley_R1_V1.append(keithley_1.amplitude())
    
K213.vrange1(2)
for i in range(-N,N,1):
    v = Max_V*i/N    
    K213.voltage1(v)
    keithley_R2_V1.append(keithley_1.amplitude())
    
K213.vrange1(3)
for i in range(-N,N,1):
    v = Max_V*i/N
    K213.voltage1(v)
    keithley_R3_V1.append(keithley_1.amplitude())
        
plt.plot(K213_V1, keithley_R0_V1, label = 'range=0V') 
plt.plot(K213_V1, keithley_R1_V1, label = 'range=1V') 
plt.plot(K213_V1, keithley_R2_V1, label = 'range=5V')
plt.plot(K213_V1, keithley_R3_V1, label = 'range=10V')

plt.title('maximum voltage = ' + str(Max_V))
plt.xlabel('K213 channel 1 supply voltage')
plt.ylabel('keithley 1 measured voltage')
plt.legend()
plt.show()

# %% [markdown]
# ## Constant K213 DC Voltage to Keithley6500 Measurement Test

# %%
K213_V1 = []
keithley_R0_V1 = []
keithley_R1_V1 = []
keithley_R2_V1 = []
keithley_R3_V1 = []
N=5000
v=0.01

K213.autorange1(0)
K213.voltage1(v)

K213.vrange1(0)
for i in range(0,2*N,1):
    K213_V1.append(i)
    keithley_R0_V1.append(keithley_1.amplitude())
    
K213.vrange1(1)
for i in range(0,2*N,1):
    keithley_R1_V1.append(keithley_1.amplitude())
    
K213.vrange1(2)
for i in range(0,2*N,1):    
    keithley_R2_V1.append(keithley_1.amplitude())
    
K213.vrange1(3)
for i in range(0,2*N,1):
    keithley_R3_V1.append(keithley_1.amplitude())
        
plt.plot(K213_V1, keithley_R0_V1, label = 'range=0V') 
plt.plot(K213_V1, keithley_R1_V1, label = 'range=1V') 
plt.plot(K213_V1, keithley_R2_V1, label = 'range=5V')
plt.plot(K213_V1, keithley_R3_V1, label = 'range=10V')

plt.title('apply voltage = ' + str(v) + 'V')
plt.xlabel('time')
plt.ylabel('keithley 1 measured voltage')
# plt.ylim([9.05e-5,9.20e-5])
plt.legend()
plt.show()

# %%
#Distribution Plotting

print('mean_R1 = %s' %np.mean(keithley_R1_V1))
print('max_R1 = %s' %np.max(keithley_R1_V1))
print('min_R1 = %s' %np.min(keithley_R1_V1))

plt.hist(keithley_R1_V1, 200, color = 'C1', label = 'range=1V')
plt.legend()
plt.show()
# Out:
# mean_R1 = 9.1763070869e-05
# max_R1 = 9.23039e-05
# min_R1 = 9.119462e-05

# %% [markdown]
# ## Data Saving (float list to .txt)

# %%
txt = 'K213_V1' #Enter the name of a new .txt file 

with open(r'D:/data/Test/111722_DC/%s.txt' % txt, 'w') as f:
    for value in K213_V1: #Enter the name of the list you want to save as .txt
        f.write('%s, ' % value)
    print('finished')
# Out:
# finished

# %%
x = []

with open(r'D:/data/Test/test.txt', 'r') as f:
    lines = f.readlines()
    s = lines[0].split(', ')
    for i in range(len(s)-1):
        x.append(float(s[i]))
print(x)
# Out:
# [9.201177e-05, 9.176282e-05, 9.18603e-05, 9.190379e-05, 9.173133e-05, 9.18753e-05, 9.169834e-05, 9.159186e-05, 9.195628e-05, 9.195778e-05, 9.170733e-05, 9.168334e-05, 9.165635e-05, 9.192179e-05, 9.188879e-05, 9.213338e-05, 9.191592e-05, 9.168348e-05, 9.192342e-05, 9.189943e-05, 9.181695e-05, 9.20269e-05, 9.189343e-05, 9.179895e-05, 9.168947e-05, 9.173296e-05, 9.176146e-05, 9.173296e-05, 9.172097e-05, 9.194442e-05, 9.169697e-05, 9.167748e-05, 9.1583e-05, 9.177346e-05, 9.186794e-05, 9.186943e-05, 9.198341e-05, 9.158e-05, 9.176596e-05, 9.196691e-05, 9.191442e-05, 9.174496e-05, 9.169547e-05, 9.185894e-05, 9.177196e-05, 9.179445e-05, 9.186943e-05, 9.207939e-05, 9.193092e-05, 9.186194e-05, 9.173596e-05, 9.190843e-05, 9.171047e-05, 9.173146e-05, 9.180345e-05, 9.179273e-05, 9.199068e-05, 9.210616e-05, 9.19142e-05, 9.171624e-05, 9.200718e-05, 9.182122e-05, 9.149429e-05, 9.197119e-05, 9.163526e-05, 9.19052e-05, 9.195919e-05, 9.197719e-05, 9.185871e-05, 9.196069e-05, 9.19067e-05, 9.177323e-05, 9.179423e-05, 9.187221e-05, 9.171174e-05, 9.203267e-05, 9.183622e-05, 9.175973e-05, 9.213615e-05, 9.162026e-05, 9.173274e-05, 9.205817e-05, 9.177473e-05, 9.197569e-05, 9.163676e-05, 9.175823e-05, 9.180772e-05, 9.196069e-05, 9.174624e-05, 9.153778e-05, 9.177773e-05, 9.164126e-05, 9.165326e-05, 9.19172e-05, 9.163226e-05, 9.199488e-05, 9.165596e-05, 9.200238e-05, 9.169945e-05, 9.164696e-05, 9.189141e-05, 9.167095e-05, 9.19349e-05, 9.209836e-05, 9.183292e-05, 9.188841e-05, 9.182092e-05, 9.198139e-05, 9.199188e-05, 9.199638e-05, 9.188541e-05, 9.209236e-05, 9.212385e-05, 9.188841e-05, 9.201138e-05, 9.175044e-05, 9.19214e-05, 9.201138e-05, 9.19109e-05, 9.221533e-05, 9.173094e-05, 9.186591e-05, 9.204287e-05, 9.220034e-05, 9.163496e-05, 9.207137e-05, 9.179093e-05, 9.200538e-05, 9.19304e-05, 9.175793e-05, 9.177443e-05, 9.180292e-05, 9.188991e-05, 9.188541e-05, 9.181942e-05, 9.174571e-05, 9.203514e-05, 9.208163e-05, 9.194216e-05, 9.17847e-05, 9.179669e-05, 9.180719e-05, 9.17517e-05, 9.191817e-05, 9.196316e-05, 9.190767e-05, 9.187168e-05, 9.194066e-05, 9.174871e-05, 9.185518e-05, 9.229759e-05, 9.17937e-05, 9.187468e-05, 9.195866e-05, 9.207563e-05, 9.17907e-05, 9.184618e-05, 9.200215e-05, 9.205014e-05, 9.181469e-05, 9.193916e-05, 9.167672e-05, 9.200815e-05, 9.181619e-05, 9.186268e-05, 9.199165e-05, 9.170521e-05, 9.196616e-05, 9.183719e-05, 9.161823e-05, 9.193316e-05, 9.167072e-05, 9.170821e-05, 9.17922e-05, 9.170521e-05, 9.198301e-05, 9.213748e-05, 9.162759e-05, 9.208049e-05, 9.207899e-05, 9.2025e-05, 9.182405e-05, 9.182105e-05, 9.179705e-05, 9.155111e-05, 9.193502e-05, 9.183305e-05, 9.161109e-05, 9.204e-05, 9.155561e-05, 9.194552e-05, 9.179405e-05, 9.16051e-05, 9.189753e-05, 9.181055e-05, 9.167408e-05, 9.187054e-05, 9.173407e-05, 9.185404e-05, 9.197701e-05, 9.161709e-05, 9.191253e-05, 9.172507e-05, 9.184054e-05, 9.162609e-05, 9.204e-05, 9.195152e-05, 9.179405e-05, 9.187804e-05, 9.161109e-05, 9.172957e-05, 9.174606e-05, 9.182705e-05, 9.193652e-05, 9.175356e-05, 9.161221e-05, 9.171418e-05, 9.190914e-05, 9.177867e-05, 9.175767e-05, 9.181616e-05, 9.195113e-05, 9.180416e-05, 9.191664e-05, 9.194513e-05, 9.170219e-05, 9.20816e-05, 9.187315e-05, 9.196013e-05, 9.171418e-05, 9.169919e-05, 9.204561e-05, 9.184615e-05, 9.160921e-05, 9.197213e-05, 9.20786e-05, 9.197213e-05, 9.201262e-05, 9.201412e-05, 9.16572e-05, 9.191964e-05, 9.180116e-05, 9.185665e-05, 9.180416e-05, 9.16407e-05, 9.175767e-05, 9.173518e-05, 9.189864e-05, 9.154622e-05, 9.187165e-05, 9.194213e-05, 9.193913e-05, 9.20756e-05, 9.186415e-05, 9.196763e-05, 9.185179e-05, 9.182479e-05, 9.175131e-05, 9.17708e-05, 9.192827e-05, 9.17888e-05, 9.17993e-05, 9.170032e-05, 9.187878e-05, 9.167782e-05, 9.187428e-05, 9.170182e-05, 9.200775e-05, 9.159234e-05, 9.197476e-05, 9.17753e-05, 9.195976e-05, 9.181729e-05, 9.183229e-05, 9.168082e-05, 9.183079e-05, 9.17738e-05, 9.204074e-05, 9.182179e-05, 9.171981e-05, 9.189678e-05, 9.206624e-05, 9.183829e-05, 9.198676e-05, 9.199126e-05, 9.186228e-05, 9.193277e-05, 9.17918e-05, 9.208574 ...

# %%
SR860_f=[]
SR860_R=[]
SR860_X=[]
N=100
f_max=100

for i in range(1,N,1):
    f = f_max*i/N
    lockin_2.frequency(f)
    SR860_f.append(f)
    SR860_R.append(lockin_2.R())
    SR860_X.append(lockin_2.X())
    
    if i%10==0:
        print(i)

plt.plot(SR860_f, SR860_R, label='R')
plt.plot(SR860_f, SR860_X, label='X')

plt.legend()
plt.show()

# %% [markdown]
# ## DAC rates

# %%
ivvi.dac1.step = 50
ivvi.dac1.inter_delay = 0.05
ivvi.dac2.step = 50
ivvi.dac2.inter_delay = 0.05
ivvi.dac3.step = 1
ivvi.dac3.inter_delay = 0.2

# %% [markdown]
# ## Database initialisation

# %% [markdown]
# Next, we create a qcodes database. If you want to use an existing one, set reuse 'True'. Database is created in the "data" folder. Sample folder is the same as for this script

# %%
reuse = True
# %run ..\..\..\..\..\code\qcodes\init_database.py {reuse}

# %% [markdown]
# # Scaled parameters

# %% [markdown]
# It is more convenient to use meaningful parameters with correct units

# %%
from qcodes import ManualParameter, ScaledParameter

# %% [markdown]
# ## Defining scaled parameters

# %%
Irange = Parameter('Irange', label='current range', unit='', set_cmd=None, get_cmd=None)
Vrange = Parameter('Vrange', label='voltage range', unit='', set_cmd=None, get_cmd=None)
TGrange = Parameter('TGrange', label='Top gate range', unit='', set_cmd=None, get_cmd=None)

#division paraemtrs required for simplier update: they used as an argument for scaled paraemtrs of sorce instruments

Irange_division = Parameter('Irange_division', 
                            label='scaled current range', unit='', 
                            set_cmd=None, get_cmd=lambda : 1000 / Irange())

Vrange_division = Parameter('Vrange_division', 
                            label='scaled voltage range', unit='', 
                            set_cmd=None, get_cmd=lambda : 1000 / Vrange())

TGrange_division = Parameter('TGrange_division', 
                             label='scaled Top gate range', unit='', 
                             set_cmd=None, get_cmd=lambda : 1000 / TGrange())

Irange_AC_division = Parameter('Irange_AC_division', 
                               label='scaled current range for lockin', unit='', 
                               set_cmd=None, get_cmd=lambda : 100 / Irange())

Vrange_AC_division = Parameter('Vrange_AC_division', 
                               label='scaled voltage range for lockin', unit='', 
                               set_cmd=None, get_cmd=lambda : 100 / Vrange())

Gain_K1 = Parameter('Gain_K1', label='Gain K1', unit='', set_cmd=None, get_cmd=None)
Gain_K2 = Parameter('Gain_K2', label='Gain K2', unit='', set_cmd=None, get_cmd=None)
Gain_L1 = Parameter('Gain_L1', label='Gain L1', unit='', set_cmd=None, get_cmd=None)
Gain_L2 = Parameter('Gain_L2', label='Gain L2', unit='', set_cmd=None, get_cmd=None)

#Add components
station.add_component(Irange)
station.add_component(Vrange)
station.add_component(TGrange)

station.add_component(Irange_division)
station.add_component(Vrange_division)
station.add_component(TGrange_division)

station.add_component(Irange_AC_division)
station.add_component(Vrange_AC_division)
                             
station.add_component(Gain_K1)
station.add_component(Gain_K2)
station.add_component(Gain_L1)
station.add_component(Gain_L2)

# %% [markdown]
# ## IVVI rack parameters - update here during measuerements

# %%
Irange.set(100e-6)
Vrange.set(10e-3)
TGrange.set(15)
Gain_K1.set(1e6)
Gain_K2.set(1e6)
# Gain_K3.set(1e2)
Gain_L1.set(Gain_K1())
Gain_L2.set(Gain_K2())
#division parameters are updated automatically

# %% [markdown]
# ## DC parameters
# Check that devicies are correct!

# %%
# appl_current = ScaledParameter(ivvi.dac1, division = Irange_division, name = 'appl_current', unit = 'A')
appl_current = ScaledParameter(K213.voltage, division = Irange_division, name = 'appl_current', unit = 'A')
appl_voltage = ScaledParameter(ivvi.dac2, division = Vrange_division, name = 'appl_voltage', unit = 'V')
appl_TG = ScaledParameter(ivvi.dac3, division = TGrange_division, name = 'appl_TG', unit = 'V')

meas_voltage_K1 = ScaledParameter(keithley_1.amplitude, division = Gain_K1, name = 'meas_voltage_K1', unit = 'V')
meas_voltage_K2 = ScaledParameter(keithley_2.amplitude, division = Gain_K2, name = 'meas_voltage_K2', unit = 'V')

meas_leakage = ScaledParameter(keithley_2.amplitude, division = Gain_K2, name = 'meas_leakage', unit = 'A')

meas_current_K1 = ScaledParameter(keithley_1.amplitude, division = Gain_K1, name = 'meas_current_K1', unit = 'A')
meas_current_K2 = ScaledParameter(keithley_2.amplitude, division = Gain_K2, name = 'meas_current_K2', unit = 'A')

station.add_component(appl_current)
station.add_component(appl_voltage)
station.add_component(appl_TG)
station.add_component(meas_voltage_K1)
station.add_component(meas_voltage_K2)
station.add_component(meas_leakage)
station.add_component(meas_current_K1)
station.add_component(meas_current_K2)

# %% [markdown]
# ## AC parameters

# %%
appl_current_AC = ScaledParameter(lockin_1.amplitude, 
                                  division = Irange_AC_division, name = 'appl_current_AC', unit = 'A')

appl_voltage_AC = ScaledParameter(lockin_1.amplitude, 
                                  division = Vrange_AC_division, name = 'appl_voltage_AC', unit = 'V')

station.add_component(appl_current_AC)
station.add_component(appl_voltage_AC)

meas_voltage_AC_L1 = ScaledParameter(lockin_1.X, division = Gain_L1, name = 'meas_voltage_Lockin1', unit = 'V')
meas_current_AC_L1 = ScaledParameter(lockin_1.X, division = Gain_L1, name = 'meas_current_Lockin1', unit = 'A')

meas_voltage_AC_L2 = ScaledParameter(lockin_2.X, division = Gain_L2, name = 'meas_voltage_Lockin2', unit = 'V')
meas_current_AC_L2 = ScaledParameter(lockin_2.X, division = Gain_L2, name = 'meas_current_Lockin2', unit = 'A')

station.add_component(meas_voltage_AC_L1)
station.add_component(meas_current_AC_L1)

station.add_component(meas_voltage_AC_L2)
station.add_component(meas_current_AC_L2)

meas_voltage_AC_L1_R = ScaledParameter(lockin_1.R, division = Gain_L1, name = 'meas_voltage_R_Lockin1', unit = 'V')
meas_voltage_AC_L2_R = ScaledParameter(lockin_2.R, division = Gain_L2, name = 'meas_voltage_R_Lockin2', unit = 'V')

station.add_component(meas_voltage_AC_L1_R)
station.add_component(meas_voltage_AC_L2_R)

# %% [markdown]
# ## Another useful example: magnet using dac (Janis)

# %% [markdown]
# >2231.2 G per A => 0.22312 T per A<br>
# I source 10mA per V => 1e-5 A per 1mV<br>
# result: 0.22312 T/A * 1e-5 A/mV

# %%
#check Janis and VectorJanis!
#magnetic_field = ScaledParameter(ivvi.dac3, gain = 0.22312e-5, name = 'magnetic_field_dac', unit = 'T')
#station.add_component(magnetic_field)

# %%
def get_R_from_IV(dataid):
    dataset = qc.load_by_id(dataid)

    voltage = dataset.get_parameter_data()['meas_voltage_K1']['meas_voltage_K1']
    current = dataset.get_parameter_data()['meas_voltage_K1']['appl_current']
    fit_values = np.polyfit(current,voltage,1)
    
    return fit_values[0]

def get_R_from_IV_2(dataid):
    dataset = qc.load_by_id(dataid)

    voltage = dataset.get_parameter_data()['meas_voltage_K2']['meas_voltage_K2']
    current = dataset.get_parameter_data()['meas_voltage_K2']['appl_current']
    fit_values = np.polyfit(current,voltage,1)
    
    return fit_values[0]

# %% [markdown]
# # Fridge

# %%
monitor = qc.Monitor(level_meter.lastval, 
                         lakeshore.A.temperature, lakeshore.B.temperature, lakeshore.C.temperature,
                         cryomag.channel_A.field,
                         cryomag.channel_B.field,
                         appl_TG,
                         appl_current)

# %%
monitor.show()

# %%
monitor.stop()

# %%
ivvi.set_dacs_zero()
lockin_1.amplitude(0.004)

# %%
# lakeshore.output_1.output_range('off')
# lakeshore.output_1.setpoint(50.0)
# lakeshore.output_1.input_channel('A')
# lakeshore.output_1.output_range('2.5W')

# %%
print('Temps: A= {:.2f}, B = {:.4f}, C ={:.4f}'.format(lakeshore.A.temperature(), lakeshore.B.temperature(), lakeshore.C.temperature()) )

# %%
level_meter.print_readable_snapshot(update=True)

# %%
level_meter.lastval()

# %%
# level_meter.sample_mode('Continuous')
level_meter.sample_mode('Sample/Hold')

# %%
while True:
    print('A= {:.2f}, B = {:.4f}, C ={:.4f}, power = {:.2f}'.format(lakeshore.A.temperature(), lakeshore.B.temperature(), lakeshore.C.temperature(), lakeshore.output_1.output()), end = '\r')
    sleep(1)

# %%
while True:
    print('He Level = {:.2f}'.format(level_meter.lastval()), end = '\r')
    sleep(1)

# %%
cryomag.print_readable_snapshot(update = True)

# %%
cryomag.channel_A.heater('off')
cryomag.channel_B.heater('off')

# %%
cryomag.channel_A.write('SWEEP ZERO')

# %%
cryomag.channel_A.field()

# %%
cryomag.channel_A.tolerance()

# %%
# lakeshore.output_1.output_range('2.5W')
# # cryomag.channel_B.field(6)

# time = ElapsedTimeParameter('time')

# def time_limit(time, measured_values):
#     return time() > 60 * 60 * 1

# exp = qc.new_experiment('Condensing', sample_name='Janis')
# time.reset_clock()
# dataid = measure_until(time, time_limit, 10, 
#                        lakeshore.A.temperature, lakeshore.B.temperature,
#                        lakeshore.C.temperature, lakeshore.output_1.output)

# lakeshore.output_1.output_range('off')

# def time_limit(time, measured_values):
#     return time() > 60 * 60 * 1

# exp = qc.new_experiment('Cool down', sample_name='Janis')
# time.reset_clock()
# dataid = measure_until(time, time_limit, 10, 
#                        lakeshore.A.temperature, lakeshore.B.temperature,
#                        lakeshore.C.temperature, lakeshore.output_1.output)

# %%
# appl_TG()

# %% [markdown]
# # Yokko for magnet

# %%
#check Janis and VectorJanis!
field_to_current_ratio =  0.14912 # T per A, 1491.2 gauss/amp

# %%
# yoko.source_mode('CURR')
# yoko.current(0)
yoko.output('off')

# %%
yoko.current_limit() * field_to_current_ratio *1e3 #maximum field in mT

# %%
yoko.voltage_limit(1) #no more than 1V on magnet!

# %%
yoko.current_range()* field_to_current_ratio *1e3 #maximum field for current range in mT (can be incresed up to current limit)

# %%
#used in function ramp_yoko
ramp_rate = 0.001 #A/s
time_step = 0.01 #10ms

# %%
#ramps current slowly.

def ramp_yoko(new_val):
    
    old_val = yoko.current()
    ramp_time = np.abs(old_val - new_val) / ramp_rate
    
    n_steps = int(ramp_time / time_step)
    
    if ramp_time < time_step:
        yoko.current(new_val)
        return
    
    for inter_val in np.linspace(old_val, new_val, n_steps + 1):
        yoko.current(inter_val)
        sleep(time_step)
#         print('current = {:.3f} mA'.format(yoko.current()), end = '\r' )

# %%
#gonna always set current in yoko by the ramp function

yoko_slow_current = Parameter('yoko_slow_current', 
                               label='current set by rump function', unit='A', 
                               set_cmd=ramp_yoko, get_cmd=yoko.current)
station.add_component(yoko_slow_current)

# %%
#finally: field in Tesla

magnetic_field_yoko = ScaledParameter(yoko_slow_current, gain = field_to_current_ratio, name = 'magnetic_field_yoko', unit = 'T')
station.add_component(magnetic_field_yoko)

# %% [markdown]
# # Parameter to get R from fast IV

# %%
I_lim_r_IV = 5e-9
N_point_r_IV = 40
delay_r_IV = 0.02

# %%
R_val_2 = None

def get_R_from_IV_1():
    global R_val_2
    I_vals = np.linspace(-I_lim_r_IV, I_lim_r_IV, N_point_r_IV)
    V_vals_1 = np.zeros_like(I_vals)
    V_vals_2 = np.zeros_like(I_vals)
    appl_current.post_delay = delay_r_IV
    
    for i, I_val in enumerate(I_vals):
        appl_current(I_val)
        V_vals_1[i] = meas_voltage_K1()
        V_vals_2[i] = meas_voltage_K2()
        
    fit_values_1 = np.polyfit(I_vals,V_vals_1,1)
    fit_values_2 = np.polyfit(I_vals,V_vals_2,1)
    
    R_val_2 = fit_values_2[0]
    
    return fit_values_1[0]

def get_R_from_IV_2():
    global R_val_2
    if R_val_2:
        last_val = R_val_2
        R_val_2 = None
    else:
        get_R_from_IV_1()
        last_val = R_val_2
        R_val_2 = None
    
    return last_val

# %%
import time
start_time = time.time()
get_R_from_IV_1()
print("--- %s seconds ---" % (time.time() - start_time))

# %%
r_from_IV_1 = Parameter('r_from_IV_1', 
                       label='resistance from fast IV K1 fit', unit='Ohm', 
                       set_cmd=None, get_cmd=get_R_from_IV_1)

r_from_IV_2 = Parameter('r_from_IV_2', 
                       label='resistance from fast IV K2 fit', unit='Ohm', 
                       set_cmd=None, get_cmd=get_R_from_IV_2)

# %% [markdown]
# # Fridge measurements

# %%
time = ElapsedTimeParameter('time')

def He_limit(time, measured_values):
    return measured_values[0].get() > 31

# %%
time = ElapsedTimeParameter('time')

def temp_limit(time, measured_values):
    return measured_values[2].get() < 0.31

# %%
exp = qc.new_experiment('cool_down_to_base_vs_time', sample_name='fridge VJ')
time.reset_clock()
dataid = measure_until(time, temp_limit, 3, lakeshore.A.temperature, lakeshore.B.temperature, lakeshore.C.temperature)

# %%
plot_by_id(3)

# %%
time = ElapsedTimeParameter('time')

def time_limit_3_days(time, measured_values):
    return time() > 60 * 60 * 24 * 3

# %%
exp = qc.new_experiment('fridge at base', sample_name='fridge VJ')
time.reset_clock()
dataid = measure_until(time, time_limit_3_days, 60 * 5, 
                       lakeshore.A.temperature, lakeshore.B.temperature, lakeshore.C.temperature, 
                       level_meter.lastval )

# %% [markdown]
# # Simple IVs

# %%
# cryomag.channel_B.field(0)
# magnetic_field_yoko(-1.07e-3)
# magnetic_field_yoko(0)

# %%
appl_TG(0.35)

# %%
# appl_TG(0.7)
# sleep(10)
appl_current(-0.5e-6)
sleep(1)
station.snapshot(update=True);
exp = qc.new_experiment('IV', sample_name='JJ1_JJ1(K1)_JJ2(K2)')
dataid = do1d(appl_current, -0.5e-6, 0.5e-6, 1001, 0.02, meas_voltage_K1, meas_voltage_K2)
# ivvi.set_dacs_zero()
appl_current(0)
plot_by_id(dataid)
# print(get_R_from_IV(dataid))
# print(get_R_from_IV_2(dataid))

# %%
print(get_R_from_IV(dataid))
print(get_R_from_IV_2(dataid))

# %%
appl_current_AC(10e-9)
appl_current(-1e-6)
sleep(10)
station.snapshot(update=True);
exp = qc.new_experiment('IV + AC', sample_name='TL1_fL_finger')
dataid = do1d(appl_current, -1e-6, 1e-6, 501, 3, 
              meas_voltage_K1, meas_voltage_AC_L1, lockin_1.P, 
              meas_voltage_K2, meas_voltage_AC_L2, lockin_2.P)
# plot_by_id(dataid)
ivvi.set_dacs_zero()
lockin_1.amplitude(0.004)

# %% [markdown]
# # Zero Everything

# %%
ivvi.set_dacs_zero()
lockin_1.amplitude(0.004)
# ivvi.print_readable_snapshot(update=True)

# %% [markdown]
# # Gate simple sweeps

# %%
exp = qc.new_experiment('I_vs_Vtg', sample_name='BL1')

appl_voltage(1e-3)

start_gate = 0.0
stop_gate = 0.45
num_points = 500
leak_threshold = 1e-9

#Register independent parameters
meas = Measurement()
meas.register_parameter(appl_TG)
appl_TG.post_delay = 0.05

#Register dependent parametrs
param_meas = [meas_current_K1, meas_leakage]
output = []
for parameter in param_meas:
    meas.register_parameter(parameter, setpoints=(appl_TG,))
    output.append([parameter, None])

#Add action at the end
meas.add_after_run(ivvi.set_dacs_zero, ())

appl_TG(start_gate)
sleep(2)

#Start measuremnts
with meas.run() as datasaver:
    for set_point in tqdm(np.linspace(start_gate, stop_gate, num_points)):
        appl_TG(set_point)
        sleep(0.05)
        if np.abs(meas_leakage()) > leak_threshold:
            print('Leakage detected!')
            break
        sleep(0.05)
        for i, parameter in enumerate(param_meas):
            output[i][1] = parameter.get()
        datasaver.add_result((appl_TG, appl_TG()),
                             *output)
dataid = datasaver.run_id  # convenient to have for plotting

# %%
appl_TG(0)

# %%
plot_by_id(dataid)

# %%
appl_voltage(1e-3)
appl_TG(0)
sleep(2)
station.snapshot(update=True);
exp = qc.new_experiment('I_vs_Vgate_up', sample_name='JJ1_JJ5')
dataid1 = do1d(appl_TG, 0, 0.4, 400, 0.1, meas_current_K1)
# plot_by_id(dataid1)

# station.snapshot(update=True);
exp = qc.new_experiment('I_vs_Vgate_down', sample_name='JJ1_JJ5')
dataid2 = do1d(appl_TG, 0.4, 0.0, 400, 0.1, meas_current_K1)
# plot_by_id(dataid2)

ivvi.set_dacs_zero()

# %%
fig, ax = plt.subplots(1)
axes, cbaxes = plot_by_id(dataid1, axes=[ax], label = 'up')
axes, cbaxes = plot_by_id(dataid2, axes=[ax], label = 'down')
plt.legend(fontsize = 14)
plt.savefig('../plots/JJ1_JJ5_hyst1.png')

# %% [markdown]
# # JJ measurement

# %%
appl_TG(0.35)
cryomag.channel_A.field(-5e-3)

# %%
appl_TG(0.35)
cryomag.channel_A.field(-5e-3)
appl_current(-0.5e-6)
sleep(5)

station.snapshot(update=True);

exp = qc.new_experiment('IV vs B', sample_name='JJ1_JJ1(K1)_JJ2(K2)')

dataid = do2d(cryomag.channel_A.field, -5e-3, 5e-3, 201, 2, appl_current, -0.5e-6, 0.5e-6, 501, 0.01, meas_voltage_K1, meas_voltage_K2)

appl_current(0)
cryomag.channel_A.field(0)

plot_by_id(dataid)

# %%
appl_TG(0.35)
cryomag.channel_A.field(-20e-3)
appl_current(-0.5e-6)
sleep(60)

station.snapshot(update=True);

exp = qc.new_experiment('IV vs B larger range', sample_name='JJ1_JJ1(K1)_JJ2(K2)')

dataid = do2d(cryomag.channel_A.field, -20e-3, 20e-3, 401, 4, appl_current, -0.5e-6, 0.5e-6, 501, 0.01, meas_voltage_K1, meas_voltage_K2)

appl_current(0)
cryomag.channel_A.field(0)

plot_by_id(dataid)

# %%
appl_TG(0.35)
cryomag.channel_A.field(-5e-3)
appl_current(-0.5e-6)
sleep(60)

station.snapshot(update=True);

exp = qc.new_experiment('IV vs B small range', sample_name='JJ1_JJ1(K1)_JJ2(K2)')

dataid = do2d(cryomag.channel_A.field, -5e-3, 5e-3, 401, 4, appl_current, -0.5e-6, 0.5e-6, 801, 0.01, meas_voltage_K1, meas_voltage_K2)

appl_current(0)
cryomag.channel_A.field(0)

plot_by_id(dataid)

# %%
cryomag.channel_A.field(-0.3e-3)

# %%
appl_TG(0.2)
appl_current(-0.5e-6)
sleep(60)

station.snapshot(update=True);

exp = qc.new_experiment('IV vs Vg', sample_name='JJ1_JJ1(K1)_JJ2(K2)')

dataid = do2d(appl_TG, 0.2, 0.4, 21, 3, appl_current, -0.5e-6, 0.5e-6, 801, 0.01, meas_voltage_K1, meas_voltage_K2)

appl_current(0)
appl_TG(0.35)

plot_by_id(dataid)

# %% [markdown]
# # JJ measurements for MAR

# %%
cryomag.channel_A.field()

# %%
appl_TG(0.4)

# %%
lockin_1.amplitude(0.004)
appl_current(-20e-6)
sleep(1)
station.snapshot(update=True);

exp = qc.new_experiment('IV', sample_name='JJ1_JJ_1')
dataid = do1d(appl_current, -20e-6, 20e-6, 501, 0.01, meas_voltage_K1)
# ivvi.set_dacs_zero()
appl_current(0)
plot_by_id(dataid)

# %%
#determine lockin sensitivity
R = 500 #Ohms
I_AC = 100e-9
V_real = R * I_AC
V_lockin = R * I_AC * Gain_L1()
print(V_lockin)

# %%
lockin_1.sensitivity(0.01)

# %%
lockin_1.sensitivity.vals

# %%
2000 / 60

# %%
appl_current(-20e-6)
appl_current_AC(100e-9)

# %%
keithley_1.amplitude()

# %%
appl_current_AC(100e-9)
appl_current(-20e-6)
sleep(10)
station.snapshot(update=True);
exp = qc.new_experiment('IV + AC', sample_name='JJ1_JJ_3')
dataid = do1d(appl_current, -20e-6, 20e-6, 2001, 1, meas_voltage_K1, meas_voltage_AC_L1, meas_voltage_AC_L1_R)
# ivvi.set_dacs_zero()
appl_current(0)
lockin_1.amplitude(0.004)
plot_by_id(dataid)

# %%
appl_current(0)
lockin_1.amplitude(0.004)

# %% [markdown]
# # Hall measurements

# %%
appl_gate_1(1)
appl_TG(0.4)

# %%
appl_TG(0.4)

# %%
appl_gate_1(1)
appl_TG(0.4)
appl_current(100e-9)
sleep(30)


station.snapshot(update=True);

exp = qc.new_experiment('Vu_vs_gate_field, Vsplit = 0.4', sample_name='TR1_left_half')

dataid = do2d(cryomag.channel_B.field, 0, 5, 41, 10, appl_gate_1, 1, 1.75, 120, 1, meas_voltage_K1)

appl_current(0)
# appl_TG(0)
# appl_gate_1(0)
plot_by_id(dataid)

# %%
appl_gate_1(1.1)

# %%
appl_gate_1(1.1)
appl_TG(0.4)
appl_current_AC(5e-9)
appl_current(0)
sleep(30)


station.snapshot(update=True);

exp = qc.new_experiment('ACVd_vs_gate B=5T, Vsplit = 0.4', sample_name='TR1_left_half')

dataid = do1d(appl_gate_1, 1.1, 1.75, 120, 3, meas_voltage_AC_L1, meas_voltage_AC_L1_R)
lockin_1.amplitude(0.004)
appl_current(0)
# appl_TG(0)
# appl_gate_1(0)
plot_by_id(dataid)

# %%
appl_gate_1(1.1)
appl_TG(0.4)
lockin_1.amplitude(0.004)
appl_current(0)
sleep(10)


station.snapshot(update=True);

exp = qc.new_experiment('fast_DC_Vd_vs_gate B=5T, Vsplit = 0.4', sample_name='TR1_left_half')

dataid = do1d(appl_gate_1, 1.1, 1.75, 120, 1, r_from_IV_1)
lockin_1.amplitude(0.004)
appl_current(0)
# appl_TG(0)
# appl_gate_1(0)
plot_by_id(dataid)

# %%
lockin_1.amplitude(0.004)

# %%
appl_gate_1(1.1)
appl_TG(0.4)
appl_current_AC(5e-9)
appl_current(0)
sleep(30)


station.snapshot(update=True);

exp = qc.new_experiment('ACVd_vs_gate_vs_B, Vsplit = 0.4', sample_name='TR1_left_half')

dataid = do2d(cryomag.channel_B.field, 5, 4, 11, 5, appl_gate_1, 1.1, 1.75, 120, 3, meas_voltage_AC_L1, meas_voltage_AC_L1_R)
lockin_1.amplitude(0.004)
appl_current(0)
# appl_TG(0)
# appl_gate_1(0)
plot_by_id(dataid)

# %%
14e3 * 300e-9 *1e3

# %%
lockin_1.amplitude(0.004)
appl_gate_1(1.1)
appl_TG(0.4)

for B_field in [3,4,5,6]:
    appl_gate_1(1.1)
    cryomag.channel_B.field(B_field)
    appl_current(-300e-9)
    sleep(60)
    
    station.snapshot(update=True);

    exp = qc.new_experiment('Vd_vs_I_gate, Vsplit = 0.4, B={}'.format(B_field), sample_name='TR1_left_half')

    dataid = do2d( appl_gate_1, 1.1, 1.75, 120, 3, appl_current, -300e-9, 300e-9, 1201, 0.05, meas_voltage_K1)
    
    plot_by_id(dataid)

# %%
#Extra experiment at B=3.5
lockin_1.amplitude(0.004)
appl_gate_1(1.1)
appl_TG(0.4)

for B_field in [3.5]:
    appl_gate_1(1.1)
    cryomag.channel_B.field(B_field)
    appl_current(-300e-9)
    sleep(60)
    
    station.snapshot(update=True);

    exp = qc.new_experiment('Vd_vs_I_gate, Vsplit = 0.4, B={}'.format(B_field), sample_name='TR1_left_half')

    dataid = do2d( appl_gate_1, 1.1, 1.75, 120, 3, appl_current, -300e-9, 300e-9, 1201, 0.05, meas_voltage_K1)
    
    plot_by_id(dataid)

# %%
# Pinch off measurement

lockin_1.amplitude(0.004)
appl_gate_1(1.1)
appl_TG(0.4)

for B_field in [3,4,5,6]:
    appl_gate_1(1.1)
    cryomag.channel_B.field(B_field)
    appl_current(-300e-9)
    sleep(60)
    
    station.snapshot(update=True);

    exp = qc.new_experiment('Vd_vs_I_gate, Vsplit = 0.4, B={}'.format(B_field), sample_name='TR1_left_half')

    dataid = do2d( appl_gate_1, 1.1, 1.75, 120, 3, appl_current, -300e-9, 300e-9, 1201, 0.05, meas_voltage_K1)
    
    plot_by_id(dataid)

# %%
appl_current(0)

# %% [markdown]
# # Split-gate in QH

# %%
appl_gate_1(1.3) #nu=1 at 6T
appl_TG(0.4) #split-gate
appl_voltage(1e-3)

station.snapshot(update=True);

exp = qc.new_experiment('I,Vd_vs_splitgate, B={}'.format(6), sample_name='TR1_left_half')

dataid = do1d(appl_TG, 0.4, -0.5, 200, 1, meas_voltage_K1, meas_current_K2)

appl_voltage(0)
appl_TG(0)
plot_by_id(dataid)

# %%
appl_voltage_AC(1e-6) #1uV
appl_gate_1(1.3) #nu=1 at 6T
appl_TG(0.4) #split-gate
appl_voltage(0)

station.snapshot(update=True);

exp = qc.new_experiment('I,Vd_vs_splitgate, B={}'.format(6), sample_name='TR1_left_half')

dataid = do1d(appl_TG, 0.4, -0.1, 120, 3, meas_voltage_AC_L1, meas_current_AC_L2)

lockin_1.amplitude(0.004)
appl_TG(0)
plot_by_id(dataid)

# %%
appl_voltage_AC(1e-6) #1uV
appl_gate_1(1.3) #nu=1 at 6T
appl_TG(0.4) #split-gate
appl_voltage(0)

station.snapshot(update=True);

exp = qc.new_experiment('I,Vd_vs_splitgate, B={}'.format(6), sample_name='TR1_left_half')

dataid = do1d(appl_TG, 0.4, -0.1, 300, 3, meas_voltage_AC_L1, meas_current_AC_L2)

lockin_1.amplitude(0.004)
appl_TG(0)
plot_by_id(dataid)

# %%
appl_voltage_AC(5e-6) #5uV
appl_gate_1(1.3) #nu=1 at 6T
appl_TG(0.4) #split-gate
appl_voltage(0)

station.snapshot(update=True);

exp = qc.new_experiment('I,Vd_vs_splitgate, B={}'.format(6), sample_name='TR1_left_half')

dataid = do1d(appl_TG, 0.4, -0.1, 300, 3, meas_voltage_AC_L1, meas_current_AC_L2)

lockin_1.amplitude(0.004)
appl_TG(0)
plot_by_id(dataid)

# %%
appl_voltage_AC(10e-6) #10uV
appl_gate_1(1.3) #nu=1 at 6T
appl_TG(0.4) #split-gate
appl_voltage(0)

station.snapshot(update=True);

exp = qc.new_experiment('I,Vd_vs_splitgate, B={}'.format(6), sample_name='TR1_left_half')

dataid = do1d(appl_TG, 0.4, -0.1, 300, 3, meas_voltage_AC_L1, meas_current_AC_L2)

lockin_1.amplitude(0.004)
appl_TG(0)
plot_by_id(dataid)

# %%
appl_voltage_AC(5e-6) #5uV
appl_gate_1(1.1)
appl_TG(0.4) #split-gate
appl_voltage(0)

station.snapshot(update=True);

exp = qc.new_experiment('I,Vd_vs_TG,splitgate, B={}'.format(6), sample_name='TR1_left_half')

dataid = do2d(appl_gate_1, 1.1, 1.75, 21, 3, appl_TG, 0.4, -0.1, 300, 3, meas_voltage_AC_L1, meas_current_AC_L2)

lockin_1.amplitude(0.004)
appl_TG(0)
appl_gate_1(1.4)
plot_by_id(dataid)

# %%
lockin_1.amplitude(0.004)
appl_TG(0)
appl_gate_1(1.4)

# %%
temp = lakeshore.C.temperature()
while temp > 0.35:
    print('Waiting for base temp! current temp is {:.2f}K'.format(temp), end = '\r')
    sleep(1)
    temp = lakeshore.C.temperature()

# %%
cryomag.B.field(5)

# %%
for top_gate_val in np.linspace(1.7, 1.2, 6):
    appl_gate_1(top_gate_val)
    appl_TG(0.5) #split-gate
    appl_voltage(-4e-3)
    
    sleep(60)

    station.snapshot(update=True);

    exp = qc.new_experiment('I,Vd_vs_Vbias,splitgate, Vtg={}'.format(top_gate_val), sample_name='TR1_left_half')

    dataid = do2d(appl_TG, 0.5, -0.4, 101, 2, appl_voltage, -4e-3, 4e-3, 1201, 0.01, meas_voltage_K1, meas_current_K2)
    
    appl_voltage(0)
    appl_TG(0)

# %%
appl_voltage(0)
appl_TG(0)

# %% [markdown]
# # JJ at high field

# %%
appl_gate_1(0.4)

# %%
station.snapshot(update=True);
exp = qc.new_experiment('IV B aprox 5T, TG=0.4V', sample_name='TR1_JJ')
dataid = do1d(appl_current, -10e-9, 10e-9, 101, 0.1, meas_voltage_K1)
# ivvi.set_dacs_zero()
appl_current(0)
plot_by_id(dataid)

# %%
temp = lakeshore.C.temperature()
while temp > 0.35:
    print('Waiting for base temp! current temp is {:.2f}K'.format(temp), end = '\r')
    sleep(1)
    temp = lakeshore.C.temperature()

# %%
appl_gate_1(0.3)
appl_current_AC(1e-9)
appl_current(0)
sleep(60)


station.snapshot(update=True);

exp = qc.new_experiment('ACVd_vs_gate B=5T, Vsplit = 0.4', sample_name='TR1_left_half')

dataid = do2d(cryomag.channel_B.field, 6, 1, 51, 5, appl_gate_1, 0.3, 1.7, 141, 3, meas_voltage_AC_L1, meas_voltage_AC_L1_R)

lockin_1.amplitude(0.004)
appl_current(0)

cryomag.channel_B.field(0)

appl_gate_1(0.3)
plot_by_id(dataid)

# %%
cryomag.channel_B.field(3)

# %%
for Bval in [6, 5, 4, 3]:

    cryomag.channel_B.field(Bval)

    appl_gate_1(0.4)
    appl_current_AC(1e-9)
    appl_current(-200e-9)
    sleep(60)


    station.snapshot(update=True);

    exp = qc.new_experiment('AC IV vs Vg, B = {:.2f}'.format(Bval), sample_name='TR1_JJ')

    dataid = do2d(appl_gate_1, 0.4, 1.7, 40, 3, appl_current, -200e-9, 200e-9, 21, 3,
                  meas_voltage_K1, meas_voltage_AC_L1, meas_voltage_AC_L1_R)

    appl_current(0)
    appl_gate_1(0.4)
    
lockin_1.amplitude(0.004)
appl_gate_1(0.4)
cryomag.channel_B.field(0)

# %% [markdown]
# # Temp dependence

# %%
# lakeshore.output_1.output_range('off')
lakeshore.output_1.setpoint(45.0)
# lakeshore.output_1.input_channel('A')
lakeshore.output_1.output_range('2.5W')

# %%
print('Temps: A= {:.2f}, B = {:.4f}, C ={:.4f}'.format(lakeshore.A.temperature(), lakeshore.B.temperature(), lakeshore.C.temperature()) )

# %%
lockin_1.time_constant(1)
sleep(1)
appl_current_AC(2.5e-9)
appl_current(-8e-6)
sleep(9)

lakeshore.output_1.setpoint(0.3)
lakeshore.output_1.output_range('25mW')

sleep(6)

for set_temp in [0.3, 0.35, 0.4, 0.5, 0.6]:
    lakeshore.output_1.setpoint(set_temp)
    sleep(5)
    lakeshore.output_1.wait_until_set_point_reached(wait_cycle_time = 2, tolerance = 20e-3, wait_equilibration_time = 20)
    
    exp = qc.new_experiment('IV + AC across finger zero field T={}K'.format(set_temp), sample_name='TR1_fR')
    
    dataid = do1d(appl_current, -8e-6, 8e-6, 400, 2, meas_voltage_K1, meas_voltage_AC_L1, meas_voltage_AC_L1_R, lockin_1.P, lakeshore.C.temperature)
    
    appl_current(-8e-6)
    sleep(5)
    
    
lockin_1.amplitude(0.004)
appl_current(0.0)
lakeshore.output_1.setpoint(0)
lakeshore.output_1.output_range('off')

# %%
lakeshore.C.temperature()

# %%
# time = ElapsedTimeParameter('time')

#note that here exit_condition takes two independent parameters and only then measured parameters
def temp_limit(temp, current, measured_values):
    return temp() < 0.33

appl_TG(2.0)
sleep(5)
appl_TG(1.2)
sleep(5)
    
gate_val = 1.5
appl_TG(gate_val)
appl_current(-300e-9)
sleep(10)

B_val = cryomag.channel_B.field()

station.snapshot(update=True);
exp = qc.new_experiment('IV_vs_temp_CD Vg = {}, B = {:.1f}'.format(gate_val, B_val), sample_name='TR2_fL')

dataid = do1d_until(lakeshore.C.temperature, temp_limit, 20, appl_current, -300e-9, 300e-9, 400, 0.05, 
                    meas_voltage_K1, meas_voltage_K2)

appl_current(0)

# %%
def temp_limit(temp, current, measured_values):
    return temp() < 0.33

# %%
for B_val, gate_val in zip([3, 4, 5, 5, 6, 6],[1.6, 1.8, 1.44, 2, 1.5, 1.6]):
    appl_TG(2.0)
    sleep(5)
    appl_TG(1.2)
    sleep(5)
    appl_TG(gate_val)
    cryomag.channel_B.field(B_val)
    
    lakeshore.output_1.output_range('2.5W')
    
    while lakeshore.A.temperature() < 44.5:
        sleep(5)
    
    sleep(60*4)
    lakeshore.output_1.output_range('off')
    sleep(60*4)
    
    if level_meter.lastval() < 14.5:
        print('He level critical!')
        cryomag.channel_B.write('SWEEP ZERO')
        break
    
    temp = lakeshore.C.temperature()
    while temp > 2.5:
        sleep(10)
        temp = lakeshore.C.temperature()
    
    appl_current(-400e-9)
    sleep(5)

    station.snapshot(update=True);
    exp = qc.new_experiment('IV_vs_temp_CD Vg = {}, B = {:.1f}'.format(gate_val, B_val), sample_name='TR2_N_4probes')

    dataid = do1d_until(lakeshore.C.temperature, temp_limit, 20, appl_current, -400e-9, 400e-9, 400, 0.05, 
                        meas_voltage_K1, meas_voltage_K2)

    appl_current(0)
    appl_TG(1.3)
    
# cryomag.channel_B.write('SWEEP ZERO')

# %%
lockin_1.amplitude(0.004)

for B_val in [6, 5]:
    
    cryomag.channel_B.field(B_val)
    
    lakeshore.output_1.output_range('2.5W')
    
    while lakeshore.A.temperature() < 44.5:
        sleep(5)
    
    sleep(60*4)
    lakeshore.output_1.output_range('off')
    sleep(60*3)
    
    appl_TG(2.0)
    sleep(5)
    appl_TG(1.3)

    station.snapshot(update=True);
    exp = qc.new_experiment('DC_fit_vs_Vg_vs_temp_CD zero bias B = {:.1f}'.format(B_val), sample_name='TR2_fB')

    dataid = do1d_until(lakeshore.C.temperature, temp_limit, 5, appl_TG, 1.3, 2, 41, 3, 
                        r_from_IV_1, r_from_IV_2)
    appl_TG(1.3)
    
appl_current(0)

# %%
appl_current_AC(5e-9)
appl_current(0)

for B_val in [5, 4, 3]:
    
    cryomag.channel_B.field(B_val)
    
    lakeshore.output_1.output_range('2.5W')
    
    while lakeshore.A.temperature() < 44.5:
        sleep(5)
    
    sleep(60*4)
    lakeshore.output_1.output_range('off')
    sleep(60*3)
    
    appl_TG(2.0)
    sleep(5)
    appl_TG(1.3)
    
    if level_meter.lastval() < 14.5:
        print('He level critical!')
        cryomag.channel_B.write('SWEEP ZERO')
        break
        

    station.snapshot(update=True);
    exp = qc.new_experiment('AC_vs_Vg_vs_temp_CD zero bias B = {:.1f}'.format(B_val), sample_name='TR2_fB')

    dataid = do1d_until(lakeshore.C.temperature, temp_limit, 5, appl_TG, 1.3, 2, 41, 3, 
                        meas_voltage_AC_L1, meas_voltage_AC_L2, meas_voltage_AC_L1_R, meas_voltage_AC_L2_R,
                        lockin_1.P, lockin_2.P)
    appl_TG(1.3)
    
# cryomag.channel_B.write('SWEEP ZERO')
lockin_1.amplitude(0.004)
station.snapshot(update=True);

# %%
cryomag.channel_B.field(0)

# %%
cryomag.channel_B.write('SWEEP ZERO')

# %%
station.snapshot(update=True);

# %%
appl_current(0)

# %% [markdown]
# # Test cells

# %%
appl_voltage(0)
station.snapshot(update=True);
exp = qc.new_experiment('wire resistant', sample_name='wire')
dataid = do1d(appl_voltage, -3e-3, 3e-3, 101, 0.1, meas_current_K2)
# ivvi.set_dacs_zero()

plot_by_id(dataid)

# %%
dataid = 153
dataset = qc.load_by_id(dataid)

# %%
dataset.get_parameter_data().keys()

# %%
voltage = dataset.get_parameter_data()['meas_current_K2']['appl_voltage']
current = dataset.get_parameter_data()['meas_current_K2']['meas_current_K2']

fit=np.polyfit(current,voltage,1)
fit
