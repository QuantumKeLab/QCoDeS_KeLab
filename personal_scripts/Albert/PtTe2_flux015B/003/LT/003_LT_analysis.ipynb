# %%
from Init3 import *
# Out:
# Imported all modules, QCoDeS version: 0.53.0.dev272+main.g13f25236a.dirty initialized
# 找到 2 個 .db 文件:
# 1. c:\Users\admin\Documents\GitHub\QCoDeS_local\personal_scripts\Albert\PtTe2_flux015B\003\LT\LT_2025-05-18_01.db
# 2. c:\Users\admin\Documents\GitHub\QCoDeS_local\personal_scripts\Albert\PtTe2_flux015B\003\RT\RT_2025-04-02_01.db
# 初始化數據庫: c:\Users\admin\Documents\GitHub\QCoDeS_local\personal_scripts\Albert\PtTe2_flux015B\003\LT\LT_2025-05-18_01.db

# %%
info_df(505)
# Out:
# 正在從快取或磁碟載入 run_id: 505
#
# --- 參數資訊 (runid 505, 基於原始數據結構) ---
# - meas_voltage_K1 (dependent): 76 points
# - y_field              (setpoint): 76 unique points, from -0.0075 to 0.0075, step: 2.000e-04
# - appl_current         (setpoint): 201 unique points, from -1.25e-06 to 1.25e-06, step: 1.250e-08
#
# --- dV/dI 計算 (runid 505) ---
# 使用 電壓: 'meas_voltage_K1', 電流: 'appl_current' 計算 dV/dI。
# 按其他設定點參數分組: ['y_field']
# 已添加 'dV_dI' 列到處理後的 DataFrame。
#
# --- DataFrame 處理後概覽 (runid 505) ---
# 處理後 DataFrame 的 info():
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15276 entries, 0 to 15275
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   appl_current     15276 non-null  float64
#  1   meas_voltage_K1  15276 non-null  float64
#  2   y_field          15276 non-null  float64
#  3   dV_dI            15276 non-null  float64
# dtypes: float64(4)
# memory usage: 477.5 KB
#
# 處理後 DataFrame 的 describe():
#        appl_current  meas_voltage_K1       y_field         dV_dI
# count  1.527600e+04     1.527600e+04  1.527600e+04  15276.000000
# mean   4.435889e-24    -7.604682e-08  0.000000e+00      2.188071
# std    7.253110e-07     1.547073e-06  4.387626e-03      4.900061
# min   -1.250000e-06    -2.995574e-06 -7.500000e-03    -14.780844
# 25%   -6.250000e-07    -1.411117e-06 -3.750000e-03      0.133939
# 50%    0.000000e+00    -7.769639e-08 -2.981556e-19      1.729827
# 75%    6.250000e-07     1.259391e-06  3.750000e-03      3.365040
# max    1.250000e-06     2.818100e-06  7.500000e-03     74.636568
#
# 處理後 DataFrame 的缺失值總和:
# appl_current       0
# meas_voltage_K1    0
# y_field            0
# dV_dI              0
# dtype: int64
# (['y_field', 'appl_current'],
#  'meas_voltage_K1',
#  {'meas_voltage_K1': {'points': 76, 'type': 'dependent'},
#   'y_field': {'unique_points': 76,
#    'start': np.float64(-0.0075),
#    'end': np.float64(0.0075),
#    'step_size_calculated': np.float64(0.00019999999999999998),
#    'step_size_display': '2.000e-04',
#    'type': 'setpoint'},
#   'appl_current': {'unique_points': 201,
#    'start': np.float64(-1.25e-06),
#    'end': np.float64(1.25e-06),
#    'step_size_calculated': np.float64(1.2500000000000001e-08),
#    'step_size_display': '1.250e-08',
#    'type': 'setpoint'}},
#         appl_current  meas_voltage_K1  y_field     dV_dI
#  0         -0.000001        -0.000003  -0.0075  10.68272
#  1         -0.000001        -0.000003  -0.0075   6.83136
#  2         -0.000001        -0.000003  -0.0075   2.24452
#  3         -0.000001        -0.000003  -0.0075   3.87100
#  4         -0.000001        -0.000003  -0.0075   0.99472
#  ...             ...              ...      ...       ...
#  15271      0.000001         0.000003   0.0075   4.71676
#  15272      0.000001         0.000003   0.0075   0.00360
#  15273      0.000001         0.000003   0.0075  -0.25268
#  15274      0.000001         0.000003   0.0075   4.46644
#  15275      0.000001         0.000003   0.0075   0.08584
#
#  [15276 rows x 4 columns])

# %%
df
# Out:
#        appl_current  meas_voltage_K1  y_field     dV_dI
# 0         -0.000001        -0.000003  -0.0075  10.68272
# 1         -0.000001        -0.000003  -0.0075   6.83136
# 2         -0.000001        -0.000003  -0.0075   2.24452
# 3         -0.000001        -0.000003  -0.0075   3.87100
# 4         -0.000001        -0.000003  -0.0075   0.99472
# ...             ...              ...      ...       ...
# 15271      0.000001         0.000003   0.0075   4.71676
# 15272      0.000001         0.000003   0.0075   0.00360
# 15273      0.000001         0.000003   0.0075  -0.25268
# 15274      0.000001         0.000003   0.0075   4.46644
# 15275      0.000001         0.000003   0.0075   0.08584
#
# [15276 rows x 4 columns]

# %%
params[0]
# Out:
# 'appl_current'

# %%
params
# Out:
# ['appl_current', 'meas_voltage_K1', 'y_field', 'dV_dI']

# %%
setpoint_params, dependent_param, param_info, df = info_df(505)
    
# 獲取參數名稱
params = list(df.keys())
# Out:
# --- 參數資訊 (runid 505, 基於原始數據結構) ---
# - meas_voltage_K1 (dependent): 76 points
# - y_field              (setpoint): 76 unique points, from -0.0075 to 0.0075, step: 2.000e-04
# - appl_current         (setpoint): 201 unique points, from -1.25e-06 to 1.25e-06, step: 1.250e-08
#
# --- dV/dI 計算 (runid 505) ---
# 使用 電壓: 'meas_voltage_K1', 電流: 'appl_current' 計算 dV/dI。
# 按其他設定點參數分組: ['y_field']
# 已添加 'dV_dI' 列到處理後的 DataFrame。
#
# --- DataFrame 處理後概覽 (runid 505) ---
# 處理後 DataFrame 的 info():
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15276 entries, 0 to 15275
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   appl_current     15276 non-null  float64
#  1   meas_voltage_K1  15276 non-null  float64
#  2   y_field          15276 non-null  float64
#  3   dV_dI            15276 non-null  float64
# dtypes: float64(4)
# memory usage: 477.5 KB
#
# 處理後 DataFrame 的 describe():
#        appl_current  meas_voltage_K1       y_field         dV_dI
# count  1.527600e+04     1.527600e+04  1.527600e+04  15276.000000
# mean   4.435889e-24    -7.604682e-08  0.000000e+00      2.188071
# std    7.253110e-07     1.547073e-06  4.387626e-03      4.900061
# min   -1.250000e-06    -2.995574e-06 -7.500000e-03    -14.780844
# 25%   -6.250000e-07    -1.411117e-06 -3.750000e-03      0.133939
# 50%    0.000000e+00    -7.769639e-08 -2.981556e-19      1.729827
# 75%    6.250000e-07     1.259391e-06  3.750000e-03      3.365040
# max    1.250000e-06     2.818100e-06  7.500000e-03     74.636568
#
# 處理後 DataFrame 的缺失值總和:
# appl_current       0
# meas_voltage_K1    0
# y_field            0
# dV_dI              0
# dtype: int64

# %%
fig2 = go.Figure(data=go.Heatmap(
            x=df[params[2]],
            y=df[params[0]],
            z=df[params[3]],
            # zmin=df[params[3]].min(),
            # zmax=df[params[3]].mean() + 2 * df[params[3]].std(),
            colorscale='RdBu',
            colorbar=dict(
                title=dict(
                    text=f"",
                    side="top" ))
        ))
fig2.show()

# %%
import pandas as pd
import numpy as np
import qcodes as qc # 假設 qc.load_by_id 是主要的載入方式
from functools import lru_cache
import warnings

# 您提供的 cached_load_dataset 函數
@lru_cache(maxsize=32)
def cached_load_dataset(runid):
    """緩存數據集載入結果"""
    print(f"正在從快取或磁碟載入 run_id: {runid}") # 添加打印以便追蹤
    return qc.load_by_id(runid)

def _clean_data_for_gradient(df_group, x_col, y_col, other_cols_to_keep=None):
    """
    輔助函數：清洗數據以準備進行梯度計算。
    - 按 x_col 排序
    - 移除在 x_col 或 y_col 中的 NaN
    - 對於 x_col 中的重複值，聚合 y_col (取平均值)
    - 保留 other_cols_to_keep 中的其他欄位 (取第一個值)
    """
    if df_group.empty:
        # 如果輸入的 df_group 為空，則返回一個帶有預期欄位的空 DataFrame
        # 這樣可以避免後續在空的 DataFrame 上操作時出錯
        expected_cols = []
        if x_col: expected_cols.append(x_col)
        if y_col: expected_cols.append(y_col)
        if other_cols_to_keep: expected_cols.extend(other_cols_to_keep)
        return pd.DataFrame(columns=list(set(expected_cols))) # 使用 set 去除可能的重複欄位名

    if not all(col in df_group.columns for col in [x_col, y_col]):
        print(f"警告 (_clean_data_for_gradient): 欄位 '{x_col}' 或 '{y_col}' 不在提供的 DataFrame 中。")
        # 返回原始分組，讓後續邏輯處理（例如，梯度計算會失敗或跳過）
        # 或者返回一個空的 DataFrame 結構，取決於期望的錯誤處理流程
        # 這裡我們選擇返回修改後的副本或原始副本（如果欄位不存在）
        return df_group.copy()


    # 0. 複製以避免修改原始分組
    cleaned_df = df_group.copy()

    # 1. 移除在 x_col 或 y_col 中的 NaN
    cleaned_df.dropna(subset=[x_col, y_col], inplace=True)
    if cleaned_df.empty:
        # 如果移除 NaN 後為空，也返回帶有預期欄位的空 DataFrame
        expected_cols = [x_col, y_col]
        if other_cols_to_keep: expected_cols.extend(other_cols_to_keep)
        return pd.DataFrame(columns=list(set(expected_cols)))

    # 2. 按 x_col 排序 (聚合前排序是好習慣，聚合後也需要排序)
    cleaned_df.sort_values(by=x_col, inplace=True)
    
    # 3. 處理 x_col 中的重複值
    if cleaned_df.duplicated(subset=[x_col]).any():
        agg_functions = {y_col: 'mean'}
        # 確保 other_cols_to_keep 中的欄位存在於 cleaned_df 中，並且不是 x_col 或 y_col
        if other_cols_to_keep:
            for col in other_cols_to_keep:
                if col in cleaned_df.columns and col != x_col and col != y_col:
                    agg_functions[col] = 'first' # 保留其他重要欄位的第一個值
        
        cleaned_df = cleaned_df.groupby(x_col, as_index=False).agg(agg_functions)
        # groupby 後，x_col 成為結果的一部分，並且結果通常已按 x_col 排序，
        # 但為了確保，再次排序 (如果 agg_functions 改變了順序)
        cleaned_df.sort_values(by=x_col, inplace=True) 

    return cleaned_df


def info_df(runid, voltage_param_name=None, current_param_name=None):
    """
    輸入 runid，輸出數據集中的參數信息，並計算 dV/dI。
    經過修改以包含更靈活的參數識別、數據清洗和改進的錯誤處理。
    
    Parameters:
    runid : int
        要查看的數據集的 runid
    voltage_param_name : str, optional
        指定的電壓參數欄位名。如果 None，則嘗試自動檢測。
    current_param_name : str, optional
        指定的電流參數欄位名。如果 None，則嘗試自動檢測。

    Returns:
    setpoint_params_names : list
        所有獨立參數的名稱列表 (來自原始數據集結構)
    actual_dependent_param_name : str
        實際使用的依賴/電壓參數的名稱
    param_info : dict
        包含每個原始掃描參數的起始值、結束值和步長的字典
    df_processed : pd.DataFrame
        處理後的數據集的 pandas DataFrame，可能包含 'dV_dI' 列。
        如果進行了聚合，其行數可能與原始數據集不同。
    """
    try:
        dataset = cached_load_dataset(runid)
        if dataset is None:
            print(f"錯誤：無法載入 runid {runid} 的數據集。")
            return [], None, {}, pd.DataFrame()
    except Exception as e:
        print(f"載入數據集 runid {runid} 時發生錯誤: {e}")
        return [], None, {}, pd.DataFrame()

    # --- 1. 提取原始參數結構和資訊 ---
    param_data = dataset.get_parameter_data()
    if not param_data or not isinstance(param_data, dict) or not list(param_data.keys()):
        print(f"錯誤：runid {runid} 的參數數據無效或為空。")
        return [], None, {}, pd.DataFrame()

    # QCoDeS 中，get_parameter_data() 返回的字典，其頂層鍵通常是主要測量參數組
    # 我們假設第一個頂層鍵代表了主要的測量組
    main_measurement_group_key = list(param_data.keys())[0]
    
    if main_measurement_group_key not in param_data or \
       not isinstance(param_data[main_measurement_group_key], dict):
        print(f"錯誤：在 runid {runid} 中找不到有效的測量組數據 '{main_measurement_group_key}'。")
        return [], None, {}, pd.DataFrame()
        
    all_param_names_in_group = list(param_data[main_measurement_group_key].keys())

    # --- 2. 識別依賴參數和設定點參數 (基於原始數據結構) ---
    #    (注意: 'actual_voltage_param' 和 'actual_current_param' 會在稍後根據 df 欄位確定)
    
    # 依賴參數的初步猜測 (通常是測量值，也可能是指定的電壓參數)
    # 如果 voltage_param_name 未提供，則依賴參數是 param_data 中的第一個key
    # 否則，依賴參數是 voltage_param_name (如果它有效)
    # 這個 `determined_dependent_param` 用於提取 param_info
    if voltage_param_name and voltage_param_name in all_param_names_in_group:
        determined_dependent_param = voltage_param_name
    elif main_measurement_group_key in all_param_names_in_group : # QCoDeS 中通常主要依賴參數名與其組名相同
        determined_dependent_param = main_measurement_group_key
    elif all_param_names_in_group: # 如果都不是，退回到組內第一個參數（不太可靠）
        determined_dependent_param = all_param_names_in_group[0]
        print(f"警告：無法精確確定主要依賴參數，假設為 '{determined_dependent_param}'。")
    else:
        print(f"錯誤：在測量組 '{main_measurement_group_key}' 中沒有找到任何參數名。")
        return [], None, {}, pd.DataFrame()


    setpoint_params_names = [p for p in all_param_names_in_group if p != determined_dependent_param]

    param_info = {}
    print(f"\n--- 參數資訊 (runid {runid}, 基於原始數據結構) ---")
    if determined_dependent_param in param_data[main_measurement_group_key]:
        dep_data_array = param_data[main_measurement_group_key][determined_dependent_param]
        param_info[determined_dependent_param] = {
            'points': len(dep_data_array),
            'type': 'dependent'
        }
        print(f"- {determined_dependent_param} (dependent): {len(dep_data_array)} points")
    else:
         print(f"警告：主要依賴參數 '{determined_dependent_param}' 在原始參數數據中未找到數組。")


    for sp_name in setpoint_params_names:
        if sp_name in param_data[main_measurement_group_key]:
            sp_data_array = param_data[main_measurement_group_key][sp_name]
            # 移除 NaN 後取唯一值來計算 start, end, step
            valid_sp_data = sp_data_array[~np.isnan(sp_data_array)] if isinstance(sp_data_array, np.ndarray) else np.array(sp_data_array)[~np.isnan(np.array(sp_data_array))]

            unique_values = np.unique(valid_sp_data)
            num_unique_points = len(unique_values)
            
            start_val, end_val, step_size, step_size_str = "N/A", "N/A", None, "N/A"
            if num_unique_points > 0:
                start_val = unique_values[0]
                end_val = unique_values[-1]
                if num_unique_points > 1:
                    # 步長計算：可以考慮更穩健的方法，例如中位數差值，或檢查是否均勻
                    diffs = np.diff(unique_values)
                    if len(diffs) > 0 :
                        step_size = np.mean(diffs) # 或 np.median(diffs)
                        step_size_str = f"{step_size:.3e}"
                    else: # 只有一個點差 (兩個unique points)
                        step_size = diffs[0] if len(diffs) == 1 else None
                        step_size_str = f"{step_size:.3e}" if step_size is not None else "N/A"
                else: # 只有一個唯一點
                    step_size_str = "N/A (single point)"
            
            param_info[sp_name] = {
                'unique_points': num_unique_points,
                'start': start_val,
                'end': end_val,
                'step_size_calculated': step_size, # 儲存計算出的步長值
                'step_size_display': step_size_str,
                'type': 'setpoint'
            }
            print(f"- {sp_name:<20} (setpoint): {num_unique_points} unique points, from {start_val} to {end_val}, step: {step_size_str}")
        else:
            print(f"警告：設定點參數 '{sp_name}' 在原始參數數據中未找到數組。")

    # --- 3. 獲取並準備 DataFrame ---
    try:
        df_original = dataset.to_pandas_dataframe()
        # QCoDeS 的 to_pandas_dataframe 可能會將獨立參數設為索引，確保它們是列
        if isinstance(df_original.index, pd.MultiIndex) or df_original.index.name is not None:
            df_original = df_original.reset_index()

    except Exception as e:
        print(f"錯誤：轉換 runid {runid} 的數據集到 DataFrame 時失敗: {e}")
        return setpoint_params_names, determined_dependent_param, param_info, pd.DataFrame()

    if df_original.empty:
        print("警告：從數據集轉換的 DataFrame 為空。")
        return setpoint_params_names, determined_dependent_param, param_info, df_original.assign(dV_dI=np.nan)


    df_processed = df_original.copy() # 我們將在這個副本上操作

    # --- 4. 確定實際用於 dV/dI 計算的電壓和電流參數欄位名 (基於 df_processed 的欄位) ---
    current_df_columns = list(df_processed.columns)
    
    # 確定電壓參數
    actual_voltage_param = None
    if voltage_param_name and voltage_param_name in current_df_columns:
        actual_voltage_param = voltage_param_name
    elif determined_dependent_param in current_df_columns: # 如果用戶未指定，則使用自動檢測的依賴參數
        actual_voltage_param = determined_dependent_param
    else: # 如果自動檢測的依賴參數也不在df中，嘗試在df中找一個可能的依賴參數（例如，不是setpoint的）
        non_setpoint_cols = [col for col in current_df_columns if col not in setpoint_params_names]
        if len(non_setpoint_cols) == 1: # 如果只有一個非setpoint欄位，很可能就是它
            actual_voltage_param = non_setpoint_cols[0]
            print(f"提示：自動選擇 '{actual_voltage_param}' 作為電壓參數 (因其為唯一的非設定點欄位)。")
        elif voltage_param_name: # 如果用戶指定了但不在欄位中
             print(f"警告：指定的電壓參數 '{voltage_param_name}' 不在 DataFrame 的欄位中。")
        else:
            print(f"警告：無法自動確定電壓參數，且 '{determined_dependent_param}' 不在 DataFrame 的欄位中。")

    # 確定電流參數
    actual_current_param = None
    if current_param_name and current_param_name in current_df_columns:
        actual_current_param = current_param_name
    else: # 自動檢測
        # 優先從 setpoint_params_names (來自原始數據結構) 中查找
        potential_current_params = [p for p in setpoint_params_names if p in current_df_columns]
        for p_name in potential_current_params:
            if any(keyword in p_name.lower() for keyword in ["curr", "_i_", "current"]):
                actual_current_param = p_name
                break
        if not actual_current_param and current_param_name: # 如果用戶指定了但不在欄位中
            print(f"警告：指定的電流參數 '{current_param_name}' 不在 DataFrame 的欄位中。")

    # --- 5. 計算 dV/dI ---
    print(f"\n--- dV/dI 計算 (runid {runid}) ---")
    if actual_current_param and actual_voltage_param:
        print(f"使用 電壓: '{actual_voltage_param}', 電流: '{actual_current_param}' 計算 dV/dI。")

        # 找出其他設定點欄位 (用於分組，且必須存在於 df_processed 中)
        other_setpoint_cols_for_grouping = [
            p for p in setpoint_params_names 
            if p in df_processed.columns and p != actual_current_param and p != actual_voltage_param
        ]
        
        processed_groups_list = []
        if other_setpoint_cols_for_grouping:
            print(f"按其他設定點參數分組: {other_setpoint_cols_for_grouping}")
            # dropna=False 避免因分組鍵含 NaN 而丟失組
            # observed=True 是 pandas >= 1.1.0 的推薦用法，避免產生未觀察到的分類組合
            grouped = df_processed.groupby(other_setpoint_cols_for_grouping, observed=True, dropna=False)
            
            for _, group_df_slice in grouped:
                if group_df_slice.empty: continue

                cleaned_group = _clean_data_for_gradient(
                    group_df_slice, 
                    actual_current_param, 
                    actual_voltage_param, 
                    other_cols_to_keep=other_setpoint_cols_for_grouping # 確保分組依據的欄位被保留
                )
                
                if len(cleaned_group) >= 2:
                    # 在 try-except 內執行 np.gradient 以處理潛在的數值問題
                    try:
                        with warnings.catch_warnings(): # 捕捉 np.gradient 可能的警告
                            warnings.simplefilter("ignore", category=RuntimeWarning)
                            dv_di_values = np.gradient(
                                cleaned_group[actual_voltage_param].values, 
                                cleaned_group[actual_current_param].values
                            )
                        cleaned_group['dV_dI'] = dv_di_values
                    except Exception as e_grad:
                        print(f"警告：在分組中計算梯度時發生錯誤: {e_grad}。該分組的 dV/dI 將設為 NaN。")
                        cleaned_group['dV_dI'] = np.nan
                elif not cleaned_group.empty: # 如果清洗後有點但少於2個
                    cleaned_group['dV_dI'] = np.nan
                
                if not cleaned_group.empty:
                    processed_groups_list.append(cleaned_group)
        else:
            # 沒有其他參數，直接處理整個 DataFrame
            cleaned_df = _clean_data_for_gradient(
                df_processed, 
                actual_current_param, 
                actual_voltage_param
            )
            if len(cleaned_df) >= 2:
                try:
                    with warnings.catch_warnings():
                        warnings.simplefilter("ignore", category=RuntimeWarning)
                        dv_di_values = np.gradient(
                            cleaned_df[actual_voltage_param].values, 
                            cleaned_df[actual_current_param].values
                        )
                    cleaned_df['dV_dI'] = dv_di_values
                except Exception as e_grad:
                    print(f"警告：計算梯度時發生錯誤: {e_grad}。dV/dI 將設為 NaN。")
                    cleaned_df['dV_dI'] = np.nan
            elif not cleaned_df.empty:
                cleaned_df['dV_dI'] = np.nan
            
            if not cleaned_df.empty:
                processed_groups_list.append(cleaned_df)

        if processed_groups_list:
            # 合併所有處理過的分組
            df_processed = pd.concat(processed_groups_list, ignore_index=True)
            print("已添加 'dV_dI' 列到處理後的 DataFrame。")
        else:
            print("警告：沒有足夠的數據或有效分組來計算 dV/dI。dV_dI 列將全為 NaN。")
            df_processed['dV_dI'] = np.nan # 在 df_processed 上添加全NaN列
            
    else:
        missing_params_msg = []
        if not actual_voltage_param: missing_params_msg.append("電壓參數無法確定")
        if not actual_current_param: missing_params_msg.append("電流參數無法確定")
        print(f"警告：{ ' 和 '.join(missing_params_msg) }。跳過 dV/dI 計算。")
        df_processed['dV_dI'] = np.nan # 添加一個全NaN的列以保持一致性

    # --- 6. DataFrame 最終概覽 ---
    print(f"\n--- DataFrame 處理後概覽 (runid {runid}) ---")
    print("處理後 DataFrame 的 info():")
    if not df_processed.empty:
        df_processed.info()
        print("\n處理後 DataFrame 的 describe():")
        print(df_processed.describe(include='all'))
        print("\n處理後 DataFrame 的缺失值總和:")
        print(df_processed.isnull().sum())
    else:
        print("處理後的 DataFrame 為空。")
    
    return setpoint_params_names, determined_dependent_param, param_info, df_processed

# --- 範例使用 (請確保您有 QCoDeS 環境和數據庫來運行真實測試) ---
if __name__ == '__main__':
    # 為了測試，需要 mock `qc.load_by_id` 或有一個真實的QCoDeS數據庫和數據
    # 以下是偽代碼風格的測試，因為我無法在這裡真正載入QCoDeS數據集

    print("="*20 + " 偽測試範例 (需要真實QCoDeS數據) " + "="*20)
    
    # 假設您有一個 runid = 1 的數據集
    # mock_qc_load_by_id() # 您需要提供一個模擬函數或真實數據
    
    # 範例1：自動檢測參數
    # print("\n--- 測試1：自動檢測參數 ---")
    # sp_names, dep_name, p_info, df_proc = info_df_modified(1)
    # if not df_proc.empty:
    #     print("\n返回的處理後 DataFrame (自動檢測) 的前幾行:")
    #     print(df_proc.head())
    #     if 'dV_dI' in df_proc.columns:
    #          print(f"dV_dI 是否包含 NaN? {df_proc['dV_dI'].isnull().any()}")

    # 範例2：手動指定電壓和電流參數名稱
    # print("\n--- 測試2：手動指定參數 ---")
    # sp_names2, dep_name2, p_info2, df_proc2 = info_df_modified(
    #     1, 
    #     voltage_param_name='your_voltage_column_name', # 替換為您數據中的實際電壓欄位名
    #     current_param_name='your_current_column_name'  # 替換為您數據中的實際電流欄位名
    # )
    # if not df_proc2.empty:
    #     print("\n返回的處理後 DataFrame (手動指定) 的前幾行:")
    #     print(df_proc2.head())

    # 範例3：一個沒有電流參數的數據集 (dV/dI 應為 NaN)
    # print("\n--- 測試3：無電流參數的數據集 ---")
    # sp_names3, dep_name3, p_info3, df_proc3 = info_df_modified(2) # 假設 runid 2 沒有電流數據
    # if not df_proc3.empty and 'dV_dI' in df_proc3.columns:
    #     print("\n返回的處理後 DataFrame (無電流) 的 dV_dI 是否全為 NaN:")
    #     print(df_proc3['dV_dI'].isnull().all())
    
    # 提醒：上面的測試範例需要您準備好 QCoDeS 環境和數據，或者提供更完善的模擬 `qc.load_by_id`。
    # 我在這裡添加的 `cached_load_dataset` 函數使用了 `qc.load_by_id`，
    # 如果您在沒有 QCoDeS 環境的情況下直接運行此腳本，它會出錯。
    print("\n請注意：以上範例測試需要在配置好的 QCoDeS 環境中運行，")
    print("或者您需要提供 `qc.load_by_id` 的模擬實現才能看到實際輸出。")
    print("函數 `info_df_modified` 已定義。")
# Out:
# ==================== 偽測試範例 (需要真實QCoDeS數據) ====================
#
# 請注意：以上範例測試需要在配置好的 QCoDeS 環境中運行，
# 或者您需要提供 `qc.load_by_id` 的模擬實現才能看到實際輸出。
# 函數 `info_df_modified` 已定義。

# %%
# !uv pip install --upgrade kaleido
# Out:
# Using Python 3.13.3 environment at: C:\Users\admin\anaconda3\envs\py313
# Resolved 1 package in 911ms
# Downloading kaleido (62.9MiB)
#  Downloading kaleido
# Prepared 1 package in 6.98s
# Installed 1 package in 165ms
#  + kaleido==0.2.1

# %% [markdown]
# # plot_heatmaps

# %%
import numpy
import scipy
import pandas
import matplotlib
# import qcodes # if used in plot_heatmaps
print("NumPy:", numpy.__version__)
print("SciPy:", scipy.__version__)
print("Pandas:", pandas.__version__)
print("Matplotlib:", matplotlib.__version__)
# print("QCoDeS:", qcodes.__version__)
# Out:
# NumPy: 2.2.6
# SciPy: 1.15.3
# Pandas: 2.2.3
# Matplotlib: 3.10.3

# %%
import warnings

warnings.filterwarnings('default')

# %%
dataid = 355
fig1, fig2, fig3 , Ic_df= plot_heatmaps(dataid)
clear_output(wait=False)
fig1.show()
fig2.show()
fig3.show()
# Out:
# ID               : 355
# Type             : IVBy+
# Sample           : 003-2_20-19-30-29@r:60mT,θ:7°,φ:-90°@(0,-8,60)mT
# Run time         : 14 min 48 sec
# Parameter unit:
# - meas_voltage_K1: V
# - y_field        : T
# - appl_current   : A
#
# Number of points for each parameter in dataset 355:
# - meas_voltage_K1 (dependent): 151 points
# - y_field          (setpoint): 151 unique points, from -7.50e-03 to 7.50e-03, step size: 1.00e-04
# - appl_current     (setpoint): 81 unique points, from 0.00e+00 to 8.00e-06, step size: 1.00e-07
# 計算微分電阻 dV/dI，使用電壓: meas_voltage_K1 和電流: appl_current
# 已添加dV_dI列到數據框
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12231 entries, 0 to 12230
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   y_field          12231 non-null  float64
#  1   appl_current     12231 non-null  float64
#  2   meas_voltage_K1  12231 non-null  float64
#  3   dV_dI            12231 non-null  float64
# dtypes: float64(4)
# memory usage: 382.3 KB
# None
#             y_field  appl_current  meas_voltage_K1         dV_dI
# count  12231.000000  12231.000000     1.223100e+04  12231.000000
# mean       0.000000      0.000004     8.367495e-06      2.017384
# std        0.004359      0.000002     5.519731e-06      3.003405
# min       -0.007500      0.000000     2.644277e-07     -3.190121
# 25%       -0.003800      0.000002     1.980179e-06      1.681178
# 50%        0.000000      0.000004     8.965947e-06      2.019850
# 75%        0.003800      0.000006     1.318794e-05      2.210698
# max        0.007500      0.000008     1.738638e-05     41.322855
# y_field            0
# appl_current       0
# meas_voltage_K1    0
# dV_dI              0
# dtype: int64
# C:\Users\admin\Documents\GitHub\Qcodes\src\qcodes\dataset\sqlite\database.py:70: ResourceWarning: unclosed database in <qcodes.dataset.sqlite.connection.AtomicConnection object at 0x000002BB0542E650>
#   def _convert_numeric(value: bytes) -> float | int | str:
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# c:\Users\admin\anaconda3\envs\py313\Lib\site-packages\kaleido\scopes\base.py:188: DeprecationWarning:
#
# setDaemon() is deprecated, set the daemon attribute instead

# %% [markdown]
# ## xaxes update

# %%
# x_range=[0.0e-6, 12.0e-6]
# fig1.update_xaxes(range=x_range) 
# y_range=[0e-6, 1.5e-6]
# fig1.data[0].update(zmin= 0.0e-6, zmax=4e-6)
y_range=[-1.5e-6, 0e-6]
fig1.data[0].update(zmin=-4.0e-6, zmax=0e-6)
fig1.update_yaxes(range=y_range) 
fig1.show()
fig2.data[0].update(zmin=0, zmax=0.3)
# fig2.update_xaxes(range=range)
# fig2.show()
# fig3.update_xaxes(range=range) 
fig3.update_yaxes(range=[130e-6, 140e-6])
# fig3.show()

# %%
dataid = 197 # East(E) 0°
dataid = 196 # NorthEast(NE) 45°
dataid = 178 # North(N) 90°
dataid = 180 # NorthWest(NW) 135°
dataid = 186 # West(W) 180°
dataid = 185 # SouthWest(SW) 225°
dataid = 188 # South(S) 270°
dataid = 191 # SouthEast(SE) 315°

# %%
# Critical current Ic comparison with fixed In-plane field value but different angles
f=0
ByRange = 5e-3
IcMax_df = pd.DataFrame(columns=["angle", "IcMax","By", "dataid"])
dataid = 196 # NorthEast(NE) 45°
angle = 45
Ic_offset = angle*1e-6*f
ByOffset = 2e-3
fig1, fig2, fig3 , Ic_df= plot_heatmaps(dataid)
# add Max Ic of Ic_df to IcMax_df label with dataid and angle
# Filter out the Ic_df where Ic_df["param_value"] is between 0-ByRange and 0+ByRange
Ic_df = Ic_df[(Ic_df["param_value"] < ByRange) & (Ic_df["param_value"] > -ByRange)]
# Find the param_value where Ic is maximal
By = Ic_df.loc[Ic_df["Ic"].idxmax(), "param_value"]
new_row = pd.DataFrame([{"angle": angle, "IcMax": Ic_df["Ic"].max(),"By": By, "dataid": dataid}])
IcMax_df = pd.concat([IcMax_df, new_row], ignore_index=True)
clear_output(wait=True)
fig = go.Figure()
fig.add_trace(go.Scatter(
        x=Ic_df["param_value"], # Out-off-plane field y_field values, unit: T
        y=Ic_df["Ic"]+Ic_offset, # Critical current Ic values, unit: A
        mode='lines+markers',
        name=f'{angle}°NE{dataid}',
        marker=dict(size=5),
        line=dict(width=2)
    ))
dataid = 197 # East(E) 0°
angle = 0
Ic_offset = angle*1e-6*f
fig1, fig2, fig3 , Ic_df= plot_heatmaps(dataid)
# add Max Ic of Ic_df to IcMax_df label with dataid and angle
# Filter out the Ic_df where Ic_df["param_value"] is between 0-ByRange and 0+ByRange
Ic_df = Ic_df[(Ic_df["param_value"] < ByRange) & (Ic_df["param_value"] > -ByRange)]
By = Ic_df.loc[Ic_df["Ic"].idxmax(), "param_value"] 
new_row = pd.DataFrame([{"angle": angle, "IcMax": Ic_df["Ic"].max(),"By": By, "dataid": dataid}])
IcMax_df = pd.concat([IcMax_df, new_row], ignore_index=True)
clear_output(wait=True)
fig.add_trace(go.Scatter(
        x=Ic_df["param_value"], # Out-off-plane field y_field values, unit: T
        y=Ic_df["Ic"]+Ic_offset, # Critical current Ic values, unit: A
        mode='lines+markers',
        name=f'{angle}°E{dataid}',
        marker=dict(size=5),
        line=dict(width=2)
    ))
dataid = 191 # SouthEast(SE) 315°
angle = 315
Ic_offset = angle*1e-6*f
fig1, fig2, fig3 , Ic_df= plot_heatmaps(dataid)
# add Max Ic of Ic_df to IcMax_df label with dataid and angle
# Filter out the Ic_df where Ic_df["param_value"] is between 0-ByRange and 0+ByRange
Ic_df = Ic_df[(Ic_df["param_value"] < ByRange) & (Ic_df["param_value"] > -ByRange)]
By = Ic_df.loc[Ic_df["Ic"].idxmax(), "param_value"] 
new_row = pd.DataFrame([{"angle": angle, "IcMax": Ic_df["Ic"].max(),"By": By, "dataid": dataid}])
IcMax_df = pd.concat([IcMax_df, new_row], ignore_index=True)
clear_output(wait=True)
fig.add_trace(go.Scatter(
        x=Ic_df["param_value"], # Out-off-plane field y_field values, unit: T
        y=Ic_df["Ic"]+Ic_offset, # Critical current Ic values, unit: A
        mode='lines+markers',
        name=f'{angle}°SE{dataid}',
        marker=dict(size=5),
        line=dict(width=2)
    ))
dataid = 188 # South(S) 270°
angle = 270
Ic_offset = angle*1e-6*f
fig1, fig2, fig3 , Ic_df= plot_heatmaps(dataid)
# add Max Ic of Ic_df to IcMax_df label with dataid and angle
# Filter out the Ic_df where Ic_df["param_value"] is between 0-ByRange and 0+ByRange
Ic_df = Ic_df[(Ic_df["param_value"] < ByRange) & (Ic_df["param_value"] > -ByRange)]
By = Ic_df.loc[Ic_df["Ic"].idxmax(), "param_value"] 
new_row = pd.DataFrame([{"angle": angle, "IcMax": Ic_df["Ic"].max(),"By": By, "dataid": dataid}])
IcMax_df = pd.concat([IcMax_df, new_row], ignore_index=True)
clear_output(wait=True)
fig.add_trace(go.Scatter(
        x=Ic_df["param_value"], # Out-off-plane field y_field values, unit: T
        y=Ic_df["Ic"]+Ic_offset, # Critical current Ic values, unit: A
        mode='lines+markers',
        name=f'{angle}°S{dataid}',
        marker=dict(size=5),
        line=dict(width=2)
    ))
dataid = 185 # SouthWest(SW) 225°
angle = 225
Ic_offset = angle*1e-6*f
fig1, fig2, fig3 , Ic_df= plot_heatmaps(dataid)
# add Max Ic of Ic_df to IcMax_df label with dataid and angle
# Filter out the Ic_df where Ic_df["param_value"] is between 0-ByRange and 0+ByRange
Ic_df = Ic_df[(Ic_df["param_value"] < ByRange) & (Ic_df["param_value"] > -ByRange)]
By = Ic_df.loc[Ic_df["Ic"].idxmax(), "param_value"] 
new_row = pd.DataFrame([{"angle": angle, "IcMax": Ic_df["Ic"].max(),"By": By, "dataid": dataid}])
IcMax_df = pd.concat([IcMax_df, new_row], ignore_index=True)
clear_output(wait=True)
fig.add_trace(go.Scatter(
        x=Ic_df["param_value"], # Out-off-plane field y_field values, unit: T
        y=Ic_df["Ic"]+Ic_offset, # Critical current Ic values, unit: A
        mode='lines+markers',
        name=f'{angle}°SW{dataid}',
        marker=dict(size=5),
        line=dict(width=2)
    ))
dataid = 186 # West(W) 180°
angle = 180
Ic_offset = angle*1e-6*f
fig1, fig2, fig3 , Ic_df= plot_heatmaps(dataid)
# add Max Ic of Ic_df to IcMax_df label with dataid and angle
# Filter out the Ic_df where Ic_df["param_value"] is between 0-ByRange and 0+ByRange
Ic_df = Ic_df[(Ic_df["param_value"] < ByRange) & (Ic_df["param_value"] > -ByRange)]
By = Ic_df.loc[Ic_df["Ic"].idxmax(), "param_value"] 
new_row = pd.DataFrame([{"angle": angle, "IcMax": Ic_df["Ic"].max(),"By": By, "dataid": dataid}])
IcMax_df = pd.concat([IcMax_df, new_row], ignore_index=True)
clear_output(wait=True)
fig.add_trace(go.Scatter(
        x=Ic_df["param_value"], # Out-off-plane field y_field values, unit: T
        y=Ic_df["Ic"]+Ic_offset, # Critical current Ic values, unit: A
        mode='lines+markers',
        name=f'{angle}°W{dataid}',
        marker=dict(size=5),
        line=dict(width=2)
    ))
dataid = 180 # NorthWest(NW) 135°
angle = 135
Ic_offset = angle*1e-6*f
fig1, fig2, fig3 , Ic_df= plot_heatmaps(dataid)
# add Max Ic of Ic_df to IcMax_df label with dataid and angle
# Filter out the Ic_df where Ic_df["param_value"] is between 0-ByRange and 0+ByRange
Ic_df = Ic_df[(Ic_df["param_value"] < ByRange) & (Ic_df["param_value"] > -ByRange)]
By = Ic_df.loc[Ic_df["Ic"].idxmax(), "param_value"] 
new_row = pd.DataFrame([{"angle": angle, "IcMax": Ic_df["Ic"].max(),"By": By, "dataid": dataid}])
IcMax_df = pd.concat([IcMax_df, new_row], ignore_index=True)
clear_output(wait=True)
fig.add_trace(go.Scatter(
        x=Ic_df["param_value"], # Out-off-plane field y_field values, unit: T
        y=Ic_df["Ic"]+Ic_offset, # Critical current Ic values, unit: A
        mode='lines+markers',
        name=f'{angle}°NW{dataid}',
        marker=dict(size=5),
        line=dict(width=2)
    ))
dataid = 178 # North(N) 90°
angle = 90
Ic_offset = angle*1e-6*f
fig1, fig2, fig3 , Ic_df= plot_heatmaps(dataid)
# add Max Ic of Ic_df to IcMax_df label with dataid and angle
# Filter out the Ic_df where Ic_df["param_value"] is between 0-ByRange and 0+ByRange
Ic_df = Ic_df[(Ic_df["param_value"] < ByRange) & (Ic_df["param_value"] > -ByRange)]
By = Ic_df.loc[Ic_df["Ic"].idxmax(), "param_value"] 
new_row = pd.DataFrame([{"angle": angle, "IcMax": Ic_df["Ic"].max(),"By": By, "dataid": dataid}])
IcMax_df = pd.concat([IcMax_df, new_row], ignore_index=True)
clear_output(wait=True)
fig.add_trace(go.Scatter(
        x=Ic_df["param_value"], # Out-off-plane field y_field values, unit: T
        y=Ic_df["Ic"]+Ic_offset, # Critical current Ic values, unit: A
        mode='lines+markers',
        name=f'{angle}°N{dataid}',
        marker=dict(size=5),
        line=dict(width=2)
    ))
# add IcMax_df to fig
fig.add_trace(go.Scatter(
        x=IcMax_df["By"], # angle values, unit: degree
        y=IcMax_df["IcMax"]+IcMax_df["angle"]*1e-6*f, # Critical current Ic values, unit: A
        mode='lines+markers',
        name='IcMax',
        marker=dict(size=5),
        line=dict(width=2)
    ))
fig.show()

# %%
import pandas as pd
import plotly.graph_objects as go
from IPython.display import clear_output

# Assume plot_heatmaps is defined elsewhere and works as expected
# from your_module import plot_heatmaps # Example of how you might import it

# --- Helper Function Definition ---
def process_and_plot_data(dataid, angle, angle_label, fig, IcMax_df, ByOffset, ByRange, f_factor):
    """
    Processes data for a given angle and dataid, updates the IcMax_df,
    and adds a trace to the figure.

    Args:
        dataid (int): The ID of the dataset.
        angle (int or float): The angle in degrees.
        angle_label (str): A short label for the angle (e.g., "NE", "E").
        fig (go.Figure): The Plotly figure object to add traces to.
        IcMax_df (pd.DataFrame): DataFrame to store maximum Ic values.
        ByRange (float): The range to filter 'param_value'.
        f_factor (float): The factor 'f' used in Ic_offset calculation.

    Returns:
        tuple: Updated (fig, IcMax_df)
    """
    print(f"Processing dataid: {dataid}, angle: {angle}° ({angle_label})")
    Ic_offset = angle * 1e-6 * f_factor
    
    # Simulate plot_heatmaps if it's not available in this environment
    # In your actual code, you would call your plot_heatmaps function:
    # fig1, fig2, fig3, Ic_df = plot_heatmaps(dataid)
    
    # --- Placeholder for plot_heatmaps and Ic_df generation ---
    # Replace this with your actual plot_heatmaps call and Ic_df structure
    # For demonstration, creating a dummy Ic_df
    if 'plot_heatmaps' not in globals():
        print(f"Warning: 'plot_heatmaps' function not found. Using dummy data for dataid {dataid}.")
        _data_points = 10
        _param_values = [(i - _data_points/2) * ByRange / (_data_points/2) for i in range(_data_points)] # Symetric around 0
        _ic_values = [abs(5e-6 - abs(pv)*1e-3 + (angle/90)*1e-7) for pv in _param_values] # Dummy Ic values
        Ic_df = pd.DataFrame({
            "param_value": _param_values,
            "Ic": _ic_values
        })
    else:
        # This is where your actual data loading happens
        fig1, fig2, fig3, Ic_df = plot_heatmaps(dataid) 
    # --- End of Placeholder ---

    # Filter out the Ic_df
    Ic_df_filtered = Ic_df[(Ic_df["param_value"] < ByRange) & (Ic_df["param_value"] > -ByRange)].copy() # Use .copy() to avoid SettingWithCopyWarning

    if Ic_df_filtered.empty:
        print(f"Warning: Ic_df_filtered is empty for dataid {dataid} after filtering with ByRange {ByRange}. Skipping this data point for IcMax and plot trace.")
        return fig, IcMax_df

    # Find the param_value where Ic is maximal
    # Ensure 'Ic' column exists and is numeric
    if 'Ic' not in Ic_df_filtered.columns or not pd.api.types.is_numeric_dtype(Ic_df_filtered['Ic']):
        print(f"Error: 'Ic' column is missing or not numeric in Ic_df_filtered for dataid {dataid}.")
        return fig, IcMax_df
        
    By = Ic_df_filtered.loc[Ic_df_filtered["Ic"].idxmax(), "param_value"]
    Ic_max_value = Ic_df_filtered["Ic"].max()
    
    new_row_data = [{"angle": angle, "IcMax": Ic_max_value, "By": By, "dataid": dataid}]
    new_row_df = pd.DataFrame(new_row_data)
    IcMax_df = pd.concat([IcMax_df, new_row_df], ignore_index=True)
    
    # Add trace to the main figure
    fig.add_trace(go.Scatter(
        x=Ic_df_filtered["param_value"]+ByOffset,  # Out-off-plane field y_field values, unit: T
        y=Ic_df_filtered["Ic"] + Ic_offset,  # Critical current Ic values, unit: A
        mode='lines+markers',
        name=f'{angle}°{angle_label}',
        marker=dict(size=5),
        line=dict(width=2)
    ))
    
    clear_output(wait=True) # Clears the output of the cell, useful in notebooks
    return fig, IcMax_df

# --- Main Script ---
f = 2
ByOffset = 2e-3
ByRange = 5e-3
IcMax_df = pd.DataFrame(columns=["angle", "IcMax", "By", "dataid"])
fig = go.Figure()

# Define data points as a list of dictionaries for easier iteration

data_points = [
    {"dataid": 192, "angle": 0, "label": "E"},
    {"dataid": 194, "angle": 45, "label": "NE"},
    {"dataid": 177, "angle": 90, "label": "N"},
    {"dataid": 179, "angle": 135, "label": "NW"},
    {"dataid": 181, "angle": 180, "label": "W"},
    {"dataid": 183, "angle": 225, "label": "SW"},
    {"dataid": 187, "angle": 270, "label": "S"},
    {"dataid": 189, "angle": 315, "label": "SE"},
]

# Loop through the data points and process them
for point in data_points:
    fig, IcMax_df = process_and_plot_data(
        dataid=point["dataid"],
        angle=point["angle"],
        angle_label=point["label"],
        fig=fig,
        IcMax_df=IcMax_df,
        ByRange=ByRange,
        f_factor=f
    )

# Add IcMax_df trace to fig
if not IcMax_df.empty:
    fig.add_trace(go.Scatter(
        x=IcMax_df["By"],  # By values where Ic is maximal
        y=IcMax_df["IcMax"] + IcMax_df["angle"] * 1e-6 * f,  # Max Critical current Ic values, unit: A
        mode='lines+markers',
        name='IcMax',
        marker=dict(size=8, symbol='star'), # Made marker different for clarity
        line=dict(width=2, dash='dash') # Differentiated line style
    ))
else:
    print("IcMax_df is empty. Skipping the IcMax trend plot.")

# --- Figure Layout and Display ---
fig.update_layout(
    title="Ic-By@r60mT w/ In-Plane Field Angles",
    xaxis_title="Out-of-Plane Field (By) [T]",
    yaxis_title=f"Critical Current (Ic) + Offset [A] (angle*{f}e-6)",
    legend_title="Angle",
    hovermode="x unified",
    template="plotly_white",
    width=800,
    height=800,

)
fig.show()

print("\nFinal IcMax DataFrame:")
print(IcMax_df)

# %%
import pandas as pd
import plotly.graph_objects as go
from IPython.display import clear_output

# Assume plot_heatmaps is defined elsewhere and works as expected
# from your_module import plot_heatmaps # Example of how you might import it

# --- Helper Function Definition ---
def process_and_plot_data(dataid, angle, angle_label, fig, IcMax_df, ByOffset, ByRange, f_factor):
    """
    Processes data for a given angle and dataid, updates the IcMax_df,
    and adds a trace to the figure.

    Args:
        dataid (int): The ID of the dataset.
        angle (int or float): The angle in degrees.
        angle_label (str): A short label for the angle (e.g., "NE", "E").
        fig (go.Figure): The Plotly figure object to add traces to.
        IcMax_df (pd.DataFrame): DataFrame to store maximum Ic values.
        ByRange (float): The range to filter 'param_value'.
        f_factor (float): The factor 'f' used in Ic_offset calculation.

    Returns:
        tuple: Updated (fig, IcMax_df)
    """
    print(f"Processing dataid: {dataid}, angle: {angle}° ({angle_label})")
    Ic_offset = angle * 1e-6 * f_factor
    
    # Simulate plot_heatmaps if it's not available in this environment
    # In your actual code, you would call your plot_heatmaps function:
    # fig1, fig2, fig3, Ic_df = plot_heatmaps(dataid)
    
    # --- Placeholder for plot_heatmaps and Ic_df generation ---
    # Replace this with your actual plot_heatmaps call and Ic_df structure
    # For demonstration, creating a dummy Ic_df
    if 'plot_heatmaps' not in globals():
        print(f"Warning: 'plot_heatmaps' function not found. Using dummy data for dataid {dataid}.")
        _data_points = 10
        _param_values = [(i - _data_points/2) * ByRange / (_data_points/2) for i in range(_data_points)] # Symetric around 0
        _ic_values = [abs(5e-6 - abs(pv)*1e-3 + (angle/90)*1e-7) for pv in _param_values] # Dummy Ic values
        Ic_df = pd.DataFrame({
            "param_value": _param_values,
            "Ic": _ic_values
        })
    else:
        # This is where your actual data loading happens
        fig1, fig2, fig3, Ic_df = plot_heatmaps(dataid) 
    # --- End of Placeholder ---

    # Filter out the Ic_df
    Ic_df_filtered = Ic_df[(Ic_df["param_value"] < ByRange) & (Ic_df["param_value"] > -ByRange)].copy() # Use .copy() to avoid SettingWithCopyWarning

    if Ic_df_filtered.empty:
        print(f"Warning: Ic_df_filtered is empty for dataid {dataid} after filtering with ByRange {ByRange}. Skipping this data point for IcMax and plot trace.")
        return fig, IcMax_df

    # Find the param_value where Ic is maximal
    # Ensure 'Ic' column exists and is numeric
    if 'Ic' not in Ic_df_filtered.columns or not pd.api.types.is_numeric_dtype(Ic_df_filtered['Ic']):
        print(f"Error: 'Ic' column is missing or not numeric in Ic_df_filtered for dataid {dataid}.")
        return fig, IcMax_df
        
    By = Ic_df_filtered.loc[Ic_df_filtered["Ic"].idxmax(), "param_value"]
    Ic_max_value = Ic_df_filtered["Ic"].max()
    
    new_row_data = [{"angle": angle, "IcMax": Ic_max_value, "By": By, "dataid": dataid}]
    new_row_df = pd.DataFrame(new_row_data)
    IcMax_df = pd.concat([IcMax_df, new_row_df], ignore_index=True)
    
    # Add trace to the main figure
    fig.add_trace(go.Scatter(
        x=Ic_df_filtered["param_value"]+ByOffset,  # Out-off-plane field y_field values, unit: T
        y=Ic_df_filtered["Ic"] + Ic_offset,  # Critical current Ic values, unit: A
        mode='lines+markers',
        name=f'{angle}°{angle_label}',
        marker=dict(size=5),
        line=dict(width=2)
    ))
    
    clear_output(wait=True) # Clears the output of the cell, useful in notebooks
    return fig, IcMax_df

# --- Main Script ---
f = 0.2
ByRange = 10e-3
IcMax_df = pd.DataFrame(columns=["angle", "IcMax", "By", "dataid"])
fig = go.Figure()

# Define data points as a list of dictionaries for easier iteration
data_points = [
    {"dataid": 144, "angle": 0, "label": "O", "ByOffset": 0e-3},
    {"dataid": 197, "angle": 0, "label": "E", "ByOffset": 2e-3+5.5e-6},
    {"dataid": 196, "angle": 45, "label": "NE", "ByOffset": 2e-3+500e-9},
    {"dataid": 178, "angle": 90, "label": "N", "ByOffset": 0e-3+6e-6},
    {"dataid": 180, "angle": 135, "label": "NW", "ByOffset": 0e-3+7.5e-6},
    {"dataid": 186, "angle": 180, "label": "W", "ByOffset": -2e-3},
    {"dataid": 185, "angle": 225, "label": "SW", "ByOffset": -1.2e-3+6e-6},
    {"dataid": 188, "angle": 270, "label": "S", "ByOffset": 0e-3+3.5e-6},
    {"dataid": 191, "angle": 315, "label": "SE", "ByOffset": 2e-3+7.5e-6},
]

# Loop through the data points and process them
for point in data_points:
    fig, IcMax_df = process_and_plot_data(
        dataid=point["dataid"],
        angle=point["angle"],
        angle_label=point["label"],
        fig=fig,
        IcMax_df=IcMax_df,
        ByOffset=point["ByOffset"],
        ByRange=ByRange,
        f_factor=f
    )

# Add IcMax_df trace to fig
if not IcMax_df.empty:
    fig.add_trace(go.Scatter(
        x=IcMax_df["By"],  # By values where Ic is maximal
        y=IcMax_df["IcMax"] + IcMax_df["angle"] * 1e-6 * f,  # Max Critical current Ic values, unit: A
        mode='lines+markers',
        name='IcMax',
        marker=dict(size=8, symbol='star'), # Made marker different for clarity
        line=dict(width=2, dash='dash') # Differentiated line style
    ))
else:
    print("IcMax_df is empty. Skipping the IcMax trend plot.")

# --- Figure Layout and Display ---
fig.update_layout(
    title="<b>|005-1|Ic-By@r60mT| w/ In-Plane Field Angles",
    xaxis_title="Out-of-Plane Field (By) [T]",
    yaxis_title=f"Critical Current (Ic) + Offset [A] (angle*{f}e-6)",
    legend_title="Angle",
    hovermode="x unified",
    template="plotly_white",
    width=1600,
    height=800,

)
fig.show()

print("\nFinal IcMax DataFrame:")
import pandas as pd
import plotly.graph_objects as go
from IPython.display import clear_output

# Assume plot_heatmaps is defined elsewhere and works as expected
# from your_module import plot_heatmaps # Example of how you might import it

# --- Helper Function Definition ---
def process_and_plot_data(dataid, angle, angle_label, fig, IcMax_df, ByOffset, ByRange, f_factor):
    """
    Processes data for a given angle and dataid, updates the IcMax_df,
    and adds a trace to the figure.

    Args:
        dataid (int): The ID of the dataset.
        angle (int or float): The angle in degrees.
        angle_label (str): A short label for the angle (e.g., "NE", "E").
        fig (go.Figure): The Plotly figure object to add traces to.
        IcMax_df (pd.DataFrame): DataFrame to store maximum Ic values.
        ByRange (float): The range to filter 'param_value'.
        f_factor (float): The factor 'f' used in Ic_offset calculation.

    Returns:
        tuple: Updated (fig, IcMax_df)
    """
    print(f"Processing dataid: {dataid}, angle: {angle}° ({angle_label})")
    Ic_offset = angle * 1e-6 * f_factor
    
    # Simulate plot_heatmaps if it's not available in this environment
    # In your actual code, you would call your plot_heatmaps function:
    # fig1, fig2, fig3, Ic_df = plot_heatmaps(dataid)
    
    # --- Placeholder for plot_heatmaps and Ic_df generation ---
    # Replace this with your actual plot_heatmaps call and Ic_df structure
    # For demonstration, creating a dummy Ic_df
    if 'plot_heatmaps' not in globals():
        print(f"Warning: 'plot_heatmaps' function not found. Using dummy data for dataid {dataid}.")
        _data_points = 10
        _param_values = [(i - _data_points/2) * ByRange / (_data_points/2) for i in range(_data_points)] # Symetric around 0
        _ic_values = [abs(5e-6 - abs(pv)*1e-3 + (angle/90)*1e-7) for pv in _param_values] # Dummy Ic values
        Ic_df = pd.DataFrame({
            "param_value": _param_values,
            "Ic": _ic_values
        })
    else:
        # This is where your actual data loading happens
        fig1, fig2, fig3, Ic_df = plot_heatmaps(dataid) 
    # --- End of Placeholder ---

    # Filter out the Ic_df
    Ic_df_filtered = Ic_df[(Ic_df["param_value"] < ByRange) & (Ic_df["param_value"] > -ByRange)].copy() # Use .copy() to avoid SettingWithCopyWarning

    if Ic_df_filtered.empty:
        print(f"Warning: Ic_df_filtered is empty for dataid {dataid} after filtering with ByRange {ByRange}. Skipping this data point for IcMax and plot trace.")
        return fig, IcMax_df

    # Find the param_value where Ic is maximal
    # Ensure 'Ic' column exists and is numeric
    if 'Ic' not in Ic_df_filtered.columns or not pd.api.types.is_numeric_dtype(Ic_df_filtered['Ic']):
        print(f"Error: 'Ic' column is missing or not numeric in Ic_df_filtered for dataid {dataid}.")
        return fig, IcMax_df
        
    By = Ic_df_filtered.loc[Ic_df_filtered["Ic"].idxmax(), "param_value"]
    Ic_max_value = Ic_df_filtered["Ic"].max()
    
    new_row_data = [{"angle": angle, "IcMax": Ic_max_value, "By": By, "dataid": dataid}]
    new_row_df = pd.DataFrame(new_row_data)
    IcMax_df = pd.concat([IcMax_df, new_row_df], ignore_index=True)
    
    # Add trace to the main figure
    fig.add_trace(go.Scatter(
        x=Ic_df_filtered["param_value"]+ByOffset,  # Out-off-plane field y_field values, unit: T
        y=Ic_df_filtered["Ic"] + Ic_offset,  # Critical current Ic values, unit: A
        mode='lines+markers',
        name=f'{angle}°{angle_label}',
        marker=dict(size=5),
        line=dict(width=2)
    ))
    
    clear_output(wait=True) # Clears the output of the cell, useful in notebooks
    return fig, IcMax_df

# --- Main Script ---
f = 0.2
ByRange = 10e-3
IcMax_df = pd.DataFrame(columns=["angle", "IcMax", "By", "dataid"])
fig = go.Figure()

# Define data points as a list of dictionaries for easier iteration
data_points = [
    {"dataid": 144, "angle": 0, "label": "O", "ByOffset": 0e-3},
    {"dataid": 197, "angle": 0, "label": "E", "ByOffset": 2e-3+5.5e-6},
    {"dataid": 196, "angle": 45, "label": "NE", "ByOffset": 2e-3+500e-9},
    {"dataid": 178, "angle": 90, "label": "N", "ByOffset": 0e-3+6e-6},
    {"dataid": 180, "angle": 135, "label": "NW", "ByOffset": 0e-3+7.5e-6},
    {"dataid": 186, "angle": 180, "label": "W", "ByOffset": -2e-3},
    {"dataid": 185, "angle": 225, "label": "SW", "ByOffset": -1.2e-3+6e-6},
    {"dataid": 188, "angle": 270, "label": "S", "ByOffset": 0e-3+3.5e-6},
    {"dataid": 191, "angle": 315, "label": "SE", "ByOffset": 2e-3+7.5e-6},
]

# Loop through the data points and process them
for point in data_points:
    fig, IcMax_df = process_and_plot_data(
        dataid=point["dataid"],
        angle=point["angle"],
        angle_label=point["label"],
        fig=fig,
        IcMax_df=IcMax_df,
        ByOffset=point["ByOffset"],
        ByRange=ByRange,
        f_factor=f
    )

# Add IcMax_df trace to fig
if not IcMax_df.empty:
    fig.add_trace(go.Scatter(
        x=IcMax_df["By"],  # By values where Ic is maximal
        y=IcMax_df["IcMax"] + IcMax_df["angle"] * 1e-6 * f,  # Max Critical current Ic values, unit: A
        mode='lines+markers',
        name='IcMax',
        marker=dict(size=8, symbol='star'), # Made marker different for clarity
        line=dict(width=2, dash='dash') # Differentiated line style
    ))
else:
    print("IcMax_df is empty. Skipping the IcMax trend plot.")

# --- Figure Layout and Display ---
fig.update_layout(
    title="<b>|005-1|Ic-By@r60mT| w/ In-Plane Field Angles",
    xaxis_title="Out-of-Plane Field (By) [T]",
    yaxis_title=f"Critical Current (Ic) + Offset [A] (angle*{f}e-6)",
    legend_title="Angle",
    hovermode="x unified",
    template="plotly_white",
    width=1600,
    height=800,

)
fig.show()

print("\nFinal IcMax DataFrame:")
import pandas as pd
import plotly.graph_objects as go
from IPython.display import clear_output

# Assume plot_heatmaps is defined elsewhere and works as expected
# from your_module import plot_heatmaps # Example of how you might import it

# --- Helper Function Definition ---
def process_and_plot_data(dataid, angle, angle_label, fig, IcMax_df, ByOffset, ByRange, f_factor):
    """
    Processes data for a given angle and dataid, updates the IcMax_df,
    and adds a trace to the figure.

    Args:
        dataid (int): The ID of the dataset.
        angle (int or float): The angle in degrees.
        angle_label (str): A short label for the angle (e.g., "NE", "E").
        fig (go.Figure): The Plotly figure object to add traces to.
        IcMax_df (pd.DataFrame): DataFrame to store maximum Ic values.
        ByRange (float): The range to filter 'param_value'.
        f_factor (float): The factor 'f' used in Ic_offset calculation.

    Returns:
        tuple: Updated (fig, IcMax_df)
    """
    print(f"Processing dataid: {dataid}, angle: {angle}° ({angle_label})")
    Ic_offset = angle * 1e-6 * f_factor
    
    # Simulate plot_heatmaps if it's not available in this environment
    # In your actual code, you would call your plot_heatmaps function:
    # fig1, fig2, fig3, Ic_df = plot_heatmaps(dataid)
    
    # --- Placeholder for plot_heatmaps and Ic_df generation ---
    # Replace this with your actual plot_heatmaps call and Ic_df structure
    # For demonstration, creating a dummy Ic_df
    if 'plot_heatmaps' not in globals():
        print(f"Warning: 'plot_heatmaps' function not found. Using dummy data for dataid {dataid}.")
        _data_points = 10
        _param_values = [(i - _data_points/2) * ByRange / (_data_points/2) for i in range(_data_points)] # Symetric around 0
        _ic_values = [abs(5e-6 - abs(pv)*1e-3 + (angle/90)*1e-7) for pv in _param_values] # Dummy Ic values
        Ic_df = pd.DataFrame({
            "param_value": _param_values,
            "Ic": _ic_values
        })
    else:
        # This is where your actual data loading happens
        fig1, fig2, fig3, Ic_df = plot_heatmaps(dataid) 
    # --- End of Placeholder ---

    # Filter out the Ic_df
    Ic_df_filtered = Ic_df[(Ic_df["param_value"] < ByRange) & (Ic_df["param_value"] > -ByRange)].copy() # Use .copy() to avoid SettingWithCopyWarning

    if Ic_df_filtered.empty:
        print(f"Warning: Ic_df_filtered is empty for dataid {dataid} after filtering with ByRange {ByRange}. Skipping this data point for IcMax and plot trace.")
        return fig, IcMax_df

    # Find the param_value where Ic is maximal
    # Ensure 'Ic' column exists and is numeric
    if 'Ic' not in Ic_df_filtered.columns or not pd.api.types.is_numeric_dtype(Ic_df_filtered['Ic']):
        print(f"Error: 'Ic' column is missing or not numeric in Ic_df_filtered for dataid {dataid}.")
        return fig, IcMax_df
        
    By = Ic_df_filtered.loc[Ic_df_filtered["Ic"].idxmax(), "param_value"]
    Ic_max_value = Ic_df_filtered["Ic"].max()
    
    new_row_data = [{"angle": angle, "IcMax": Ic_max_value, "By": By, "dataid": dataid}]
    new_row_df = pd.DataFrame(new_row_data)
    IcMax_df = pd.concat([IcMax_df, new_row_df], ignore_index=True)
    
    # Add trace to the main figure
    fig.add_trace(go.Scatter(
        x=Ic_df_filtered["param_value"]+ByOffset,  # Out-off-plane field y_field values, unit: T
        y=Ic_df_filtered["Ic"] + Ic_offset,  # Critical current Ic values, unit: A
        mode='lines+markers',
        name=f'{angle}°{angle_label}',
        marker=dict(size=5),
        line=dict(width=2)
    ))
    
    clear_output(wait=True) # Clears the output of the cell, useful in notebooks
    return fig, IcMax_df

# --- Main Script ---
f = 0.2
ByRange = 10e-3
IcMax_df = pd.DataFrame(columns=["angle", "IcMax", "By", "dataid"])
fig = go.Figure()

# Define data points as a list of dictionaries for easier iteration
data_points = [
    {"dataid": 144, "angle": 0, "label": "O", "ByOffset": 0e-3},
    {"dataid": 197, "angle": 0, "label": "E", "ByOffset": 2e-3+5.5e-6},
    {"dataid": 196, "angle": 45, "label": "NE", "ByOffset": 2e-3+500e-9},
    {"dataid": 178, "angle": 90, "label": "N", "ByOffset": 0e-3+6e-6},
    {"dataid": 180, "angle": 135, "label": "NW", "ByOffset": 0e-3+7.5e-6},
    {"dataid": 186, "angle": 180, "label": "W", "ByOffset": -2e-3},
    {"dataid": 185, "angle": 225, "label": "SW", "ByOffset": -1.2e-3+6e-6},
    {"dataid": 188, "angle": 270, "label": "S", "ByOffset": 0e-3+3.5e-6},
    {"dataid": 191, "angle": 315, "label": "SE", "ByOffset": 2e-3+7.5e-6},
]

# Loop through the data points and process them
for point in data_points:
    fig, IcMax_df = process_and_plot_data(
        dataid=point["dataid"],
        angle=point["angle"],
        angle_label=point["label"],
        fig=fig,
        IcMax_df=IcMax_df,
        ByOffset=point["ByOffset"],
        ByRange=ByRange,
        f_factor=f
    )

# Add IcMax_df trace to fig
if not IcMax_df.empty:
    fig.add_trace(go.Scatter(
        x=IcMax_df["By"],  # By values where Ic is maximal
        y=IcMax_df["IcMax"] + IcMax_df["angle"] * 1e-6 * f,  # Max Critical current Ic values, unit: A
        mode='lines+markers',
        name='IcMax',
        marker=dict(size=8, symbol='star'), # Made marker different for clarity
        line=dict(width=2, dash='dash') # Differentiated line style
    ))
else:
    print("IcMax_df is empty. Skipping the IcMax trend plot.")

# --- Figure Layout and Display ---
fig.update_layout(
    title="<b>|005-1|Ic-By@r60mT| w/ In-Plane Field Angles",
    xaxis_title="Out-of-Plane Field (By) [T]",
    yaxis_title=f"Critical Current (Ic) + Offset [A] (angle*{f}e-6)",
    legend_title="Angle",
    hovermode="x unified",
    template="plotly_white",
    width=1600,
    height=800,

)
fig.show()

print("\nFinal IcMax DataFrame:")
print(IcMax_df)

# %%
import pandas as pd
import plotly.graph_objects as go
from IPython.display import clear_output

# Assume plot_heatmaps is defined elsewhere and works as expected
# from your_module import plot_heatmaps # Example of how you might import it

# --- Helper Function Definition ---
def process_and_plot_data(dataid, angle, angle_label, fig, IcMax_df, ByOffset, ByRange, f_factor):
    """
    Processes data for a given angle and dataid, updates the IcMax_df,
    and adds a trace to the figure.

    Args:
        dataid (int): The ID of the dataset.
        angle (int or float): The angle in degrees.
        angle_label (str): A short label for the angle (e.g., "NE", "E").
        fig (go.Figure): The Plotly figure object to add traces to.
        IcMax_df (pd.DataFrame): DataFrame to store maximum Ic values.
        ByRange (float): The range to filter 'param_value'.
        f_factor (float): The factor 'f' used in Ic_offset calculation.

    Returns:
        tuple: Updated (fig, IcMax_df)
    """
    print(f"Processing dataid: {dataid}, angle: {angle}° ({angle_label})")
    Ic_offset = angle * 1e-6 * f_factor
    
    # Simulate plot_heatmaps if it's not available in this environment
    # In your actual code, you would call your plot_heatmaps function:
    # fig1, fig2, fig3, Ic_df = plot_heatmaps(dataid)
    
    # --- Placeholder for plot_heatmaps and Ic_df generation ---
    # Replace this with your actual plot_heatmaps call and Ic_df structure
    # For demonstration, creating a dummy Ic_df
    if 'plot_heatmaps' not in globals():
        print(f"Warning: 'plot_heatmaps' function not found. Using dummy data for dataid {dataid}.")
        _data_points = 10
        _param_values = [(i - _data_points/2) * ByRange / (_data_points/2) for i in range(_data_points)] # Symetric around 0
        _ic_values = [abs(5e-6 - abs(pv)*1e-3 + (angle/90)*1e-7) for pv in _param_values] # Dummy Ic values
        Ic_df = pd.DataFrame({
            "param_value": _param_values,
            "Ic": _ic_values
        })
    else:
        # This is where your actual data loading happens
        fig1, fig2, fig3, Ic_df = plot_heatmaps(dataid) 
    # --- End of Placeholder ---

    # Filter out the Ic_df
    Ic_df_filtered = Ic_df[(Ic_df["param_value"] < ByRange) & (Ic_df["param_value"] > -ByRange)].copy() # Use .copy() to avoid SettingWithCopyWarning

    if Ic_df_filtered.empty:
        print(f"Warning: Ic_df_filtered is empty for dataid {dataid} after filtering with ByRange {ByRange}. Skipping this data point for IcMax and plot trace.")
        return fig, IcMax_df

    # Find the param_value where Ic is maximal
    # Ensure 'Ic' column exists and is numeric
    if 'Ic' not in Ic_df_filtered.columns or not pd.api.types.is_numeric_dtype(Ic_df_filtered['Ic']):
        print(f"Error: 'Ic' column is missing or not numeric in Ic_df_filtered for dataid {dataid}.")
        return fig, IcMax_df
        
    By = Ic_df_filtered.loc[Ic_df_filtered["Ic"].idxmax(), "param_value"]
    Ic_max_value = Ic_df_filtered["Ic"].max()
    
    new_row_data = [{"angle": angle, "IcMax": Ic_max_value, "By": By, "dataid": dataid}]
    new_row_df = pd.DataFrame(new_row_data)
    IcMax_df = pd.concat([IcMax_df, new_row_df], ignore_index=True)
    
    # Add trace to the main figure
    fig.add_trace(go.Scatter(
        x=Ic_df_filtered["param_value"]+ByOffset,  # Out-off-plane field y_field values, unit: T
        y=Ic_df_filtered["Ic"] + Ic_offset,  # Critical current Ic values, unit: A
        mode='lines+markers',
        name=f'{angle}°{angle_label}{dataid}',
        marker=dict(size=5),
        line=dict(width=2)
    ))
    
    clear_output(wait=True) # Clears the output of the cell, useful in notebooks
    return fig, IcMax_df

# --- Main Script ---
f = 0.2
ByRange = 10e-3
IcMax_df = pd.DataFrame(columns=["angle", "IcMax", "By", "dataid"])
fig = go.Figure()

# Define data points as a list of dictionaries for easier iteration
data_points = [
    {"dataid": 251, "angle": 0, "label": "O", "ByOffset": 0e-3+12e-6},
    {"dataid": 230, "angle": 0, "label": "E", "ByOffset": 2.5e-3+13.7e-6},
    {"dataid": 235, "angle": 45, "label": "NE", "ByOffset": 2e-3+10e-6+700e-9},
    {"dataid": 240, "angle": 90, "label": "N", "ByOffset": 0.3e-3+9.1e-6},
    {"dataid": 201, "angle": 90, "label": "N", "ByOffset": 0.e-3+22.5e-6},
    {"dataid": 242, "angle": 135, "label": "NW", "ByOffset": -1e-3+11.7e-6},
    {"dataid": 204, "angle": 135, "label": "NW", "ByOffset": -1e-3+66e-6},
    {"dataid": 254, "angle": 180, "label": "W", "ByOffset": -1.75e-3+10e-6},
    {"dataid": 206, "angle": 180, "label": "W", "ByOffset": -1.75e-3+274e-6},
    {"dataid": 252, "angle": 225, "label": "SW", "ByOffset": -1.25e-3+8.2e-6},
    {"dataid": 213, "angle": 270, "label": "S", "ByOffset": 0.1e-3+9.7e-6},
    {"dataid": 208, "angle": 225, "label": "SW", "ByOffset": -1.25e-3+261.5e-6},
    {"dataid": 223, "angle": 315, "label": "SE", "ByOffset": 1.75e-3+9.5e-6},
]

# Loop through the data points and process them
for point in data_points:
    fig, IcMax_df = process_and_plot_data(
        dataid=point["dataid"],
        angle=point["angle"],
        angle_label=point["label"],
        fig=fig,
        IcMax_df=IcMax_df,
        ByOffset=point["ByOffset"],
        ByRange=ByRange,
        f_factor=f
    )

# Add IcMax_df trace to fig
# if not IcMax_df.empty:
    # fig.add_trace(go.Scatter(
    #     x=IcMax_df["By"],  # By values where Ic is maximal
    #     y=IcMax_df["IcMax"] + IcMax_df["angle"] * 1e-6 * f,  # Max Critical current Ic values, unit: A
    #     mode='lines+markers',
    #     name='IcMax',
    #     marker=dict(size=8, symbol='star'), # Made marker different for clarity
    #     line=dict(width=2, dash='dash') # Differentiated line style
    # ))
# else:
print("IcMax_df is empty. Skipping the IcMax trend plot.")

# --- Figure Layout and Display ---
fig.update_layout(
    title="<b>|005-2|Ic-By@r60mT| w/ In-Plane Field Angles",
    xaxis_title="Out-of-Plane Field (By) [T]",
    yaxis_title=f"Critical Current (Ic) + Offset [A] (angle*{f}e-6)",
    legend_title="Angle",
    hovermode="x unified",
    template="plotly_white",
    # width=1600,
    # height=1000,

)
fig.show()

print("\nFinal IcMax DataFrame:")
print(IcMax_df)

# %%
import pandas as pd
import plotly.graph_objects as go
from IPython.display import clear_output

# Assume plot_heatmaps is defined elsewhere and works as expected
# from your_module import plot_heatmaps # Example of how you might import it

# --- Helper Function Definition (Modified) ---
def process_and_plot_data(dataid, angle, angle_label, fig, IcMax_df, ByRange, f_factor):
    """
    Processes data for a given angle and dataid, updates the IcMax_df,
    adds a trace to the figure, and returns the filtered Ic_df.

    Args:
        dataid (int): The ID of the dataset.
        angle (int or float): The angle in degrees.
        angle_label (str): A short label for the angle (e.g., "NE", "E").
        fig (go.Figure): The Plotly figure object to add traces to.
        IcMax_df (pd.DataFrame): DataFrame to store maximum Ic values.
        ByRange (float): The range to filter 'param_value'.
        f_factor (float): The factor 'f' used in Ic_offset calculation.

    Returns:
        tuple: Updated (fig, IcMax_df, Ic_df_filtered)
    """
    print(f"Processing dataid: {dataid}, angle: {angle}° ({angle_label})")
    Ic_offset = angle * 1e-6 * f_factor
    
    # --- Placeholder for plot_heatmaps and Ic_df generation ---
    if 'plot_heatmaps' not in globals():
        # print(f"Warning: 'plot_heatmaps' function not found. Using dummy data for dataid {dataid}.")
        _data_points = 10 # Number of points for By
        # Symmetrically distributed param_values around 0, within ByRange
        _param_values = [(val / (_data_points / 2 -1)) * ByRange if _data_points > 1 else 0 for val in range(-int(_data_points/2)+1, int(_data_points/2)+1)]
        _param_values = sorted(list(set(_param_values))) # Ensure unique and sorted values
        if not _param_values and ByRange == 0: # Handle edge case where ByRange is 0
             _param_values = [0.0]
        elif not _param_values and _data_points ==1:
             _param_values = [0.0]


        # Dummy Ic values that somewhat decrease away from param_value = 0 and vary with angle
        _ic_values = [
            max(0, 5e-6 - abs(pv) * 5e-4 - (abs(angle - 180)/180)*2e-6 + (0 if pv !=0 else 0.5e-6 * ( (180-abs(angle-180))/180 ) ) ) 
            for pv in _param_values
        ]
        Ic_df = pd.DataFrame({
            "param_value": _param_values,
            "Ic": _ic_values
        })
        # fig1, fig2, fig3 are not used by this function if we only use dummy data
    else:
        fig1, fig2, fig3, Ic_df = plot_heatmaps(dataid)
    # --- End of Placeholder ---

    Ic_df_filtered = Ic_df[(Ic_df["param_value"] <= ByRange) & (Ic_df["param_value"] >= -ByRange)].copy()

    if Ic_df_filtered.empty:
        print(f"Warning: Ic_df_filtered is empty for dataid {dataid} after filtering with ByRange {ByRange}. Skipping this data point for IcMax and plot trace.")
        return fig, IcMax_df, Ic_df_filtered # Return empty DF for consistency

    if 'Ic' not in Ic_df_filtered.columns or not pd.api.types.is_numeric_dtype(Ic_df_filtered['Ic']):
        print(f"Error: 'Ic' column is missing or not numeric in Ic_df_filtered for dataid {dataid}.")
        # Return the current state and an empty df for Ic_df_filtered to signal error
        return fig, IcMax_df, pd.DataFrame(columns=['param_value', 'Ic']) 

    By = Ic_df_filtered.loc[Ic_df_filtered["Ic"].idxmax(), "param_value"]
    Ic_max_value = Ic_df_filtered["Ic"].max()
    
    new_row_data = [{"angle": angle, "IcMax": Ic_max_value, "By": By, "dataid": dataid}]
    new_row_df = pd.DataFrame(new_row_data)
    IcMax_df = pd.concat([IcMax_df, new_row_df], ignore_index=True)
    
    fig.add_trace(go.Scatter(
        x=Ic_df_filtered["param_value"],
        y=Ic_df_filtered["Ic"] + Ic_offset,
        mode='lines+markers',
        name=f'{angle}°{angle_label}{dataid}',
        marker=dict(size=5),
        line=dict(width=2)
    ))
    
    # clear_output(wait=True) # Commented out for potentially faster processing in loops if output is large
    return fig, IcMax_df, Ic_df_filtered # Return the filtered DataFrame

# --- Main Script ---
f = 2
ByRange = 5e-3 # Max By value for X-axis of heatmap and for filtering individual traces
IcMax_df = pd.DataFrame(columns=["angle", "IcMax", "By", "dataid"])
fig = go.Figure()

data_points = [
    {"dataid": 194, "angle": 45, "label": "NE"},
    {"dataid": 192, "angle": 0, "label": "E"},
    {"dataid": 189, "angle": 315, "label": "SE"},
    {"dataid": 187, "angle": 270, "label": "S"},
    {"dataid": 183, "angle": 225, "label": "SW"},
    {"dataid": 181, "angle": 180, "label": "W"},
    {"dataid": 179, "angle": 135, "label": "NW"},
    {"dataid": 177, "angle": 90, "label": "N"},
]

all_dfs_for_heatmap = [] # To collect DataFrames for the heatmap

# Loop through the data points and process them
for point in data_points:
    fig, IcMax_df, current_Ic_df_filtered = process_and_plot_data(
        dataid=point["dataid"],
        angle=point["angle"],
        angle_label=point["label"],
        fig=fig,
        IcMax_df=IcMax_df,
        ByRange=ByRange,
        f_factor=f
    )
    if current_Ic_df_filtered is not None and not current_Ic_df_filtered.empty:
        # Select only necessary columns and add the angle for heatmap construction
        df_slice = current_Ic_df_filtered[['param_value', 'Ic']].copy()
        df_slice['angle'] = point["angle"]
        all_dfs_for_heatmap.append(df_slice)

clear_output(wait=True) # Clear output once after all processing

# Add IcMax_df trace to the scatter fig
if not IcMax_df.empty:
    fig.add_trace(go.Scatter(
        x=IcMax_df["By"],
        y=IcMax_df["IcMax"] + IcMax_df["angle"] * 1e-6 * f,
        mode='lines+markers',
        name='IcMax Trend',
        marker=dict(size=8, symbol='star'),
        line=dict(width=2, dash='dash')
    ))
else:
    print("IcMax_df is empty. Skipping the IcMax trend plot.")

fig.update_layout(
    title="Critical Current (Ic) vs. Out-of-Plane Field (By) at Different Angles",
    xaxis_title=f"Out-of-Plane Field (By) [T] (within ±{ByRange:.0e} T)",
    yaxis_title=f"Critical Current (Ic) + Offset [A] (Offset = angle * 1e-6 * {f})",
    legend_title="Measurement Angle & ID",
    hovermode="x unified",
    width=800,
    height=800,
    template="plotly_white"
)
fig.show()

print("\nFinal IcMax DataFrame:")
print(IcMax_df)

# --- Heatmap Generation ---
if all_dfs_for_heatmap:
    heatmap_source_data = pd.concat(all_dfs_for_heatmap, ignore_index=True)
    
    if not heatmap_source_data.empty and 'param_value' in heatmap_source_data and 'angle' in heatmap_source_data and 'Ic' in heatmap_source_data:
        try:
            # Create the pivot table: angles as rows, By (param_value) as columns, Ic as values
            pivot_table = heatmap_source_data.pivot_table(
                index='angle', 
                columns='param_value', 
                values='Ic'
            )
            
            # Sort index (angles) and columns (By values) for an ordered heatmap
            pivot_table = pivot_table.sort_index(axis=0)  # Sort by angle (Y-axis)
            pivot_table = pivot_table.sort_index(axis=1)  # Sort by param_value (X-axis)

            heatmap_fig = go.Figure(data=go.Heatmap(
                z=pivot_table.values,    # 2D array of Ic values
                x=pivot_table.columns,   # By (param_value)
                y=pivot_table.index,     # Angles
                colorscale='RdBu',    # Example colorscale
                colorbar=dict(title='Ic [A]'),
                connectgaps=False,
            ))
            
            heatmap_fig.update_layout(
                title='Critical Current (Ic) Heatmap@r60mT',
                xaxis_title=f"Out-of-Plane Field (By) [T] (within ±{ByRange:.0e} T)",
                yaxis_title='Angle [degrees]',
                # xaxis_type='linear' # Default, should work if param_value is numeric
                yaxis_type='category', # Angles are distinct categories
                width=800,
                height=800,
                template="plotly_white"
            )
            heatmap_fig.show()
            
        except Exception as e:
            print(f"Could not generate heatmap. Error: {e}")
            print("Sample of data intended for pivot table:")
            print(heatmap_source_data.head())
    else:
        print("Source data for heatmap is empty or missing required columns ('param_value', 'angle', 'Ic').")
else:
    print("No data was collected to generate the heatmap (all_dfs_for_heatmap list is empty).")

# %%
IcMax_df

# %%
# range=[-0.05e-3, 0.05e-3]
fig1.data[0].update(zmin=-10e-6, zmax=0e-6)
# fig1.update_xaxes(range=range) 
fig1.show()
fig2.data[0].update(zmin=0, zmax=0.3)
# fig2.update_xaxes(range=range)
fig2.show()
# fig3.update_xaxes(range=range) 
fig3.update_yaxes(range=[130e-6, 140e-6])
fig3.show()

# %%
# Critical current IcMax comparison with fixed In-plane field value but different angles

# Re-importing your existing functions to ensure they are defined in this block
# (assuming you are running this in an environment where the previous cells are executed)
# from __main__ import info_df, analyze_iv_curve, get_dataset_info, SI, ureg, FitResult, polyfit, constfit, print_fit_result, _display_time, cached_load_dataset

def get_ic_dataframe(runids):
    """
    Extracts critical current (Ic) and other relevant parameters for a list of QCoDeS run IDs
    and returns them as a Pandas DataFrame. It mimics the Ic extraction logic
    used for the fig3 plot in plot_heatmaps to get a single representative Ic value per runid.

    Args:
        runids (list of int): A list of QCoDeS run IDs to analyze.

    Returns:
        pd.DataFrame: A DataFrame containing 'runid', 'Ic', 'Ir', 'R_fit', and other
                      analysis results for each run. Returns an empty DataFrame if no data is found.
    """
    if not isinstance(runids, list):
        print("Warning: 'runids' should be a list. Converting to list.")
        runids = [runids]

    all_ic_data = []

    print(f"Starting Ic extraction for {len(runids)} runs...")
    for runid in tqdm(runids, desc="Processing runs"):
        try:
            # Load dataset information and DataFrame
            setpoint_params, dependent_param, param_info, df = info_df(runid)
            exp_name, sample_name, param_units, start_time, completed_time, run_time, display_time = get_dataset_info(runid)

            # Identify current and voltage parameters from the dataset
            current_param = next((p for p in setpoint_params if 'curr' in p.lower()), None)
            voltage_param = dependent_param # By convention, dependent_param is usually voltage

            if current_param is None:
                print(f"Warning: No current parameter found in runid {runid}. Skipping.")
                continue

            # Find the 'outer loop' parameter which is typically the first setpoint parameter
            # that is NOT the current_param. This is what you were using as x_param in plot_heatmaps.
            outer_loop_param = None
            for sp in setpoint_params:
                if sp != current_param:
                    outer_loop_param = sp
                    break

            ic_values_for_run = []
            ir_values_for_run = []

            # Determine the overall scan direction of the current for the run
            # This logic comes from your plot_heatmaps to decide 'Ic+' or 'Ic-'
            y_min_overall, y_max_overall = df[current_param].min(), df[current_param].max()
            if abs(y_max_overall) > abs(y_min_overall) and y_max_overall > 0:
                scan_direction_for_run = 'Ic+' # Positive dominant sweep
            elif abs(y_min_overall) > abs(y_max_overall) and y_min_overall < 0:
                scan_direction_for_run = 'Ic-' # Negative dominant sweep
            else:
                # If symmetric or mostly zero, default to positive or handle as needed
                scan_direction_for_run = 'Ic+'
                
            # If there's an outer loop parameter, iterate over its unique values
            # and analyze each IV curve separately.
            if outer_loop_param:
                for outer_param_value, group_df in df.groupby(outer_loop_param):
                    # Ensure the group_df is sorted by current_param before analysis
                    group_df_sorted = group_df.sort_values(by=current_param).reset_index(drop=True)
                    analysis = analyze_iv_curve(group_df_sorted, x_param=current_param, y_param=voltage_param, dvdi_param='dV_dI')
                    
                    # Store both Ic and Ir from each analysis, as we might need both
                    ic_values_for_run.append(analysis['Ic'])
                    ir_values_for_run.append(analysis['Ir'])
            else:
                # If no outer loop param, it's a single IV curve for the whole run
                df_sorted = df.sort_values(by=current_param).reset_index(drop=True)
                analysis = analyze_iv_curve(df_sorted, x_param=current_param, y_param=voltage_param, dvdi_param='dV_dI')
                ic_values_for_run.append(analysis['Ic'])
                ir_values_for_run.append(analysis['Ir'])


            # Now, based on the overall scan direction, determine the representative Ic for the runid
            representative_ic = np.nan
            if scan_direction_for_run == 'Ic+':
                # Take the max positive Ic from all sweeps within this run
                valid_ics = [val for val in ic_values_for_run if np.isfinite(val) and val > 0]
                if valid_ics:
                    representative_ic = max(valid_ics)
                else:
                    # Fallback if no positive Ic found, perhaps use max absolute if it's the only one
                    valid_all_ics = [val for val in ic_values_for_run if np.isfinite(val)]
                    if valid_all_ics:
                         representative_ic = max(valid_all_ics, key=abs)

            elif scan_direction_for_run == 'Ic-':
                # Take the min (most negative) Ir from all sweeps within this run
                valid_irs = [val for val in ir_values_for_run if np.isfinite(val) and val < 0]
                if valid_irs:
                    representative_ic = min(valid_irs)
                else:
                    # Fallback if no negative Ir found
                    valid_all_irs = [val for val in ir_values_for_run if np.isfinite(val)]
                    if valid_all_irs:
                        representative_ic = min(valid_all_irs, key=abs) # If it's negative, `min(abs)` is largest magnitude negative
            
            # If no specific direction was determined or no valid Ic values:
            if np.isnan(representative_ic):
                # As a last resort, if all else fails, take the maximum absolute Ic from all
                # positive Ic values or negative Ir values that were found.
                all_valid_critical_currents = [val for val in ic_values_for_run + ir_values_for_run if np.isfinite(val)]
                if all_valid_critical_currents:
                    representative_ic = max(all_valid_critical_currents, key=abs)


            # Get some additional info to add to the DataFrame, e.g., sample_name
            # and potentially the value of the outer_loop_param if it's constant for the run
            outer_param_value_for_run = None
            if outer_loop_param and len(df[outer_loop_param].unique()) == 1:
                outer_param_value_for_run = df[outer_loop_param].iloc[0]


            run_data = {
                'runid': runid,
                'sample_name': sample_name,
                'exp_name': exp_name,
                'Ic': representative_ic,
                'scan_direction_inferred': scan_direction_for_run,
                f'outer_loop_param_{outer_loop_param}': outer_param_value_for_run if outer_loop_param else 'N/A'
                # You can add more aggregate data here if needed, e.g., avg R_fit for the run
            }
            all_ic_data.append(run_data)

        except Exception as e:
            print(f"Error processing runid {runid}: {e}")
            continue

    if not all_ic_data:
        print("No Ic data was extracted. Please check your runids and dataset structure.")
        return pd.DataFrame() # Return an empty DataFrame

    df_ic_results = pd.DataFrame(all_ic_data)
    
    # Reorder columns for better readability
    cols = ['runid', 'sample_name', 'exp_name', 'scan_direction_inferred', 'Ic']
    if outer_loop_param:
        cols.insert(4, f'outer_loop_param_{outer_loop_param}')
    
    # Ensure all columns exist before reordering
    cols = [c for c in cols if c in df_ic_results.columns]
    
    return df_ic_results[cols]

# Assuming you have runids where each runid might contain multiple IV sweeps
# (e.g., IV curves taken at different magnetic field values within one run).
# The 'Ic' in the output DataFrame will be the maximum Ic from that run.
my_measurement_runids = [151, 150] # Replace with your actual run IDs

ic_data_df = get_ic_dataframe(my_measurement_runids)

print("\n--- Extracted Ic Data DataFrame ---")
print(ic_data_df)

# You can now easily access specific columns, e.g.:
# print(ic_data_df['Ic'])
# print(ic_data_df[ic_data_df['sample_name'] == 'MySample1'])

# %%
ic_data_df

# %%
import pandas as pd
import plotly.graph_objects as go
from IPython.display import clear_output

# Assume plot_heatmaps is defined elsewhere and works as expected
# from your_module import plot_heatmaps # Example of how you might import it

# --- Helper Function Definition ---
def process_and_plot_data(dataid, angle, angle_label, fig, IcMax_df, ByOffset, ByRange, f_factor):
    """
    Processes data for a given angle and dataid, updates the IcMax_df,
    and adds a trace to the figure.
    The 'param_value' for each trace is shifted so its minimum becomes 0,
    then ByOffset is added.

    Args:
        dataid (int): The ID of the dataset.
        angle (int or float): The angle in degrees.
        angle_label (str): A short label for the angle (e.g., "NE", "E").
        fig (go.Figure): The Plotly figure object to add traces to.
        IcMax_df (pd.DataFrame): DataFrame to store maximum Ic values.
        ByOffset (float): The offset to apply to the x-values AFTER aligning data start to 0.
        ByRange (float): The range to filter 'param_value'.
        f_factor (float): The factor 'f' used in Ic_offset calculation.

    Returns:
        tuple: Updated (fig, IcMax_df)
    """
    print(f"Processing dataid: {dataid}, angle: {angle}° ({angle_label})")
    Ic_offset = angle * 1e-6 * f_factor
    
    # --- Placeholder for plot_heatmaps and Ic_df generation ---
    if 'plot_heatmaps' not in globals():
        print(f"Warning: 'plot_heatmaps' function not found. Using dummy data for dataid {dataid}.")
        _data_points = 10
        # Ensure _param_values have some variation to make min() meaningful
        _base_param_values = [(i - _data_points/2 + 0.5) * ByRange / (_data_points/2) for i in range(_data_points)] 
        # Add a small unique offset per dataid to simulate different raw start points
        _param_values = [pv + (dataid * 1e-4) for pv in _base_param_values] 
        _ic_values = [abs(5e-6 - abs(pv - (dataid*1e-4))*1e-3 + (angle/90)*1e-7) for pv in _param_values] # Dummy Ic values
        Ic_df = pd.DataFrame({
            "param_value": _param_values,
            "Ic": _ic_values
        })
    else:
        # This is where your actual data loading happens
        fig1, fig2, fig3, Ic_df = plot_heatmaps(dataid) 
    # --- End of Placeholder ---

    # Filter out the Ic_df
    Ic_df_filtered = Ic_df[(Ic_df["param_value"] < Ic_df["param_value"].min() + 2*ByRange) & (Ic_df["param_value"] > Ic_df["param_value"].min() - 2*ByRange)].copy()
    # More robust filtering based on a range around the mean or median if ByRange is relative
    # For now, let's assume ByRange is an absolute limit for the spread of relevant data
    # Or, if param_value is already somewhat centered, the original filter might be fine:
    # Ic_df_filtered = Ic_df[(Ic_df["param_value"] < ByRange) & (Ic_df["param_value"] > -ByRange)].copy()
    # Reinstating original filter logic if dummy data is designed for it:
    # For dummy data, ensure it's generated around some reference, then filter.
    # The dummy _param_values are generated centered around 0 (before the dataid shift).
    # If using real data, ensure ByRange is appropriate for raw param_values.
    # A simple way to ensure the filter is meaningful with shifted data:
    # Let's assume ByRange defines the *width* of data to consider.
    # For now, falling back to your original filter and adjusting dummy data if necessary.
    # The current dummy data is generated with a spread related to ByRange.
    # Re-evaluating the filter: The original filter `(Ic_df["param_value"] < ByRange) & (Ic_df["param_value"] > -ByRange)`
    # assumes param_value is somewhat centered around 0, or that ByRange is a global limit.
    # Let's make the filter more adaptive or stick to the original if it has a specific meaning.
    # Given the alignment, let's filter first, then align.
    
    # Filter Ic_df based on param_value range *before* alignment
    # This assumes ByRange is a window relative to some central point of the raw data or absolute values
    # For simplicity, let's use the original filtering approach. If your raw data's `param_value`
    # is not centered around 0, this filter might need adjustment.
    Ic_df_filtered = Ic_df[(Ic_df["param_value"] < ByRange) & (Ic_df["param_value"] > -ByRange)].copy()


    if Ic_df_filtered.empty:
        print(f"Warning: Ic_df_filtered is empty for dataid {dataid} after filtering with ByRange {ByRange}. Check filter or data source. Skipping this data point.")
        return fig, IcMax_df

    # --- Alignment Step ---
    # Find the minimum of the 'param_value' in the filtered data
    min_param_value = Ic_df_filtered["param_value"].min()
    
    # Shift the 'param_value's so the minimum is 0, then add the ByOffset
    # This will be used for plotting the trace
    plot_x_values = (Ic_df_filtered["param_value"] - min_param_value) + ByOffset
    # --- End of Alignment Step ---

    # Ensure 'Ic' column exists and is numeric
    if 'Ic' not in Ic_df_filtered.columns or not pd.api.types.is_numeric_dtype(Ic_df_filtered['Ic']):
        print(f"Error: 'Ic' column is missing or not numeric in Ic_df_filtered for dataid {dataid}.")
        return fig, IcMax_df
        
    # Find the original param_value where Ic is maximal from the filtered (but not yet x-shifted for plot) data
    By_original = Ic_df_filtered.loc[Ic_df_filtered["Ic"].idxmax(), "param_value"]
    Ic_max_value = Ic_df_filtered["Ic"].max()
    
    # Apply the same alignment transformation to this By_original for storing in IcMax_df
    By_aligned_for_plot = (By_original - min_param_value) + ByOffset
    
    new_row_data = [{"angle": angle, "IcMax": Ic_max_value, "By": By_aligned_for_plot, "dataid": dataid}]
    new_row_df = pd.DataFrame(new_row_data)
    IcMax_df = pd.concat([IcMax_df, new_row_df], ignore_index=True)
    
    # Add trace to the main figure using the aligned x_values
    fig.add_trace(go.Scatter(
        x=plot_x_values,  # Use the aligned and offsetted x-values
        y=Ic_df_filtered["Ic"] + Ic_offset,  # Critical current Ic values, unit: A
        mode='lines+markers',
        name=f'{angle}°{angle_label}{dataid}',
        marker=dict(size=5),
        line=dict(width=2)
    ))
    
    clear_output(wait=True) # Clears the output of the cell, useful in notebooks
    return fig, IcMax_df

# --- Main Script ---
f = 0.2
ByRange = 10e-3 # This range is used for filtering param_value *before* alignment.
                # Ensure it's appropriate for your raw data's scale.
IcMax_df = pd.DataFrame(columns=["angle", "IcMax", "By", "dataid"])
fig = go.Figure()

# Define data points as a list of dictionaries for easier iteration
data_points = [
    {"dataid": 144, "angle": 0, "label": "O", "ByOffset": 0e-6},
    {"dataid": 197, "angle": 0, "label": "E", "ByOffset": 0e-6}, # Starts at x=0.0020055
    {"dataid": 196, "angle": 45, "label": "NE", "ByOffset": 0e-6},# Starts at x=0.0020005
    {"dataid": 178, "angle": 90, "label": "N", "ByOffset": 0e-6},  # Starts at x=0.000006
    {"dataid": 180, "angle": 135, "label": "NW", "ByOffset": 0e-6},# Starts at x=0.0000075
    {"dataid": 186, "angle": 180, "label": "W", "ByOffset": 0e-6},       # Starts at x=-0.002
    {"dataid": 185, "angle": 225, "label": "SW", "ByOffset": 0e-6},# Starts at x=-0.001194
    {"dataid": 188, "angle": 270, "label": "S", "ByOffset": 0e-6}, # Starts at x=0.0000035
    {"dataid": 191, "angle": 315, "label": "SE", "ByOffset": 0e-6},# Starts at x=0.0020075
]

# Loop through the data points and process them
for point in data_points:
    fig, IcMax_df = process_and_plot_data(
        dataid=point["dataid"],
        angle=point["angle"],
        angle_label=point["label"],
        fig=fig,
        IcMax_df=IcMax_df,
        ByOffset=point["ByOffset"], # This is now applied *after* data's own start is aligned to 0
        ByRange=ByRange,
        f_factor=f
    )

# Add IcMax_df trace to fig
# The "By" column in IcMax_df now contains the aligned and offsetted x-values
if not IcMax_df.empty:
    fig.add_trace(go.Scatter(
        x=IcMax_df["By"],  # These 'By' values are already transformed
        y=IcMax_df["IcMax"] + IcMax_df["angle"] * 1e-6 * f,
        mode='lines+markers',
        name='IcMax',
        marker=dict(size=8, symbol='star'),
        line=dict(width=2, dash='dash')
    ))
else:
    print("IcMax_df is empty. Skipping the IcMax trend plot.")

# --- Figure Layout and Display ---
# The x-axis title now refers to By values that have been aligned and then offset.
fig.update_layout(
    title="<b>|005-1|Ic-By@r60mT| w/ In-Plane Field Angles (Aligned Start + Offset)",
    xaxis_title=f"Out-of-Plane Field (By, aligned then offset) [T]",
    yaxis_title=f"Critical Current (Ic) + Offset [A] (angle*{f}e-6)",
    legend_title="Angle",
    hovermode="x unified",
    template="plotly_white",
    width=1200,
    height=800,
)
fig.show()

print("\nFinal IcMax DataFrame (By values are aligned then offset):")
print(IcMax_df)

# %% [markdown]
# # Ic conbine

# %%
import pandas as pd
import plotly.graph_objects as go
from IPython.display import clear_output

# Assume plot_heatmaps is defined elsewhere and works as expected
# from your_module import plot_heatmaps # Example of how you might import it

# --- Helper Function Definition ---
def process_and_plot_data(dataid, angle, angle_label, fig, IcMax_df, ByOffset, ByRange, f_factor):
    print(f"Processing dataid: {dataid}, angle: {angle}° ({angle_label})")
    Ic_offset = angle * 1e-6 * f_factor

    # --- Placeholder for plot_heatmaps and Ic_df generation ---
    if 'plot_heatmaps' not in globals():
        print(f"Warning: 'plot_heatmaps' function not found. Using dummy data for dataid {dataid}.")
        _data_points = 30
        _base_param_values = [(i - _data_points/2 + 0.5) * ByRange / (_data_points/2) for i in range(_data_points)]
        _param_values = [pv + (dataid * 1e-4) for pv in _base_param_values]
        # Add a synthetic peak for demonstration
        import numpy as np
        _ic_values = np.exp(-((np.array(_param_values)-0.002)**2)/(2*(0.001)**2)) * 5e-6 + 1e-6*np.random.rand(_data_points)
        Ic_df = pd.DataFrame({
            "param_value": _param_values,
            "Ic": _ic_values
        })
    else:
        fig1, fig2, fig3, Ic_df = plot_heatmaps(dataid)
    # --- End of Placeholder ---

    # 1. 过滤掉前10个点
    Ic_df = Ic_df.iloc[10:].reset_index(drop=True)

    # 2. 只保留By在范围内的数据
    Ic_df_filtered = Ic_df[(Ic_df["param_value"] < ByRange) & (Ic_df["param_value"] > -ByRange)].copy()
    if Ic_df_filtered.empty:
        print(f"Warning: Ic_df_filtered is empty for dataid {dataid} after filtering. Skipping.")
        return fig, IcMax_df

    # 3. 用find_peaks找第一个峰
    from scipy.signal import find_peaks
    peaks, _ = find_peaks(Ic_df_filtered["Ic"])
    if len(peaks) == 0:
        print(f"No peak found for dataid {dataid}. Using min(param_value) as alignment.")
        align_x = Ic_df_filtered["param_value"].min()
    else:
        first_peak_idx = peaks[0]
        align_x = Ic_df_filtered.iloc[first_peak_idx]["param_value"]

    # 4. 对齐By，使第一个peak在x=0，再加ByOffset
    plot_x_values = Ic_df_filtered["param_value"] - align_x + ByOffset

    # 5. 计算最大Ic及其By（同样对齐）
    idx_max = Ic_df_filtered["Ic"].idxmax()
    By_max = Ic_df_filtered.loc[idx_max, "param_value"]
    Ic_max_value = Ic_df_filtered.loc[idx_max, "Ic"]
    By_aligned_for_plot = By_max - align_x + ByOffset

    # 6. 更新IcMax_df
    new_row_data = [{"angle": angle, "IcMax": Ic_max_value, "By": By_aligned_for_plot, "dataid": dataid}]
    new_row_df = pd.DataFrame(new_row_data)
    IcMax_df = pd.concat([IcMax_df, new_row_df], ignore_index=True)

    # 7. 画图
    fig.add_trace(go.Scatter(
        x=plot_x_values,
        y=Ic_df_filtered["Ic"] + Ic_offset,
        mode='lines+markers',
        name=f'{angle}°{angle_label}{dataid}',
        marker=dict(size=5),
        line=dict(width=2)
    ))

    clear_output(wait=True)
    return fig, IcMax_df

# --- Main Script ---
f = 0.2
ByRange = 10e-3 # This range is used for filtering param_value *before* alignment.
                # Ensure it's appropriate for your raw data's scale.
IcMax_df = pd.DataFrame(columns=["angle", "IcMax", "By", "dataid"])
fig = go.Figure()

# Define data points as a list of dictionaries for easier iteration
data_points = [
    # {"dataid": 308, "angle": 0,   "label": "O",  "ByOffset":  0.0e-6},
    {"dataid": 269, "angle": 0,   "label": "E",  "ByOffset": -8.2e-6}, # Starts at x=0.0020055
    {"dataid": 284, "angle": 45,  "label": "NE", "ByOffset": -4.8e-6},# Starts at x=0.0020005
    {"dataid": 293, "angle": 90,  "label": "N",  "ByOffset": -2.0e-6},  # Starts at x=0.000006
    {"dataid": 298, "angle": 135, "label": "NW", "ByOffset": -1.6e-6},# Starts at x=0.0000075
    {"dataid": 299, "angle": 180, "label": "W",  "ByOffset": -8.2e-6},       # Starts at x=-0.002
    {"dataid": 303, "angle": 225, "label": "SW", "ByOffset":  0.0e-6},# Starts at x=-0.001194
    {"dataid": 305, "angle": 270, "label": "S",  "ByOffset":  0.0e-6}, # Starts at x=0.0000035
    {"dataid": 307, "angle": 315, "label": "SE", "ByOffset": -1.4e-6},# Starts at x=0.0020075
]

# Loop through the data points and process them
for point in data_points:
    fig, IcMax_df = process_and_plot_data(
        dataid=point["dataid"],
        angle=point["angle"],
        angle_label=point["label"],
        fig=fig,
        IcMax_df=IcMax_df,
        ByOffset=point["ByOffset"], # This is now applied *after* data's own start is aligned to 0
        ByRange=ByRange,
        f_factor=f
    )

# Add IcMax_df trace to fig
# The "By" column in IcMax_df now contains the aligned and offsetted x-values
if not IcMax_df.empty:
    fig.add_trace(go.Scatter(
        x=IcMax_df["By"],  # These 'By' values are already transformed
        y=IcMax_df["IcMax"] + IcMax_df["angle"] * 1e-6 * f,
        mode='lines+markers',
        name='IcMax',
        marker=dict(size=8, symbol='star'),
        line=dict(width=2, dash='dash')
    ))
else:
    print("IcMax_df is empty. Skipping the IcMax trend plot.")

# --- Figure Layout and Display ---
# The x-axis title now refers to By values that have been aligned and then offset.
fig.update_layout(
    title="<b>|003-3|Ic-By@r60mT| w/ In-Plane Field Angles (Aligned Start + Offset)",
    xaxis_title=f"Out-of-Plane Field (By, aligned then offset) [T]",
    yaxis_title=f"Critical Current (Ic) + Offset [A] (angle*{f}e-6)",
    legend_title="Angle",
    hovermode="x unified",
    template="plotly_white",
    width=1200,
    height=800,
)
fig.show()

print("\nFinal IcMax DataFrame (By values are aligned then offset):")
print(IcMax_df)
# --- Heatmap Generation ---
if all_dfs_for_heatmap:
    heatmap_source_data = pd.concat(all_dfs_for_heatmap, ignore_index=True)
    
    if not heatmap_source_data.empty and 'param_value' in heatmap_source_data and 'angle' in heatmap_source_data and 'Ic' in heatmap_source_data:
        try:
            # Create the pivot table: angles as rows, By (param_value) as columns, Ic as values
            pivot_table = heatmap_source_data.pivot_table(
                index='angle', 
                columns='param_value', 
                values='Ic'
            )
            
            # Sort index (angles) and columns (By values) for an ordered heatmap
            pivot_table = pivot_table.sort_index(axis=0)  # Sort by angle (Y-axis)
            pivot_table = pivot_table.sort_index(axis=1)  # Sort by param_value (X-axis)

            heatmap_fig = go.Figure(data=go.Heatmap(
                z=pivot_table.values,    # 2D array of Ic values
                x=pivot_table.columns,   # By (param_value)
                y=pivot_table.index,     # Angles
                colorscale='RdBu',    # Example colorscale
                colorbar=dict(title='Ic [A]'),
                connectgaps=False,
            ))
            
            heatmap_fig.update_layout(
                title='Critical Current (Ic) Heatmap@r60mT',
                xaxis_title=f"Out-of-Plane Field (By) [T] (within ±{ByRange:.0e} T)",
                yaxis_title='Angle [degrees]',
                # xaxis_type='linear' # Default, should work if param_value is numeric
                yaxis_type='category', # Angles are distinct categories
                width=1200,
                height=800,
                template="plotly_white"
            )
            heatmap_fig.show()
            
        except Exception as e:
            print(f"Could not generate heatmap. Error: {e}")
            print("Sample of data intended for pivot table:")
            print(heatmap_source_data.head())
    else:
        print("Source data for heatmap is empty or missing required columns ('param_value', 'angle', 'Ic').")
else:
    print("No data was collected to generate the heatmap (all_dfs_for_heatmap list is empty).")

# %%
import pandas as pd
import plotly.graph_objects as go
from IPython.display import clear_output
from scipy.signal import find_peaks
import numpy as np

# --- Helper Function Definition ---
# The function now accepts and returns 'aligned_dfs_for_heatmap'
def process_and_plot_data(dataid, angle, angle_label, fig, IcMax_df, ByOffset, ByRange, f_factor, aligned_dfs_for_heatmap):
    print(f"Processing dataid: {dataid}, angle: {angle}° ({angle_label})")
    
    # Using dummy data as plot_heatmaps is not defined
    _data_points = 100 # More points for a better demo
    _base_param_values = np.linspace(-ByRange*1.5, ByRange*1.5, _data_points)
    peak_center = 0.002 * np.cos(np.deg2rad(angle * 2)) # Example of a shifting peak
    _ic_values = np.exp(-((_base_param_values - peak_center)**2) / (2*(0.001)**2)) * 5e-6 + 1e-6*np.random.rand(_data_points)
    Ic_df = pd.DataFrame({"param_value": _base_param_values, "Ic": _ic_values})

    # 1. Filter data to be within the specified ByRange
    Ic_df_filtered = Ic_df[(Ic_df["param_value"] < ByRange) & (Ic_df["param_value"] > -ByRange)].copy()
    if Ic_df_filtered.empty:
        print(f"Warning: No data within ByRange for dataid {dataid}. Skipping.")
        return fig, IcMax_df, aligned_dfs_for_heatmap

    # 3. Use find_peaks to locate the first peak for alignment
    peaks, _ = find_peaks(Ic_df_filtered["Ic"], height=2e-6) # Added height for robustness
    if len(peaks) == 0:
        print(f"No peak found for dataid {dataid}. Using max current point for alignment.")
        align_x = Ic_df_filtered.loc[Ic_df_filtered["Ic"].idxmax()]["param_value"]
    else:
        first_peak_idx = peaks[0]
        align_x = Ic_df_filtered.iloc[first_peak_idx]["param_value"]

    # 4. Align By so the first peak is at x=0, then add the specified ByOffset
    plot_x_values = Ic_df_filtered["param_value"] - align_x + ByOffset

    # --- NEW: Collect the ALIGNED data for the new heatmap ---
    aligned_data_chunk = pd.DataFrame({
        'aligned_by': plot_x_values,
        'Ic': Ic_df_filtered['Ic'],
        'angle': angle
    })
    aligned_dfs_for_heatmap.append(aligned_data_chunk)
    # --- End of NEW section ---

    # 5. Calculate the maximum Ic and its corresponding aligned By
    idx_max = Ic_df_filtered["Ic"].idxmax()
    Ic_max_value = Ic_df_filtered.loc[idx_max, "Ic"]
    By_aligned_for_plot = plot_x_values.loc[idx_max]

    # 6. Update the IcMax_df DataFrame
    new_row_df = pd.DataFrame([{"angle": angle, "IcMax": Ic_max_value, "By": By_aligned_for_plot, "dataid": dataid}])
    IcMax_df = pd.concat([IcMax_df, new_row_df], ignore_index=True)

    # 7. Add the processed data trace to the line plot
    Ic_offset = angle * 1e-6 * f_factor
    fig.add_trace(go.Scatter(
        x=plot_x_values,
        y=Ic_df_filtered["Ic"] + Ic_offset,
        mode='lines+markers',
        name=f'{angle}° {angle_label}',
        marker=dict(size=5),
        line=dict(width=2)
    ))

    clear_output(wait=True)
    return fig, IcMax_df, aligned_dfs_for_heatmap

# --- Main Script ---
# --- Configuration ---
f = 1
ByRange = 10e-3

# --- Initialization ---
IcMax_df = pd.DataFrame(columns=["angle", "IcMax", "By", "dataid"])
fig = go.Figure()
aligned_dfs_for_heatmap = [] # <<< Initialize list for the new heatmap

# Define data points for processing
data_points = [
    {"dataid": 269, "angle": 0,   "label": "E",  "ByOffset": 0},
    {"dataid": 284, "angle": 45,  "label": "NE", "ByOffset": 0},
    {"dataid": 293, "angle": 90,  "label": "N",  "ByOffset": 0},
    {"dataid": 298, "angle": 135, "label": "NW", "ByOffset": 0},
    {"dataid": 299, "angle": 180, "label": "W",  "ByOffset": 0},
    {"dataid": 303, "angle": 225, "label": "SW", "ByOffset": 0},
    {"dataid": 305, "angle": 270, "label": "S",  "ByOffset": 0},
    {"dataid": 307, "angle": 315, "label": "SE", "ByOffset": 0},
]

# Loop through the data points and process them
for point in data_points:
    fig, IcMax_df, aligned_dfs_for_heatmap = process_and_plot_data(
        dataid=point["dataid"],
        angle=point["angle"],
        angle_label=point["label"],
        fig=fig,
        IcMax_df=IcMax_df,
        ByOffset=point["ByOffset"],
        ByRange=ByRange,
        f_factor=f,
        aligned_dfs_for_heatmap=aligned_dfs_for_heatmap
    )

# Add IcMax_df trace to the line plot
if not IcMax_df.empty:
    fig.add_trace(go.Scatter(
        x=IcMax_df["By"],
        y=IcMax_df["IcMax"] + IcMax_df["angle"] * 1e-6 * f,
        mode='lines+markers', name='IcMax Trend',
        marker=dict(size=10, symbol='star', color='red'),
        line=dict(width=2, dash='dash', color='gray')
    ))

# --- Final Line Plot ---
fig.update_layout(
    title="<b>Ic-By Scans vs. In-Plane Field Angle (Aligned)</b>",
    xaxis_title="Out-of-Plane Field (By) [T] (Aligned & Offset)",
    yaxis_title=f"Critical Current (Ic) + Offset [A]",
    legend_title="Measurement", hovermode="x unified", template="plotly_white",
    width=1200, height=800
)
fig.show()

# ==============================================================================
# --- Heatmap Generation of ALIGNED and OFFSETTED Data ---
# ==============================================================================
if aligned_dfs_for_heatmap:
    # 1. Concatenate all data into a single DataFrame
    source_df = pd.concat(aligned_dfs_for_heatmap, ignore_index=True)

    # 2. Define the bins for the aligned By-axis
    # We create 100 bins from the min to the max of the aligned data.
    num_bins = 100
    bins = np.linspace(source_df['aligned_by'].min(), source_df['aligned_by'].max(), num_bins)
    
    # 3. Assign each data point to a bin
    source_df['by_binned'] = pd.cut(source_df['aligned_by'], bins=bins)

    # 4. Group by angle and the new bins, then calculate the mean Ic
    # This aggregates the data into our desired grid format.
    heatmap_data = source_df.groupby(['angle', 'by_binned'], observed=False)['Ic'].mean().unstack()

    # 5. Create the heatmap
    aligned_heatmap_fig = go.Figure(data=go.Heatmap(
        z=heatmap_data.values,
        x=[f"{b.mid:.4f}" for b in heatmap_data.columns], # Use the midpoint of each bin as the x-label
        y=heatmap_data.index,
        colorscale='Viridis',
        colorbar=dict(title='Average Ic [A]'),
    ))
    
    aligned_heatmap_fig.update_layout(
        title='<b>Heatmap of Aligned Critical Current</b>',
        xaxis_title='Binned Out-of-Plane Field (By) [T] (Aligned & Offset)',
        yaxis_title='In-Plane Angle [degrees]',
        yaxis=dict(type='category'),
        width=1000,
        height=700,
        template="plotly_white"
    )
    aligned_heatmap_fig.show()
else:
    print("No data was collected to generate the aligned heatmap.")

# %% [markdown]
# ## output

# %%
import pandas as pd
import plotly.graph_objects as go
from IPython.display import clear_output # For use in Jupyter-like environments

# --- Helper Function Definition ---
def _process_dataset_for_Ic_By_plot(
    dataid, 
    angle, 
    angle_label, 
    fig, 
    IcMax_df, 
    ByOffset, 
    ByRange_filter, 
    f_factor, 
    data_loader_func
):
    """
    Processes data for a single dataset: loads data (or generates dummy data),
    filters it, aligns its 'param_value' start to 0 then applies ByOffset,
    calculates IcMax, updates IcMax_df, and adds a trace to the figure.

    Args:
        dataid (int): The ID of the dataset.
        angle (int or float): The angle in degrees.
        angle_label (str): A short label for the angle (e.g., "NE", "E").
        fig (go.Figure): The Plotly figure object to add traces to.
        IcMax_df (pd.DataFrame): DataFrame to store maximum Ic values, which will be modified.
        ByOffset (float): The offset to apply to the x-values AFTER aligning data start to 0.
        ByRange_filter (float): The range to filter 'param_value' (e.g., data between -ByRange_filter and +ByRange_filter).
        f_factor (float): The factor 'f' used in y-axis Ic_offset calculation (angle * 1e-6 * f_factor).
        data_loader_func (callable, optional): A function that takes 'dataid' and returns
                                              a pandas DataFrame with "param_value" and "Ic" columns.
                                              If it returns a tuple, it's assumed to be (fig1, fig2, fig3, Ic_df).
                                              If None, dummy data is generated.

    Returns:
        tuple: Updated (fig, IcMax_df)
    """
    print(f"Processing dataid: {dataid}, angle: {angle}° ({angle_label})")
    y_axis_Ic_offset = angle * 1e-6 * f_factor # Offset for y-values to separate traces visually
    
    Ic_df = None
    if data_loader_func is None:
        print(f"Warning: 'data_loader_func' not provided. Using dummy data for dataid {dataid}.")
        _data_points = 20 # Increased points for smoother dummy data
        # Generate base param values roughly centered around 0, with a span related to ByRange_filter
        _base_param_values = [(i - _data_points / 2 + 0.5) * (2 * ByRange_filter) / _data_points for i in range(_data_points)]
        # Add a small unique offset based on dataid to simulate different raw start points for testing alignment
        _param_values = [pv + (dataid * 1e-5) for pv in _base_param_values] # Reduced shift to keep within typical ByRange
        _ic_values = [abs(5e-6 - abs(pv - (dataid * 1e-5)) * 1e-3 + (angle / 90) * 1e-7) for pv in _param_values]
        Ic_df = pd.DataFrame({
            "param_value": _param_values,
            "Ic": _ic_values
        })
    else:
        returned_data = data_loader_func(dataid)
        if isinstance(returned_data, tuple) and len(returned_data) > 0 and isinstance(returned_data[-1], pd.DataFrame):
            # Assuming the last element of the tuple is the Ic_df
            Ic_df = returned_data[-1]
        elif isinstance(returned_data, pd.DataFrame):
            Ic_df = returned_data
        else:
            raise ValueError(
                f"data_loader_func for dataid {dataid} did not return data in an expected format "
                "(e.g., Ic_df DataFrame or a tuple ending with Ic_df)."
            )

    if Ic_df is None or "param_value" not in Ic_df.columns or "Ic" not in Ic_df.columns:
        print(f"Error: Ic_df for dataid {dataid} is invalid or missing required columns. Skipping.")
        return fig, IcMax_df

    # Filter the Ic_df based on the raw 'param_value' range.
    # This filter assumes 'param_value' is somewhat centered, or ByRange_filter defines absolute limits.
    Ic_df_filtered = Ic_df[
        (Ic_df["param_value"] < ByRange_filter) & (Ic_df["param_value"] > -ByRange_filter)
    ].copy()

    if Ic_df_filtered.empty:
        print(f"Warning: Ic_df_filtered is empty for dataid {dataid} after filtering with ByRange_filter={ByRange_filter}. "
              "Check filter, data source, or ByRange_filter value. Skipping this data point.")
        return fig, IcMax_df

    # --- Alignment Step ---
    min_param_value_in_filtered = Ic_df_filtered["param_value"].min()
    # Shift 'param_value's so the minimum (of the filtered set) is 0, then add the ByOffset.
    plot_x_values = (Ic_df_filtered["param_value"] - min_param_value_in_filtered) + ByOffset
    # --- End of Alignment Step ---

    if 'Ic' not in Ic_df_filtered.columns or not pd.api.types.is_numeric_dtype(Ic_df_filtered['Ic']):
        print(f"Error: 'Ic' column is missing or not numeric in Ic_df_filtered for dataid {dataid}.")
        return fig, IcMax_df
        
    # Find the original param_value (from filtered data) where Ic is maximal
    idx_max_ic = Ic_df_filtered["Ic"].idxmax()
    By_original_at_max_Ic = Ic_df_filtered.loc[idx_max_ic, "param_value"]
    Ic_max_value = Ic_df_filtered.loc[idx_max_ic, "Ic"]
    
    # Apply the same alignment transformation to this By_original for storing in IcMax_df
    By_aligned_for_plot = (By_original_at_max_Ic - min_param_value_in_filtered) + ByOffset
    
    new_row_data = [{"angle": angle, "IcMax": Ic_max_value, "By": By_aligned_for_plot, "dataid": dataid}]
    new_row_df = pd.DataFrame(new_row_data)
    IcMax_df = pd.concat([IcMax_df, new_row_df], ignore_index=True)
    
    fig.add_trace(go.Scatter(
        x=plot_x_values,
        y=Ic_df_filtered["Ic"] + y_axis_Ic_offset,
        mode='lines+markers',
        name=f'{angle}°{angle_label}',
        marker=dict(size=5),
        line=dict(width=2)
    ))
    
    # clear_output(wait=True) # Optional: uncomment if running in a context where clearing output per step is desired
    return fig, IcMax_df

# --- Main Plotting Function ---
def plot_aligned_Ic_vs_By(
    data_configurations,
    f_parameter,
    by_filter_range,
    actual_data_loader=None,
    plot_title="<b>Ic vs. By | In-Plane Field Angles (Aligned Start + Offset)</b>",
    xaxis_title_override=None, # Allow full override for xaxis title
    yaxis_title_override=None, # Allow full override for yaxis title
    legend_title="Angle",
    plot_width=1200,
    plot_height=800
):
    """
    Generates a Plotly figure showing Ic vs. By for multiple datasets.
    Each dataset's 'By' field (param_value) is aligned so its minimum starts at 0,
    then a specific ByOffset (from data_configurations) is applied.

    Args:
        data_configurations (list of dict): List of configurations for each dataset.
            Each dict must contain: "dataid", "angle", "label", "ByOffset".
        f_parameter (float): The 'f' factor used in y-axis Ic_offset calculation.
        by_filter_range (float): The range to filter 'param_value' before alignment 
                                 (e.g. data between -by_filter_range and +by_filter_range).
        actual_data_loader (callable, optional): Function to load real data. 
                                                 Takes dataid, returns Ic_df DataFrame or tuple ending in Ic_df.
                                                 If None, dummy data is used by the helper function.
        plot_title (str, optional): Title of the plot.
        xaxis_title_override (str, optional): Specific title for the X-axis. If None, a default is used.
        yaxis_title_override (str, optional): Specific title for the Y-axis. If None, a default is used.
        legend_title (str, optional): Title for the legend.
        plot_width (int, optional): Width of the plot in pixels.
        plot_height (int, optional): Height of the plot in pixels.

    Returns:
        tuple: (go.Figure, pd.DataFrame)
               - The Plotly figure object.
               - The DataFrame containing summarized IcMax values.
    """
    IcMax_df = pd.DataFrame(columns=["angle", "IcMax", "By", "dataid"])
    fig = go.Figure()

    print(f"Starting plot generation with f_parameter={f_parameter}, by_filter_range={by_filter_range}")

    for point_config in data_configurations:
        fig, IcMax_df = _process_dataset_for_Ic_By_plot(
            dataid=point_config["dataid"],
            angle=point_config["angle"],
            angle_label=point_config["label"],
            fig=fig,
            IcMax_df=IcMax_df,
            ByOffset=point_config["ByOffset"],
            ByRange_filter=by_filter_range,
            f_factor=f_parameter,
            data_loader_func=actual_data_loader
        )
    
    clear_output(wait=True) # Clear intermediate outputs from the loop
    print("All datasets processed. Finalizing plot.")

    if not IcMax_df.empty:
        fig.add_trace(go.Scatter(
            x=IcMax_df["By"],  # These 'By' values are already transformed
            y=IcMax_df["IcMax"] + IcMax_df["angle"] * 1e-6 * f_parameter, # Apply same y-offset logic
            mode='lines+markers',
            name='IcMax Trend',
            marker=dict(size=8, symbol='star', color='rgba(0,0,0,0.7)'),
            line=dict(width=2, dash='dash', color='rgba(0,0,0,0.7)')
        ))
    else:
        print("Warning: IcMax_df is empty. Skipping the IcMax trend plot.")

    # Determine axis titles
    xaxis_title = xaxis_title_override if xaxis_title_override is not None else "Out-of-Plane Field (By, aligned then offset) [T]"
    yaxis_title = yaxis_title_override if yaxis_title_override is not None else f"Critical Current (Ic) + Offset [A] (angle*{f_parameter:.2f}e-6)"


    fig.update_layout(
        title=plot_title,
        xaxis_title=xaxis_title,
        yaxis_title=yaxis_title,
        legend_title=legend_title,
        hovermode="x unified",
        template="plotly_white",
        width=plot_width,
        height=plot_height,
    )
    
    print("Plot generation complete.")
    return fig, IcMax_df

# --- Example Usage ---
if __name__ == '__main__':
    # 1. Define your data configurations
    my_data_points = [
        {"dataid": 144, "angle": 0, "label": "O", "ByOffset": 0e-3},
        {"dataid": 197, "angle": 0, "label": "E", "ByOffset": 0.002}, # Simplified ByOffset for clarity
        {"dataid": 196, "angle": 45, "label": "NE", "ByOffset": 0.0025},
        {"dataid": 178, "angle": 90, "label": "N", "ByOffset": 0.0005},
        # Add more data points as needed
    ]

    # 2. Define parameters
    f_val = 0.25
    by_range = 0.02 # 10mT, ensure this is appropriate for your raw param_value scale

    # 3. (Optional) Define your actual data loader function
    # If you have a function like `plot_heatmaps` that returns (fig1, fig2, fig3, Ic_df)
    # or just Ic_df, you can pass it.
    # For this example, we'll use the dummy data by passing `None`.
    
    # Example of what your data loader might look like:
    # def my_actual_data_loader(dataid_to_load):
    #     print(f"LOADER: Loading real data for dataid {dataid_to_load}...")
    #     # ... your actual data loading logic ...
    #     # Example: fig1, fig2, fig3, loaded_ic_df = original_plot_heatmaps(dataid_to_load)
    #     # return fig1, fig2, fig3, loaded_ic_df 
    #     # OR if it just returns the DataFrame:
    #     # loaded_ic_df = load_ic_dataframe(dataid_to_load)
    #     # return loaded_ic_df
    #
    #     # For demonstration, let's make a dummy loader that returns a DataFrame
    #     _points = 30
    #     _raw_params = [(j - _points/2) * (2*by_range) / _points + (dataid_to_load/10000.0) for j in range(_points)]
    #     _raw_ics = [abs(6e-6 - abs(p)*0.8e-3) + (dataid_to_load/1000.0 * 1e-7) for p in _raw_params]
    #     dummy_df = pd.DataFrame({"param_value": _raw_params, "Ic": _raw_ics})
    #     return dummy_df # It's important it has "param_value" and "Ic"

    # For this run, we'll use the internal dummy data by setting actual_data_loader=None
    custom_data_loader = None # Replace with `my_actual_data_loader` if you have one

    # 4. Call the main plotting function
    print("Starting example script...")
    generated_fig, final_IcMax_df = plot_aligned_Ic_vs_By(
        data_configurations=my_data_points,
        f_parameter=f_val,
        by_filter_range=by_range,
        actual_data_loader=custom_data_loader, # Set to None to use default dummy data
        plot_title="<b>Demo: Aligned Ic vs. By Field Scan</b>"
    )

    # 5. Show the figure (if in an environment that supports it, like Jupyter)
    # In a script, you might save it to a file: generated_fig.write_html("aligned_plot.html")
    generated_fig.show()

    # 6. Print the resulting IcMax DataFrame
    print("\nFinal IcMax DataFrame (By values are aligned then offset):")
    print(final_IcMax_df.to_string())

# %% [markdown]
# # HEatmap

# %%
import pandas as pd
import plotly.graph_objects as go
from IPython.display import clear_output
from scipy.signal import find_peaks
import numpy as np # Added for the dummy data

# --- Helper Function Definition ---
# --- CORRECTED Helper Function Definition ---
def process_and_plot_data(dataid, angle, angle_label, fig, IcMax_df, ByOffset, ByRange, f_factor, all_dfs_for_heatmap):
    """
    Processes a single dataset: filters, finds peaks, aligns data, and plots it.
    It also collects the data needed for the final heatmap.
    """
    print(f"Processing dataid: {dataid}, angle: {angle}° ({angle_label})")

    # --- CHOOSE ONE OPTION BELOW ---
    
    # OPTION 1: Use your REAL plot_heatmaps function.
    # The error occurred because the following line was commented out.
    # Make sure your plot_heatmaps(dataid) function returns four values,
    # with the DataFrame being the last one.
    fig1, fig2, fig3, Ic_df = plot_heatmaps(dataid)

    # OPTION 2: Use the DUMMY DATA for testing.
    # If you want to use the dummy data instead, comment out the line above
    # and uncomment the block below.
    # _data_points = 50
    # _base_param_values = np.linspace(-ByRange*1.5, ByRange*1.5, _data_points)
    # _param_values = _base_param_values
    # peak_center = 0.002 * np.cos(np.deg2rad(angle))
    # _ic_values = np.exp(-((np.array(_param_values)-peak_center)**2)/(2*(0.001)**2)) * 5e-6 + 1e-6*np.random.rand(_data_points)
    # Ic_df = pd.DataFrame({
    #     "param_value": _param_values,
    #     "Ic": _ic_values
    # })
    # --- End of choice ---

    # 1. Filter out the first 10 data points (optional, depends on your data)
    Ic_df = Ic_df.iloc[10:].reset_index(drop=True)

    # 2. Filter data to be within the specified ByRange
    Ic_df_filtered = Ic_df[(Ic_df["param_value"] < ByRange) & (Ic_df["param_value"] > -ByRange)].copy()
    if Ic_df_filtered.empty:
        print(f"Warning: No data within ByRange for dataid {dataid}. Skipping.")
        return fig, IcMax_df, all_dfs_for_heatmap # Return unmodified list

    # Collect data for the heatmap BEFORE alignment
    heatmap_data_chunk = Ic_df_filtered.copy()
    heatmap_data_chunk['angle'] = angle
    all_dfs_for_heatmap.append(heatmap_data_chunk)
    
    # 3. Use find_peaks to locate the first peak for alignment
    peaks, _ = find_peaks(Ic_df_filtered["Ic"])
    if len(peaks) == 0:
        print(f"No peak found for dataid {dataid}. Using max current point for alignment.")
        align_x = Ic_df_filtered.loc[Ic_df_filtered["Ic"].idxmax()]["param_value"]
    else:
        first_peak_idx = peaks[0]
        align_x = Ic_df_filtered.iloc[first_peak_idx]["param_value"]

    # 4. Align By so the first peak is at x=0, then add the specified ByOffset
    plot_x_values = Ic_df_filtered["param_value"] - align_x + ByOffset

    # 5. Calculate the maximum Ic and its corresponding aligned By
    idx_max = Ic_df_filtered["Ic"].idxmax()
    By_max = Ic_df_filtered.loc[idx_max, "param_value"]
    Ic_max_value = Ic_df_filtered.loc[idx_max, "Ic"]
    By_aligned_for_plot = By_max - align_x + ByOffset

    # 6. Update the IcMax_df DataFrame
    new_row_df = pd.DataFrame([{"angle": angle, "IcMax": Ic_max_value, "By": By_aligned_for_plot, "dataid": dataid}])
    IcMax_df = pd.concat([IcMax_df, new_row_df], ignore_index=True)

    # 7. Add the processed data trace to the line plot
    Ic_offset = angle * 1e-6 * f_factor
    fig.add_trace(go.Scatter(
        x=plot_x_values,
        y=Ic_df_filtered["Ic"] + Ic_offset,
        mode='lines+markers',
        name=f'{angle}° {angle_label} ({dataid})',
        marker=dict(size=5),
        line=dict(width=2)
    ))

    clear_output(wait=True)
    return fig, IcMax_df, all_dfs_for_heatmap
# --- Main Script ---
# --- Configuration ---
f = 0.2
ByRange = 10e-3 # Range for filtering param_value before alignment.

# --- Initialization ---
IcMax_df = pd.DataFrame(columns=["angle", "IcMax", "By", "dataid"])
fig = go.Figure()
all_dfs_for_heatmap = [] # <<< FIX: Initialize the list here

# Define data points for processing
data_points = [
    {"dataid": 318, "angle": 0,   "label": "E",  "ByOffset": 0e-6},
    {"dataid": 347, "angle": 45,  "label": "NE", "ByOffset": 0e-6},
    {"dataid": 321, "angle": 90,  "label": "N",  "ByOffset": 0e-6},
    {"dataid": 322, "angle": 135, "label": "NW", "ByOffset": 0e-6},
    {"dataid": 323, "angle": 180, "label": "W",  "ByOffset": 0e-6},
    {"dataid": 350, "angle": 225, "label": "SW", "ByOffset": 0e-6},
    {"dataid": 343, "angle": 270, "label": "S",  "ByOffset": 0e-6},
    {"dataid": 342, "angle": 315, "label": "SE", "ByOffset": 0e-6},
]

# Loop through the data points and process them
for point in data_points:
    # Pass and receive the list in each iteration
    fig, IcMax_df, all_dfs_for_heatmap = process_and_plot_data(
        dataid=point["dataid"],
        angle=point["angle"],
        angle_label=point["label"],
        fig=fig,
        IcMax_df=IcMax_df,
        ByOffset=point["ByOffset"],
        ByRange=ByRange,
        f_factor=f,
        all_dfs_for_heatmap=all_dfs_for_heatmap # <<< FIX: Pass the list
    )

# --- Final Line Plot Customization ---
# Add the IcMax trend line to the figure
if not IcMax_df.empty:
    fig.add_trace(go.Scatter(
        x=IcMax_df["By"],
        y=IcMax_df["IcMax"] + IcMax_df["angle"] * 1e-6 * f,
        mode='lines+markers',
        name='IcMax Trend',
        marker=dict(size=10, symbol='star', color='red'),
        line=dict(width=2, dash='dash', color='gray')
    ))

# Update layout for the line plot
fig.update_layout(
    title="<b>Ic-By Scans vs. In-Plane Field Angle (Aligned & Offset)</b>",
    xaxis_title=f"Out-of-Plane Field (By) [T] (Aligned & Offset)",
    yaxis_title=f"Critical Current (Ic) + Offset [A] (offset = angle * {f}e-6)",
    legend_title="Measurement",
    hovermode="x unified",
    template="plotly_white",
    width=1200,
    height=800,
)
fig.show()

print("\nFinal IcMax DataFrame (By values are aligned then offset):")
print(IcMax_df)

# --- Heatmap Generation ---
if all_dfs_for_heatmap:
    heatmap_source_data = pd.concat(all_dfs_for_heatmap, ignore_index=True)
    
    if not heatmap_source_data.empty:
        try:
            # Create the pivot table for the heatmap
            pivot_table = heatmap_source_data.pivot_table(
                index='angle', 
                columns='param_value', 
                values='Ic'
            )
            
            # Sort for an ordered heatmap
            pivot_table = pivot_table.sort_index(axis=0) 
            pivot_table = pivot_table.sort_index(axis=1) 

            # ================================================================= #
            # === NEW CODE: Interpolate to fill the gaps along the By axis === #
            pivot_table_interpolated = pivot_table.interpolate(method='linear', axis=1, limit_direction='both')
            # ================================================================= #

            heatmap_fig = go.Figure(data=go.Heatmap(
                # Use the new interpolated data for the 'z' value
                z=pivot_table_interpolated.values, # <<< CHANGE THIS
                x=pivot_table_interpolated.columns, # <<< CHANGE THIS
                y=pivot_table_interpolated.index,   # <<< CHANGE THIS
                colorscale='Viridis',
                colorbar=dict(title='Ic [A]'),
                connectgaps=False, 
            ))
            heatmap_fig.update_layout(
                title='Critical Current (Ic) Heatmap@r60mT',
                xaxis_title=f"Out-of-Plane Field (By) [T] (within ±{ByRange:.0e} T)",
                yaxis_title='Angle [degrees]',
                # xaxis_type='linear' # Default, should work if param_value is numeric
                yaxis_type='category', # Angles are distinct categories
                width=1200,
                height=800,
                template="plotly_white"
            )
            # ... (the rest of your heatmap layout code) ...
            heatmap_fig.show()
            # Change this line:
            # heatmap_fig = go.Figure(data=go.Heatmap(...))

            # To this:
            # contour_fig = go.Figure(data=go.Contour(
            #     z=pivot_table.values,
            #     x=pivot_table.columns,
            #     y=pivot_table.index,
            #     colorscale='Viridis',
            #     colorbar=dict(title='Ic [A]'),
            #     connectgaps=False, # This will connect the contour lines
            # ))
            # contour_fig.show()
        except Exception as e:
            print(f"Could not generate heatmap. Error: {e}")
            print("Sample of data intended for pivot table:")
            print(heatmap_source_data.head())
    else:
        print("Source data for heatmap is empty.")
else:
    print("No data was collected to generate the heatmap.")

# %% [markdown]
# ## dataid key-in

# %%
# 003-2
CPR_003_2_data_points = [
    {"dataid": 269, "angle": 0,   "label": "E",  "ByOffset": 0},
    {"dataid": 284, "angle": 45,  "label": "NE", "ByOffset": 0},
    {"dataid": 293, "angle": 90,  "label": "N",  "ByOffset": 0},
    {"dataid": 298, "angle": 135, "label": "NW", "ByOffset": 0},
    {"dataid": 299, "angle": 180, "label": "W",  "ByOffset": 0},
    {"dataid": 303, "angle": 225, "label": "SW", "ByOffset": 0},
    {"dataid": 305, "angle": 270, "label": "S",  "ByOffset": 0},
    {"dataid": 307, "angle": 315, "label": "SE", "ByOffset": 0},
]
IVB_003_2_data_points = [
    {"dataid": 318, "angle": 0,   "label": "E",  "ByOffset": 0e-6},
    {"dataid": 347, "angle": 45,  "label": "NE", "ByOffset": 0e-6},
    {"dataid": 321, "angle": 90,  "label": "N",  "ByOffset": 0e-6},
    {"dataid": 322, "angle": 135, "label": "NW", "ByOffset": 0e-6},
    {"dataid": 323, "angle": 180, "label": "W",  "ByOffset": 0e-6},
    {"dataid": 350, "angle": 225, "label": "SW", "ByOffset": 0e-6},
    {"dataid": 343, "angle": 270, "label": "S",  "ByOffset": 0e-6},
    {"dataid": 342, "angle": 315, "label": "SE", "ByOffset": 0e-6},
]
# 003-3
CPR_003_3_data_points = [
    {"dataid": 269, "angle": 0,   "label": "E",  "ByOffset": 0},
    {"dataid": 284, "angle": 45,  "label": "NE", "ByOffset": 0},
    {"dataid": 293, "angle": 90,  "label": "N",  "ByOffset": 0},
    {"dataid": 298, "angle": 135, "label": "NW", "ByOffset": 0},
    {"dataid": 299, "angle": 180, "label": "W",  "ByOffset": 0},
    {"dataid": 303, "angle": 225, "label": "SW", "ByOffset": 0},
    {"dataid": 305, "angle": 270, "label": "S",  "ByOffset": 0},
    {"dataid": 307, "angle": 315, "label": "SE", "ByOffset": 0},
]
IVB_003_3_data_points = [
    {"dataid": 2, "angle": 0,   "label": "E",  "ByOffset": 0},
    {"dataid": 2, "angle": 45,  "label": "NE", "ByOffset": 0},
    {"dataid": 293, "angle": 90,  "label": "N",  "ByOffset": 0},
    {"dataid": 272, "angle": 135, "label": "NW", "ByOffset": 0},
    {"dataid": 273, "angle": 180, "label": "W",  "ByOffset": 0},
    {"dataid": 275, "angle": 225, "label": "SW", "ByOffset": 0},
    {"dataid": 276, "angle": 270, "label": "S",  "ByOffset": 0},
    {"dataid": 277, "angle": 315, "label": "SE", "ByOffset": 0},
]

# %% [markdown]
# ### 003_2

# %% [markdown]
# #### IVB

# %%
IVB_003_2_data = [
    {"dataid": 318, "angle": 0,   "label": "E",  "ByOffset": 0e-6},
    {"dataid": 347, "angle": 45,  "label": "NE", "ByOffset": 0e-6},
    {"dataid": 321, "angle": 90,  "label": "N",  "ByOffset": 0e-6},
    {"dataid": 322, "angle": 135, "label": "NW", "ByOffset": 0e-6},
    {"dataid": 323, "angle": 180, "label": "W",  "ByOffset": 0e-6},
    {"dataid": 350, "angle": 225, "label": "SW", "ByOffset": 0e-6},
    {"dataid": 343, "angle": 270, "label": "S",  "ByOffset": 0e-6},
    {"dataid": 342, "angle": 315, "label": "SE", "ByOffset": 0e-6},]

# %% [markdown]
# #### CPR

# %%
CPR_003_2_data_points = [
    {"dataid": 269, "angle": 0,   "label": "E",  "ByOffset": 0},
    {"dataid": 284, "angle": 45,  "label": "NE", "ByOffset": 0},
    {"dataid": 293, "angle": 90,  "label": "N",  "ByOffset": 0},
    {"dataid": 298, "angle": 135, "label": "NW", "ByOffset": 0},
    {"dataid": 299, "angle": 180, "label": "W",  "ByOffset": 0},
    {"dataid": 303, "angle": 225, "label": "SW", "ByOffset": 0},
    {"dataid": 305, "angle": 270, "label": "S",  "ByOffset": 0},
    {"dataid": 307, "angle": 315, "label": "SE", "ByOffset": 0},]

# %% [markdown]
# #### Finite_003_2B∥_data

# %%
FiniteIVB003_2B_parallel_data =[
    {"dataid": 401, "angle": 10, "label": "B∥"},
    {"dataid": 409, "angle": 20, "label": "B∥"},
    {"dataid": 417, "angle": 30, "label": "B∥"},
    {"dataid": 419, "angle": 40, "label": "B∥"},
    {"dataid": 423, "angle": 50, "label": "B∥"},
    {"dataid": 434, "angle": 60, "label": "B∥"},
    {"dataid": 442, "angle": 70, "label": "B∥"},
    {"dataid": 447, "angle": 80, "label": "B∥"},
    {"dataid": 454, "angle": 90, "label": "B∥"},
    {"dataid": 457, "angle": 100, "label": "B∥"},
    {"dataid": 460, "angle": 110, "label": "B∥"},
    {"dataid": 462, "angle": 120, "label": "B∥"},
    {"dataid": 464, "angle": 130, "label": "B∥"},
    {"dataid": 466, "angle": 140, "label": "B∥"},
    {"dataid": 468, "angle": 150, "label": "B∥"},
    {"dataid": 476, "angle": 160, "label": "B∥"},]

FiniteCPR003_2B_parallel_data =[
    {"dataid": 401, "angle": 10, "label": "B∥"},
    {"dataid": 409, "angle": 20, "label": "B∥"},
    {"dataid": 417, "angle": 30, "label": "B∥"},
    {"dataid": 428, "angle": 40, "label": "B∥"},
    {"dataid": 423, "angle": 50, "label": "B∥"},
    {"dataid": 434, "angle": 60, "label": "B∥"},
    {"dataid": 442, "angle": 70, "label": "B∥"},
    {"dataid": 447, "angle": 80, "label": "B∥"},
    {"dataid": 454, "angle": 90, "label": "B∥"},
    {"dataid": 457, "angle": 100, "label": "B∥"},
    {"dataid": 460, "angle": 110, "label": "B∥"},
    {"dataid": 462, "angle": 120, "label": "B∥"},
    {"dataid": 464, "angle": 130, "label": "B∥"},
    {"dataid": 466, "angle": 140, "label": "B∥"},
    {"dataid": 468, "angle": 150, "label": "B∥"},
    {"dataid": 476, "angle": 160, "label": "B∥"},]

# %% [markdown]
# #### Finite_003_2B⊥_data

# %%
FiniteIVB003_2B_perp_data =[
    {"dataid": 404, "angle": 10, "label": "B⊥"},
    {"dataid": 413, "angle": 20, "label": "B⊥"},
    {"dataid": 415, "angle": 30, "label": "B⊥"},
    {"dataid": 421, "angle": 40, "label": "B⊥"},
    {"dataid": 430, "angle": 50, "label": "B⊥"},
    {"dataid": 436, "angle": 60, "label": "B⊥"},
    {"dataid": 440, "angle": 70, "label": "B⊥"},
    {"dataid": 478, "angle": 80, "label": "B⊥"},
    {"dataid": 482, "angle": 90, "label": "B⊥"},
    {"dataid": 485, "angle": 100, "label": "B⊥"},
    {"dataid": 490, "angle": 110, "label": "B⊥"},
    {"dataid": 493, "angle": 120, "label": "B⊥"},
    {"dataid": 496, "angle": 130, "label": "B⊥"},
    {"dataid": 498, "angle": 140, "label": "B⊥"},
    {"dataid": 501, "angle": 150, "label": "B⊥"},
    {"dataid": 503, "angle": 160, "label": "B⊥"},
    {"dataid": 506, "angle": 170, "label": "B⊥"},
    {"dataid": 507, "angle": 180, "label": "B⊥"},
    ]

FiniteCPR003_2B_perp_data =[
    {"dataid": 406, "angle": 10, "label": "B⊥"},
    {"dataid": 414, "angle": 20, "label": "B⊥"},
    {"dataid": 416, "angle": 30, "label": "B⊥"},
    {"dataid": 428, "angle": 40, "label": "B⊥"},
    {"dataid": 433, "angle": 50, "label": "B⊥"},
    {"dataid": 439, "angle": 60, "label": "B⊥"},
    {"dataid": 441, "angle": 70, "label": "B⊥"},
    {"dataid": 480, "angle": 80, "label": "B⊥"},
    {"dataid": 484, "angle": 90, "label": "B⊥"},
    {"dataid": 488, "angle": 100, "label": "B⊥"},
    {"dataid": 491, "angle": 110, "label": "B⊥"},
    {"dataid": 494, "angle": 120, "label": "B⊥"},
    {"dataid": 497, "angle": 130, "label": "B⊥"},
    # {"dataid": 466, "angle": 140, "label": "B⊥"},
    # {"dataid": 468, "angle": 150, "label": "B⊥"},
    # {"dataid": 476, "angle": 160, "label": "B⊥"},
    ]

# %% [markdown]
# ### 003-3

# %% [markdown]
# #### IVB

# %%
IVB_003_3_data = [
    {"dataid": 2, "angle": 0,   "label": "E",  "ByOffset": 0},
    {"dataid": 2, "angle": 45,  "label": "NE", "ByOffset": 0},
    {"dataid": 293, "angle": 90,  "label": "N",  "ByOffset": 0},
    {"dataid": 272, "angle": 135, "label": "NW", "ByOffset": 0},
    {"dataid": 273, "angle": 180, "label": "W",  "ByOffset": 0},
    {"dataid": 275, "angle": 225, "label": "SW", "ByOffset": 0},
    {"dataid": 276, "angle": 270, "label": "S",  "ByOffset": 0},
    {"dataid": 277, "angle": 315, "label": "SE", "ByOffset": 0},
]

# %% [markdown]
# #### CPR

# %%
CPR_003_3_data = [
    {"dataid": 269, "angle": 0,   "label": "E",  "ByOffset": 0},
    {"dataid": 284, "angle": 45,  "label": "NE", "ByOffset": 0},
    {"dataid": 293, "angle": 90,  "label": "N",  "ByOffset": 0},
    {"dataid": 298, "angle": 135, "label": "NW", "ByOffset": 0},
    {"dataid": 299, "angle": 180, "label": "W",  "ByOffset": 0},
    {"dataid": 303, "angle": 225, "label": "SW", "ByOffset": 0},
    {"dataid": 305, "angle": 270, "label": "S",  "ByOffset": 0},
    {"dataid": 307, "angle": 315, "label": "SE", "ByOffset": 0},
]

# %%
# --- Main Script ---
# --- Configuration ---
f = 0.2
ByRange = 10e-3 # Range for filtering param_value before alignment.

# --- Initialization ---
IcMax_df = pd.DataFrame(columns=["angle", "IcMax", "By", "dataid"])
fig = go.Figure()
all_dfs_for_heatmap = [] # <<< FIX: Initialize the list here

data_points = [
    {"dataid": 269, "angle": 0,   "label": "E",  "ByOffset": 0},
    {"dataid": 284, "angle": 45,  "label": "NE", "ByOffset": 0},
    {"dataid": 293, "angle": 90,  "label": "N",  "ByOffset": 0},
    {"dataid": 298, "angle": 135, "label": "NW", "ByOffset": 0},
    {"dataid": 299, "angle": 180, "label": "W",  "ByOffset": 0},
    {"dataid": 303, "angle": 225, "label": "SW", "ByOffset": 0},
    {"dataid": 305, "angle": 270, "label": "S",  "ByOffset": 0},
    {"dataid": 307, "angle": 315, "label": "SE", "ByOffset": 0},
]
# Define data points for processing
# data_points = [
#     {"dataid": 318, "angle": 0,   "label": "E",  "ByOffset": 0e-6},
#     {"dataid": 347, "angle": 45,  "label": "NE", "ByOffset": 0e-6},
#     {"dataid": 321, "angle": 90,  "label": "N",  "ByOffset": 0e-6},
#     {"dataid": 322, "angle": 135, "label": "NW", "ByOffset": 0e-6},
#     {"dataid": 323, "angle": 180, "label": "W",  "ByOffset": 0e-6},
#     {"dataid": 350, "angle": 225, "label": "SW", "ByOffset": 0e-6},
#     {"dataid": 343, "angle": 270, "label": "S",  "ByOffset": 0e-6},
#     {"dataid": 342, "angle": 315, "label": "SE", "ByOffset": 0e-6},
# ]

# Loop through the data points and process them
for point in data_points:
    # Pass and receive the list in each iteration
    fig, IcMax_df, all_dfs_for_heatmap = process_and_plot_data(
        dataid=point["dataid"],
        angle=point["angle"],
        angle_label=point["label"],
        fig=fig,
        IcMax_df=IcMax_df,
        ByOffset=point["ByOffset"],
        ByRange=ByRange,
        f_factor=f,
        all_dfs_for_heatmap=all_dfs_for_heatmap # <<< FIX: Pass the list
    )

# --- Final Line Plot Customization ---
# Add the IcMax trend line to the figure
if not IcMax_df.empty:
    fig.add_trace(go.Scatter(
        x=IcMax_df["By"],
        y=IcMax_df["IcMax"] + IcMax_df["angle"] * 1e-6 * f,
        mode='lines+markers',
        name='IcMax Trend',
        marker=dict(size=10, symbol='star', color='red'),
        line=dict(width=2, dash='dash', color='gray')
    ))

# Update layout for the line plot
fig.update_layout(
    title="<b>Ic-By Scans vs. In-Plane Field Angle (Aligned & Offset)</b>",
    xaxis_title=f"Out-of-Plane Field (By) [T] (Aligned & Offset)",
    yaxis_title=f"Critical Current (Ic) + Offset [A] (offset = angle * {f}e-6)",
    legend_title="Measurement",
    hovermode="x unified",
    template="plotly_white",
    width=1200,
    height=800,
)
fig.show()

print("\nFinal IcMax DataFrame (By values are aligned then offset):")
print(IcMax_df)

# --- Heatmap Generation ---
if all_dfs_for_heatmap:
    heatmap_source_data = pd.concat(all_dfs_for_heatmap, ignore_index=True)
    
    if not heatmap_source_data.empty:
        try:
            # Create the pivot table for the heatmap
            pivot_table = heatmap_source_data.pivot_table(
                index='angle', 
                columns='param_value', 
                values='Ic'
            )
            
            # Sort for an ordered heatmap
            pivot_table = pivot_table.sort_index(axis=0) 
            pivot_table = pivot_table.sort_index(axis=1) 

            # ================================================================= #
            # === NEW CODE: Interpolate to fill the gaps along the By axis === #
            pivot_table_interpolated = pivot_table.interpolate(method='linear', axis=1, limit_direction='both')
            # ================================================================= #

            heatmap_fig = go.Figure(data=go.Heatmap(
                # Use the new interpolated data for the 'z' value
                z=pivot_table_interpolated.values, # <<< CHANGE THIS
                x=pivot_table_interpolated.columns, # <<< CHANGE THIS
                y=pivot_table_interpolated.index,   # <<< CHANGE THIS
                colorscale='RdBu',
                colorbar=dict(title='Ic [A]'),
                connectgaps=False, 
            ))
            heatmap_fig.update_layout(
                title='Critical Current (Ic) Heatmap@r60mT',
                xaxis_title=f"Out-of-Plane Field (By) [T] (within ±{ByRange:.0e} T)",
                yaxis_title='Angle [degrees]',
                # xaxis_type='linear' # Default, should work if param_value is numeric
                yaxis_type='category', # Angles are distinct categories
                width=1200,
                height=800,
                template="plotly_white"
            )
            # ... (the rest of your heatmap layout code) ...
            heatmap_fig.show()
            # Change this line:
            # heatmap_fig = go.Figure(data=go.Heatmap(...))

            # To this:
            contour_fig = go.Figure(data=go.Contour(
                z=pivot_table.values,
                x=pivot_table.columns,
                y=pivot_table.index,
                colorscale='RdBu',
                colorbar=dict(title='Ic [A]'),
                connectgaps=True, # This will connect the contour lines
            ))
            
            contour_fig.update_layout(
                title='Critical Current (Ic) Heatmap@r60mT',
                xaxis_title=f"Out-of-Plane Field (By) [T] (within ±{ByRange:.0e} T)",
                yaxis_title='Angle [degrees]',
                # xaxis_type='linear' # Default, should work if param_value is numeric
                yaxis_type='category', # Angles are distinct categories
                width=1200,
                height=800,
                template="plotly_white"
            )
            contour_fig.show()
            scatter_fig = go.Figure(data=go.Scatter(
            x=heatmap_source_data['param_value'],
            y=heatmap_source_data['angle'],
            mode='markers', # We only want to see the individual data points
            marker=dict(
                color=heatmap_source_data['Ic'], # <-- Set marker color based on Ic
                colorscale='RdBu',            # <-- The color palette to use
                showscale=True,                  # <-- This displays the color bar legend
                colorbar=dict(
                    title='Ic [A]'               # <-- Label for the color bar
                ),
                symbol='square',                 # <-- Use squares for a grid-like feel
                size=70                           # <-- Adjust size for best visual fit
            )
        ))
        
            # Update the layout with titles and axis labels
            scatter_fig.update_layout(
                title='<b>Critical Current (Ic) vs. Angle and Field (Scatter Plot)</b>',
                xaxis_title='Out-of-Plane Field (By) [T]',
                yaxis_title='In-Plane Angle [degrees]',
                yaxis=dict(type='category'), # Keep angles as distinct categories
                width=1200,
                height=800,
                template="plotly_white"
            )
            
            scatter_fig.show()
        except Exception as e:
            print(f"Could not generate heatmap. Error: {e}")
            print("Sample of data intended for pivot table:")
            print(heatmap_source_data.head())
    else:
        print("Source data for heatmap is empty.")
else:
    print("No data was collected to generate the heatmap.")

# %%
heatmap_fig.data[0].update(zmin=0, zmax=30e-6)
heatmap_fig.show()

# %%
import pandas as pd
import plotly.graph_objects as go
from IPython.display import clear_output
from scipy.signal import find_peaks
import numpy as np # Added for the dummy data

# --- Helper Function Definition (Modified) ---
def process_and_plot_data(dataid, angle, angle_label, fig, IcMax_df, ByRange, f_factor, all_dfs_for_heatmap):
    """
    Processes a single dataset: filters, finds max Ic, and plots it.
    Alignment and offset logic has been REMOVED.
    It also collects the data needed for the final heatmap.
    """
    print(f"Processing dataid: {dataid}, angle: {angle}° ({angle_label})")

    # --- Use your REAL plot_heatmaps function or DUMMY DATA ---
    # Make sure your plot_heatmaps(dataid) function returns a DataFrame as the last value.
    # For testing, you can uncomment the dummy data block.
    fig1, fig2, fig3, Ic_df = plot_heatmaps(dataid)

    # --- DUMMY DATA Block (for testing) ---
    # _data_points = 50
    # _base_param_values = np.linspace(-ByRange*1.5, ByRange*1.5, _data_points)
    # _param_values = _base_param_values
    # peak_center = 0.002 * np.cos(np.deg2rad(angle))
    # _ic_values = np.exp(-((np.array(_param_values)-peak_center)**2)/(2*(0.001)**2)) * 5e-6 + 1e-6*np.random.rand(_data_points)
    # Ic_df = pd.DataFrame({
    #     "param_value": _param_values,
    #     "Ic": _ic_values
    # })
    # --- End of Dummy Data Block ---

    # 1. Filter out the first 10 data points (optional)
    Ic_df = Ic_df.iloc[10:].reset_index(drop=True)

    # 2. Filter data to be within the specified ByRange
    Ic_df_filtered = Ic_df[(Ic_df["param_value"] < ByRange) & (Ic_df["param_value"] > -ByRange)].copy()
    if Ic_df_filtered.empty:
        print(f"Warning: No data within ByRange for dataid {dataid}. Skipping.")
        return fig, IcMax_df, all_dfs_for_heatmap

    # Collect data for the heatmap
    heatmap_data_chunk = Ic_df_filtered.copy()
    heatmap_data_chunk['angle'] = angle
    all_dfs_for_heatmap.append(heatmap_data_chunk)
    
    # 3. Use the original 'param_value' for plotting (no alignment/offset)
    plot_x_values = Ic_df_filtered["param_value"]

    # 4. Calculate the maximum Ic and its corresponding original By
    idx_max = Ic_df_filtered["Ic"].idxmax()
    By_max = Ic_df_filtered.loc[idx_max, "param_value"]
    Ic_max_value = Ic_df_filtered.loc[idx_max, "Ic"]
    IC_normalized = Ic_df_filtered["Ic"]/Ic_max_value

    # 5. Update the IcMax_df DataFrame with the original By value
    new_row_df = pd.DataFrame([{"angle": angle, "IcMax": Ic_max_value, "By": By_max, "dataid": dataid}])
    IcMax_df = pd.concat([IcMax_df, new_row_df], ignore_index=True)

    # 6. Add the processed data trace to the line plot
    # A vertical offset is kept to separate the traces for clarity
    Ic_offset = angle * 1e-6 * f_factor
    fig.add_trace(go.Scatter(
        x=plot_x_values,
        y=Ic_df_filtered["Ic"]/IcMax_df["IcMax"] + Ic_offset,
        mode='lines+markers',
        name=f'{angle}° {angle_label} ({dataid})',
        marker=dict(size=5),
        line=dict(width=2)
    ))

    clear_output(wait=True)
    return fig, IcMax_df, all_dfs_for_heatmap

# --- Main Script ---
# --- Configuration ---
f = 1
ByRange = 10e-3 # Range for filtering param_value.

# --- Initialization ---
IcMax_df = pd.DataFrame(columns=["angle", "IcMax", "By", "dataid"])
fig = go.Figure()
all_dfs_for_heatmap = []

# Define data points for processing (ByOffset removed)
# data_points = [
#     {"dataid": 318, "angle": 0,   "label": "E"},
#     {"dataid": 347, "angle": 45,  "label": "NE"},
#     {"dataid": 321, "angle": 90,  "label": "N"},
#     {"dataid": 322, "angle": 135, "label": "NW"},
#     {"dataid": 323, "angle": 180, "label": "W"},
#     {"dataid": 350, "angle": 225, "label": "SW"},
#     {"dataid": 343, "angle": 270, "label": "S"},
#     {"dataid": 342, "angle": 315, "label": "SE"},
# ]
# data_points = [
#     {"dataid": 401, "angle": 10, "label": "B∥"},
#     {"dataid": 409, "angle": 20, "label": "B∥"},
#     {"dataid": 417, "angle": 30, "label": "B∥"},
#     {"dataid": 419, "angle": 40, "label": "B∥"},
#     {"dataid": 423, "angle": 50, "label": "B∥"},
#     {"dataid": 434, "angle": 60, "label": "B∥"},
#     {"dataid": 442, "angle": 70, "label": "B∥"},
#     {"dataid": 447, "angle": 80, "label": "B∥"},
#     {"dataid": 454, "angle": 90, "label": "B∥"},
#     {"dataid": 457, "angle": 100, "label": "B∥"},
#     {"dataid": 460, "angle": 110, "label": "B∥"},
#     {"dataid": 462, "angle": 120, "label": "B∥"},
#     {"dataid": 464, "angle": 130, "label": "B∥"},
#     {"dataid": 466, "angle": 140, "label": "B∥"},
#     {"dataid": 468, "angle": 150, "label": "B∥"},
#     {"dataid": 476, "angle": 160, "label": "B∥"},
#     {"dataid": 496, "angle": 160, "label": "B∥"},
# ]

data_points =[
    {"dataid": 404, "angle": 10, "label": "B⊥"},
    {"dataid": 413, "angle": 20, "label": "B⊥"},
    {"dataid": 415, "angle": 30, "label": "B⊥"},
    {"dataid": 421, "angle": 40, "label": "B⊥"},
    {"dataid": 430, "angle": 50, "label": "B⊥"},
    {"dataid": 436, "angle": 60, "label": "B⊥"},
    {"dataid": 440, "angle": 70, "label": "B⊥"},
    {"dataid": 478, "angle": 80, "label": "B⊥"},
    {"dataid": 482, "angle": 90, "label": "B⊥"},
    {"dataid": 485, "angle": 100, "label": "B⊥"},
    {"dataid": 490, "angle": 110, "label": "B⊥"},
    {"dataid": 493, "angle": 120, "label": "B⊥"},
    {"dataid": 496, "angle": 130, "label": "B⊥"},
    {"dataid": 498, "angle": 140, "label": "B⊥"},
    {"dataid": 501, "angle": 150, "label": "B⊥"},
    {"dataid": 503, "angle": 160, "label": "B⊥"},
    {"dataid": 506, "angle": 170, "label": "B⊥"},
    {"dataid": 507, "angle": 180, "label": "B⊥"},
    ]
# Loop through the data points and process them
for point in data_points:
    # Function call updated (ByOffset removed)
    fig, IcMax_df, all_dfs_for_heatmap = process_and_plot_data(
        dataid=point["dataid"],
        angle=point["angle"],
        angle_label=point["label"],
        fig=fig,
        IcMax_df=IcMax_df,
        ByRange=ByRange,
        f_factor=f,
        all_dfs_for_heatmap=all_dfs_for_heatmap
    )

# --- Final Line Plot Customization ---
# Add the IcMax trend line to the figure
if not IcMax_df.empty:
    fig.add_trace(go.Scatter(
        x=IcMax_df["By"],
        y=IcMax_df["IcMax"] + IcMax_df["angle"] * 1e-6 * f,
        mode='lines+markers',
        name='IcMax Trend',
        marker=dict(size=10, symbol='star', color='red'),
        line=dict(width=2, dash='dash', color='gray')
    ))

# Update layout for the line plot
fig.update_layout(
    title="<b>Ic-By Scans vs. In-Plane Field Angle</b>",
    xaxis_title="Out-of-Plane Field (By) [T]",
    yaxis_title=f"Critical Current (Ic) + Offset [A] (offset = angle * {f}e-6)",
    legend_title="Measurement",
    hovermode="x unified",
    template="plotly_white",
    width=1200,
    height=800,
)
fig.show()

print("\nFinal IcMax DataFrame (By values are original, not aligned):")
print(IcMax_df)

# --- Heatmap Generation (No changes needed here) ---
if all_dfs_for_heatmap:
    heatmap_source_data = pd.concat(all_dfs_for_heatmap, ignore_index=True)
    
    if not heatmap_source_data.empty:
        try:
            # Create the pivot table for the heatmap
            pivot_table = heatmap_source_data.pivot_table(
                index='angle', 
                columns='param_value', 
                values='Ic'
            )
            
            # Sort for an ordered heatmap
            pivot_table = pivot_table.sort_index(axis=0) 
            pivot_table = pivot_table.sort_index(axis=1) 

            # Interpolate to fill gaps for a smoother heatmap
            pivot_table_interpolated = pivot_table.interpolate(method='linear', axis=1, limit_direction='both')

            heatmap_fig = go.Figure(data=go.Heatmap(
                z=pivot_table_interpolated.values,
                x=pivot_table_interpolated.columns,
                y=pivot_table_interpolated.index,
                colorscale='RdBu',
                colorbar=dict(title='Ic [A]'),
                connectgaps=False, 
            ))
            heatmap_fig.update_layout(
                title='Critical Current (Ic) Heatmap@r60mT',
                xaxis_title=f"Out-of-Plane Field (By) [T] (within ±{ByRange:.0e} T)",
                # yaxis_title='Angle [degrees]',
                yaxis_title='B<sub>∥</sub>(mT)',
                yaxis_type='category',
                width=1200,
                height=800,
                template="plotly_white"
            )
            heatmap_fig.show()

            # To this:
            contour_fig = go.Figure(data=go.Contour(
                z=pivot_table.values,
                x=pivot_table.columns,
                y=pivot_table.index,
                colorscale='RdBu',
                colorbar=dict(title='Ic [A]'),
                connectgaps=True, # This will connect the contour lines
            ))
            
            contour_fig.update_layout(
                title='Critical Current (Ic) Heatmap@r60mT',
                xaxis_title=f"Out-of-Plane Field (By) [T] (within ±{ByRange:.0e} T)",
                yaxis_title='Angle [degrees]',
                # xaxis_type='linear' # Default, should work if param_value is numeric
                yaxis_type='category', # Angles are distinct categories
                width=1200,
                height=800,
                template="plotly_white"
            )
            contour_fig.show()
            scatter_fig = go.Figure(data=go.Scatter(
            x=heatmap_source_data['param_value'],
            y=heatmap_source_data['angle'],
            mode='markers', # We only want to see the individual data points
            marker=dict(
                color=heatmap_source_data['Ic'], # <-- Set marker color based on Ic
                colorscale='RdBu',            # <-- The color palette to use
                showscale=True,                  # <-- This displays the color bar legend
                colorbar=dict(
                    title='Ic [A]'               # <-- Label for the color bar
                ),
                symbol='square',                 # <-- Use squares for a grid-like feel
                size=70                           # <-- Adjust size for best visual fit
            )
        ))
        
            # Update the layout with titles and axis labels
            scatter_fig.update_layout(
                title='<b>Critical Current (Ic) vs. Angle and Field (Scatter Plot)</b>',
                xaxis_title='Out-of-Plane Field (By) [T]',
                yaxis_title='In-Plane Angle [degrees]',
                yaxis=dict(type='category'), # Keep angles as distinct categories
                width=1200,
                height=800,
                template="plotly_white"
            )
            
            scatter_fig.show()
        except Exception as e:
            print(f"Could not generate heatmap. Error: {e}")
            print("Sample of data intended for pivot table:")
            print(heatmap_source_data.head())
    else:
        print("Source data for heatmap is empty.")
else:
    print("No data was collected to generate the heatmap.")
# Out:
# Final IcMax DataFrame (By values are original, not aligned):
#    angle         IcMax      By dataid
# 0     10  3.450000e-05  0.0000    404
# 1     20  2.800000e-05  0.0001    413
# 2     30  2.100000e-05  0.0004    415
# 3     40  9.800000e-06 -0.0023    421
# 4     50  7.000000e-06 -0.0018    430
# 5     60  5.400000e-06 -0.0036    436
# 6     70  5.250000e-06 -0.0060    440
# 7     80  5.480000e-06 -0.0055    478
# 8     90  4.200000e-06 -0.0053    482
# 9    100  2.800000e-06 -0.0047    485
# 10   110  2.480000e-06 -0.0055    490
# 11   120  2.200000e-06  0.0021    493
# 12   130  1.450000e-06 -0.0049    496
# 13   140  1.125000e-06 -0.0027    498
# 14   150  7.800000e-07 -0.0027    501
# 15   160  8.100000e-07  0.0071    503
# 16   170  5.100000e-07  0.0013    506
# 17   180  1.075000e-06 -0.0053    507

# %% [markdown]
# ## output

# %% [markdown]
# ## Zmax

# %%
heatmap_fig.data[0].update(zmin=0,  zmax=1e-6)
heatmap_fig.update_layout(
                title='Critical Current (Ic) Heatmap@r60mT')
heatmap_fig.show()

# %% [markdown]
# ### output

# %% [markdown]
# # New

# %%
# ==============================================================================
# 1. IMPORTS
# ==============================================================================
import pandas as pd
import plotly.graph_objects as go
from IPython.display import clear_output
import numpy as np

# This is an assumed function from your project that loads the actual data.
# from your_project_utils import plot_heatmaps 


# ==============================================================================
# 2. HELPER FUNCTIONS
# ==============================================================================

def load_and_prepare_data(dataid, by_range):
    """
    Loads data for a given dataid and performs initial cleaning and filtering.

    Args:
        dataid (int): The identifier for the dataset.
        by_range (float): The symmetric range [-by_range, by_range] to filter 'param_value'.

    Returns:
        pd.DataFrame: A cleaned and filtered DataFrame with 'param_value' and 'Ic',
                      or an empty DataFrame if loading/filtering fails.
    """
    print(f"Processing dataid: {dataid}...")
    
    # --- Data Loading ---
    # In a real scenario, you would call your actual data loading function.
    # We use a dummy function here for demonstration.
    # fig1, fig2, fig3, ic_df = plot_heatmaps(dataid)
    fig1, fig2, fig3, Ic_df = plot_heatmaps(dataid)

    # --- DUMMY DATA Block (for testing) ---
    # _data_points = 50
    # _base_param_values = np.linspace(-ByRange*1.5, ByRange*1.5, _data_points)
    # _param_values = _base_param_values
    # peak_center = 0.002 * np.cos(np.deg2rad(angle))
    # _ic_values = np.exp(-((np.array(_param_values)-peak_center)**2)/(2*(0.001)**2)) * 5e-6 + 1e-6*np.random.rand(_data_points)
    # Ic_df = pd.DataFrame({
    #     "param_value": _param_values,
    #     "Ic": _ic_values
    # })
    # --- End of Dummy Data Block ---

    # 1. Filter out the first 10 data points (optional)
    ic_df = Ic_df.iloc[10:].reset_index(drop=True)
    # ic_df = generate_dummy_data(dataid, by_range) # Using a dummy for this example
    
    if ic_df.empty:
        print(f"Warning: No data returned for dataid {dataid}.")
        return pd.DataFrame()

    # 1. Filter out the first 10 data points (optional, for measurement stabilization)
    ic_df = ic_df.iloc[10:].reset_index(drop=True)

    # 2. Filter data to be within the specified ByRange
    ic_df_filtered = ic_df[
        (ic_df["param_value"] < by_range) & (ic_df["param_value"] > -by_range)
    ].copy()
    
    if ic_df_filtered.empty:
        print(f"Warning: No data within ByRange for dataid {dataid}.")
    
    return ic_df_filtered

def generate_dummy_data(dataid, by_range, angle_offset=0):
    """Generates sample DataFrame for testing purposes."""
    # This dummy function simulates the output of your 'plot_heatmaps'
    data_points = 50
    # Use dataid to create some variation for different plots
    angle = dataid - 400 + angle_offset 
    base_param_values = np.linspace(-by_range * 1.5, by_range * 1.5, data_points)
    
    # Simulate a peak that shifts with the angle
    peak_center = 0.002 * np.cos(np.deg2rad(angle))
    ic_values = np.exp(-((base_param_values - peak_center)**2) / (2 * (0.001)**2)) * 5e-6 \
                + 1e-6 * np.random.rand(data_points)
                
    return pd.DataFrame({"param_value": base_param_values, "Ic": ic_values})

def generate_summary_plots(source_data, config):
    """
    Generates and displays the final Heatmap, Contour, and Scatter plots.

    Args:
        source_data (pd.DataFrame): The combined DataFrame from all datasets.
        config (dict): The configuration dictionary containing plot settings.
    """
    if source_data.empty:
        print("Source data for summary plots is empty. Skipping generation.")
        return

    try:
        # --- Create Pivot Table ---
        # This reshapes the data into a 2D grid required for heatmap/contour plots
        pivot = source_data.pivot_table(
            index='angle', columns='param_value', values='Ic'
        )
        # Sort for an ordered display
        pivot = pivot.sort_index(axis=0).sort_index(axis=1)
        
        # Interpolate to fill gaps for a smoother visual
        pivot_interpolated = pivot.interpolate(method='linear', axis=1, limit_direction='both')

        # --- Define Base Layout for DRY principle ---
        base_layout = {
            "xaxis_title": f"Out-of-Plane Field (By) [T] (within ±{config['ByRange']:.0e} T)",
            "yaxis_title": 'Angle [degrees]',
            "yaxis_type": 'category',
            "width": 1200,
            "height": 800,
            "template": "plotly_white"
        }

        # --- 1. Heatmap Plot ---
        heatmap_fig = go.Figure(data=go.Heatmap(
            z=pivot_interpolated.values,
            x=pivot_interpolated.columns,
            y=pivot_interpolated.index,
            colorscale='RdBu',
            colorbar=dict(title='Ic [A]'),
            connectgaps=False,
        ))
        heatmap_fig.update_layout(title='<b>Critical Current (Ic) Heatmap</b>', **base_layout)
        heatmap_fig.show()

        # --- 2. Contour Plot ---
        contour_fig = go.Figure(data=go.Contour(
            z=pivot.values,
            x=pivot.columns,
            y=pivot.index,
            colorscale='RdBu',
            colorbar=dict(title='Ic [A]'),
            connectgaps=True,
        ))
        contour_fig.update_layout(title='<b>Critical Current (Ic) Contour Plot</b>', **base_layout)
        contour_fig.show()
        
        # --- 3. Scatter Plot ---
        scatter_fig = go.Figure(data=go.Scatter(
            x=source_data['param_value'],
            y=source_data['angle'],
            mode='markers',
            marker=dict(
                color=source_data['Ic'],
                colorscale='RdBu',
                showscale=True,
                colorbar=dict(title='Ic [A]'),
                symbol='square',
                size=10
            )
        ))
        scatter_fig.update_layout(
            title='<b>Critical Current (Ic) vs. Angle and Field (Scatter)</b>',
            **base_layout
        )
        scatter_fig.show()

    except Exception as e:
        print(f"Could not generate summary plots. Error: {e}")
        print("Sample of data intended for pivot table:")
        print(source_data.head())


# ==============================================================================
# 3. MAIN EXECUTION BLOCK
# ==============================================================================

def main():
    """
    Main function to run the entire data processing and plotting workflow.
    """
    # --- Configuration ---
    # Group all settings here for easy modification.
    CONFIG = {
        "ByRange": 10e-3,      # Range for filtering param_value (By field).
        "offset_factor": 1.0,  # Multiplier for visual offset between line plots.
        "data_points": FiniteCPR003_2B_perp_data
    }

    # --- Initialization ---
    ic_max_results = pd.DataFrame(columns=["angle", "IcMax", "By", "dataid"])
    all_dfs_for_summary = []
    line_fig = go.Figure()

    # --- Processing Loop ---
    for point in CONFIG["data_points"]:
        # 1. Load and filter the data for one point
        df_processed = load_and_prepare_data(point["dataid"], CONFIG["ByRange"])

        if df_processed.empty:
            continue # Skip to the next point if no data was found

        # 2. Collect data for the final summary plots
        heatmap_chunk = df_processed.copy()
        heatmap_chunk['angle'] = point['angle']
        all_dfs_for_summary.append(heatmap_chunk)

        # 3. Analyze to find the maximum critical current
        idx_max = df_processed["Ic"].idxmax()
        by_max = df_processed.loc[idx_max, "param_value"]
        ic_max_value = df_processed.loc[idx_max, "Ic"]

        # 4. Store the result
        new_row = pd.DataFrame([
            {"angle": point["angle"], "IcMax": ic_max_value, "By": by_max, "dataid": point["dataid"]}
        ])
        ic_max_results = pd.concat([ic_max_results, new_row], ignore_index=True)

        # 5. Add a trace to the main line plot
        ic_offset = point['angle'] * 1e-6 * CONFIG['offset_factor']
        line_fig.add_trace(go.Scatter(
            x=df_processed["param_value"],
            y=(df_processed["Ic"] / ic_max_value) + ic_offset, # Normalize to its own max
            mode='lines+markers',
            name=f"{point['angle']}° {point['label']} ({point['dataid']})",
            marker=dict(size=5),
            line=dict(width=2)
        ))
        clear_output(wait=True)

    # --- Finalize and Display Line Plot ---
    if not ic_max_results.empty:
        # Add the trend line showing the peak shifts
        trend_offset = ic_max_results["angle"] * 1e-6 * CONFIG['offset_factor']
        line_fig.add_trace(go.Scatter(
            x=ic_max_results["By"],
            y=(ic_max_results["IcMax"] / ic_max_results["IcMax"]) + trend_offset, # Normalized to 1
            mode='markers',
            name='IcMax Peak Position',
            marker=dict(size=10, symbol='star', color='red'),
        ))
    
    line_fig.update_layout(
        title="<b>Ic-By Scans vs. In-Plane Field Angle</b>",
        xaxis_title="Out-of-Plane Field (By) [T]",
        yaxis_title=f"Normalized Ic + Offset (offset = angle * {CONFIG['offset_factor']}e-6)",
        legend_title="Measurement",
        hovermode="x unified",
        template="plotly_white",
        width=1200,
        height=800,
    )
    line_fig.show()

    print("\n--- Final IcMax Results ---")
    print(ic_max_results)

    # --- Generate and Display Summary Plots (Heatmap, etc.) ---
    summary_source_data = pd.concat(all_dfs_for_summary, ignore_index=True)
    generate_summary_plots(summary_source_data, CONFIG)


if __name__ == "__main__":
    # The if __name__ == "__main__": block ensures that the main() function is
    # called only when the script is executed directly, not when it's imported.
    main()
# Out:
# --- Final IcMax Results ---
#    angle         IcMax        By dataid
# 0     10  3.439516e-05 -0.000256    406
# 1     20  2.800000e-05 -0.000004    414
# 2     30  1.986667e-05 -0.000004    416
# 3     40  9.800000e-06 -0.002300    421
# 4     50  9.300000e-06  0.000490    433
# 5     60  7.700000e-06  0.000744    439
# 6     70  4.350000e-06  0.000614    441
# 7     80  2.100000e-06  0.001094    480
# 8     90  2.150000e-06  0.001258    484
# 9    100  2.250000e-06  0.001205    488
# 10   110  1.850000e-06  0.001089    491
# 11   120  1.440000e-06  0.001090    494
# 12   130  9.200000e-07  0.001147    497

# %% [markdown]
# # New2

# %%
# ==============================================================================
# 1. IMPORTS
# ==============================================================================
import pandas as pd
import plotly.graph_objects as go
from IPython.display import clear_output
import numpy as np

# This is an assumed function from your project that loads the actual data.
# from your_project_utils import plot_heatmaps 


# ==============================================================================
# 2. HELPER FUNCTIONS
# ==============================================================================

def load_and_prepare_data(dataid, by_range):
    """
    Loads data for a given dataid and performs initial cleaning and filtering.

    Args:
        dataid (int): The identifier for the dataset.
        by_range (float): The symmetric range [-by_range, by_range] to filter 'param_value'.

    Returns:
        pd.DataFrame: A cleaned and filtered DataFrame with 'param_value' and 'Ic',
                      or an empty DataFrame if loading/filtering fails.
    """
    print(f"Processing dataid: {dataid}...")
    
    # --- Data Loading ---
    # In a real scenario, you would call your actual data loading function.
    # We use a dummy function here for demonstration.
    fig1, fig2, fig3, ic_df = plot_heatmaps(dataid)
    ic_df = Ic_df.iloc[10:].reset_index(drop=True)
    # ic_df = generate_dummy_data(dataid, by_range) # Using a dummy for this example
    
    if ic_df.empty:
        print(f"Warning: No data returned for dataid {dataid}.")
        return pd.DataFrame()

    # 1. Filter out the first 10 data points (optional, for measurement stabilization)
    ic_df = ic_df.iloc[10:].reset_index(drop=True)

    # 2. Filter data to be within the specified ByRange
    ic_df_filtered = ic_df[
        (ic_df["param_value"] < by_range) & (ic_df["param_value"] > -by_range)
    ].copy()
    
    if ic_df_filtered.empty:
        print(f"Warning: No data within ByRange for dataid {dataid}.")
    
    return ic_df_filtered

def generate_dummy_data(dataid, by_range, angle_offset=0):
    """Generates sample DataFrame for testing purposes."""
    # This dummy function simulates the output of your 'plot_heatmaps'
    data_points = 50
    # Use dataid to create some variation for different plots
    angle = dataid - 400 + angle_offset 
    base_param_values = np.linspace(-by_range * 1.5, by_range * 1.5, data_points)
    
    # Simulate a peak that shifts with the angle
    peak_center = 0.003 * np.cos(np.deg2rad(angle * 2)) # Shift peak for alignment demo
    ic_values = np.exp(-((base_param_values - peak_center)**2) / (2 * (0.001)**2)) * 5e-6 \
                + 1e-6 * np.random.rand(data_points)
                
    return pd.DataFrame({"param_value": base_param_values, "Ic": ic_values})

def generate_summary_plots(source_data, config):
    """
    Generates and displays the final Heatmap, Contour, and Scatter plots.

    Args:
        source_data (pd.DataFrame): The combined DataFrame from all datasets.
        config (dict): The configuration dictionary containing plot settings.
    """
    if source_data.empty:
        print("Source data for summary plots is empty. Skipping generation.")
        return

    try:
        # --- Create Pivot Table ---
        # This reshapes the data into a 2D grid required for heatmap/contour plots
        pivot = source_data.pivot_table(
            index='angle', columns='param_value', values='Ic'
        )
        # Sort for an ordered display
        pivot = pivot.sort_index(axis=0).sort_index(axis=1)
        
        # Interpolate to fill gaps for a smoother visual
        pivot_interpolated = pivot.interpolate(method='linear', axis=1, limit_direction='both')

        # --- Define Base Layout for DRY principle ---
        base_layout = {
            "xaxis_title": config["x_axis_label"], # Use label from config
            "yaxis_title": 'Angle [degrees]',
            "yaxis_type": 'category',
            "width": 1200,
            "height": 800,
            "template": "plotly_white"
        }

        # --- 1. Heatmap Plot ---
        heatmap_fig = go.Figure(data=go.Heatmap(
            z=pivot_interpolated.values,
            x=pivot_interpolated.columns,
            y=pivot_interpolated.index,
            colorscale='RdBu',
            colorbar=dict(title='Ic [A]'),
            connectgaps=False,
        ))
        heatmap_fig.update_layout(title='<b>Aligned Critical Current (Ic) Heatmap</b>', **base_layout)
        heatmap_fig.show()

        # --- 2. Contour Plot ---
        contour_fig = go.Figure(data=go.Contour(
            z=pivot.values,
            x=pivot.columns,
            y=pivot.index,
            colorscale='RdBu',
            colorbar=dict(title='Ic [A]'),
            connectgaps=True,
        ))
        contour_fig.update_layout(title='<b>Aligned Critical Current (Ic) Contour Plot</b>', **base_layout)
        contour_fig.show()
        
        # --- 3. Scatter Plot ---
        scatter_fig = go.Figure(data=go.Scatter(
            x=source_data['param_value'],
            y=source_data['angle'],
            mode='markers',
            marker=dict(
                color=source_data['Ic'],
                colorscale='RdBu',
                showscale=True,
                colorbar=dict(title='Ic [A]'),
                symbol='square',
                size=10
            )
        ))
        scatter_fig.update_layout(
            title='<b>Aligned Critical Current (Ic) vs. Angle and Field (Scatter)</b>',
            **base_layout
        )
        scatter_fig.show()

    except Exception as e:
        print(f"Could not generate summary plots. Error: {e}")
        print("Sample of data intended for pivot table:")
        print(source_data.head())


# ==============================================================================
# 3. MAIN EXECUTION BLOCK
# ==============================================================================

def main():
    """
    Main function to run the entire data processing and plotting workflow.
    """
    # --- Configuration ---
    # Group all settings here for easy modification.
    CONFIG = {
        "ByRange": 10e-3,      # Range for filtering param_value (By field).
        "offset_factor": 1.0,  # Multiplier for visual offset between line plots.
        "x_axis_label": "Aligned Out-of-Plane Field (By - By_peak) [T]", # New label for aligned data
        "data_points":  FiniteCPR003_2B_perp_data
    }

    # --- Initialization ---
    ic_max_results = pd.DataFrame(columns=["angle", "IcMax", "By_original", "dataid"])
    all_dfs_for_summary = []
    line_fig = go.Figure()

    # --- Processing Loop ---
    for point in CONFIG["data_points"]:
        # 1. Load and filter the data for one point
        df_processed = load_and_prepare_data(point["dataid"], CONFIG["ByRange"])

        if df_processed.empty:
            continue

        # 2. Analyze to find the maximum critical current and its original position
        idx_max = df_processed["Ic"].idxmax()
        by_peak_original = df_processed.loc[idx_max, "param_value"]
        ic_max_value = df_processed.loc[idx_max, "Ic"]

        # 3. Store the result with the ORIGINAL peak position
        new_row = pd.DataFrame([
            {"angle": point["angle"], "IcMax": ic_max_value, "By_original": by_peak_original, "dataid": point["dataid"]}
        ])
        ic_max_results = pd.concat([ic_max_results, new_row], ignore_index=True)

        # 4. <<<< ALIGNMENT LOGIC >>>>
        # Create the aligned x-axis values by subtracting the peak's position.
        x_values_aligned = df_processed["param_value"] - by_peak_original

        # 5. Collect data for the summary plots using the ALIGNED values
        summary_chunk = df_processed.copy()
        summary_chunk['angle'] = point['angle']
        summary_chunk['param_value'] = x_values_aligned # Use aligned values
        all_dfs_for_summary.append(summary_chunk)

        # 6. Add a trace to the main line plot using ALIGNED data
        ic_offset = point['angle'] * 1e-6 * CONFIG['offset_factor']
        line_fig.add_trace(go.Scatter(
            x=x_values_aligned, # Use aligned values for the x-axis
            y=(df_processed["Ic"] / ic_max_value) + ic_offset, # Normalize to its own max
            mode='lines+markers',
            name=f"{point['angle']}° {point['label']} ({point['dataid']})",
            marker=dict(size=5),
            line=dict(width=2)
        ))
        clear_output(wait=True)

    # --- Finalize and Display Line Plot ---
    if not ic_max_results.empty:
        # Add the peak markers. After alignment, their x-position is always 0.
        peak_x_positions = np.zeros(len(ic_max_results))
        trend_offset = ic_max_results["angle"] * 1e-6 * CONFIG['offset_factor']
        line_fig.add_trace(go.Scatter(
            x=peak_x_positions,
            y=(ic_max_results["IcMax"] / ic_max_results["IcMax"]) + trend_offset, # Normalized to 1
            mode='markers',
            name='IcMax Peak Position',
            marker=dict(size=10, symbol='star', color='red'),
        ))
    
    line_fig.update_layout(
        title="<b>Aligned Ic-By Scans vs. In-Plane Field Angle</b>",
        xaxis_title=CONFIG["x_axis_label"],
        yaxis_title=f"Normalized Ic + Offset (offset = angle * {CONFIG['offset_factor']}e-6)",
        legend_title="Measurement",
        hovermode="x unified",
        template="plotly_white",
        width=1200,
        height=800,
    )
    line_fig.show()

    print("\n--- Final IcMax Results (Original Peak Positions) ---")
    print(ic_max_results)

    # --- Generate and Display Summary Plots ---
    summary_source_data = pd.concat(all_dfs_for_summary, ignore_index=True)
    generate_summary_plots(summary_source_data, CONFIG)


if __name__ == "__main__":
    # This block ensures that the main() function is called only when the
    # script is executed directly, not when it's imported as a module.
    main()
# Out:
# --- Final IcMax Results (Original Peak Positions) ---
#    angle         IcMax  By_original dataid
# 0     10  8.250000e-07       0.0053    406
# 1     20  8.250000e-07       0.0053    414
# 2     30  8.250000e-07       0.0053    416
# 3     40  8.250000e-07       0.0053    428
# 4     50  8.250000e-07       0.0053    433
# 5     60  8.250000e-07       0.0053    439
# 6     70  8.250000e-07       0.0053    441
# 7     80  8.250000e-07       0.0053    480
# 8     90  8.250000e-07       0.0053    484
# 9    100  8.250000e-07       0.0053    488
# 10   110  8.250000e-07       0.0053    491
# 11   120  8.250000e-07       0.0053    494
# 12   130  8.250000e-07       0.0053    497
